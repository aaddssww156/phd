# %%
from new_library import MLPipeline, HyperparameterOptimizer, ModelTrainer, DataPreprocessor, DataAnalyzer
import pandas as pd

# %%
df = pd.read_excel("./data_raw/DataSet_V49 (2).xlsx")

print(f"Данные успешно загружены! Размер: {df.shape}")
print(f"Занимаемая память: {df.memory_usage(deep=True).sum() / 1024**2:.2f} MB")
# Out:
# Данные успешно загружены! Размер: (17430, 465)
# Занимаемая память: 189.51 MB

# %%
print("hello world")
# Out:
# hello world

# %%
pipeline = MLPipeline()
pipeline.load_data(df)
pipeline.preprocess_data()  # Пропускаем EDA
pipeline.train_models()
# Out:
# ### 🗑️ Удалено 817 строк с пропусками в целевой переменной
# ✅ Целевая переменная преобразована: 'Да'→1, 'Нет'→0
# ## ⚖️ Финальный дисбаланс классов:
# <style type="text/css">
# #T_6df14_row0_col0, #T_6df14_row1_col1, #T_6df14_row1_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_6df14_row0_col1, #T_6df14_row0_col2, #T_6df14_row1_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6df14">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6df14_level0_col0" class="col_heading level0 col0" >Класс</th>
#       <th id="T_6df14_level0_col1" class="col_heading level0 col1" >Количество</th>
#       <th id="T_6df14_level0_col2" class="col_heading level0 col2" >Процент</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6df14_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6df14_row0_col0" class="data row0 col0" >0</td>
# ...
