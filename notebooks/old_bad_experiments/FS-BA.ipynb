# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import (accuracy_score, precision_score, recall_score, 
                           f1_score, roc_auc_score, confusion_matrix, 
                           classification_report, roc_curve, precision_recall_curve, 
                            balanced_accuracy_score)
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from tqdm import tqdm
import time
import warnings
warnings.filterwarnings('ignore')

class FeatureSelectionAnalyzer:
    def __init__(self, X, y, test_size=0.2, random_state=42):
        """
        Инициализация анализатора отбора признаков
        
        Parameters:
        -----------
        X : pandas.DataFrame
            Матрица признаков
        y : pandas.Series или numpy.array
            Целевая переменная (бинарная классификация)
        test_size : float, default=0.2
            Размер тестовой выборки
        random_state : int, default=42
            Фиксатор случайности
        """
        self.X = X
        self.y = y
        self.test_size = test_size
        self.random_state = random_state
        
        # Разделение данных
        self.X_train, self.X_test, self.y_train, self.y_test = train_test_split(
            X, y, test_size=test_size, random_state=random_state, stratify=y
        )
        
        # Хранение результатов
        self.forward_results = {}
        self.backward_results = {}
        self.best_threshold = 0.5  # по умолчанию
        
    def _evaluate_model(self, model, features, method_name, step):
        """
        Оценка модели и сохранение результатов
        """
        start_time = time.time()
        
        # Обучение модели
        X_train_subset = self.X_train[features]
        X_test_subset = self.X_test[features]
        
        model.fit(X_train_subset, self.y_train)
        
        # Предсказания
        y_pred_proba = model.predict_proba(X_test_subset)[:, 1]
        y_pred = (y_pred_proba >= self.best_threshold).astype(int)
        
        # Расчет метрик
        metrics = {
            'accuracy': accuracy_score(self.y_test, y_pred),
            'balanced_accuracy': balanced_accuracy_score(self.y_test, y_pred),
            'precision': precision_score(self.y_test, y_pred),
            'recall': recall_score(self.y_test, y_pred),
            'f1': f1_score(self.y_test, y_pred),
            'roc_auc': roc_auc_score(self.y_test, y_pred_proba),
            'training_time': time.time() - start_time
        }
        
        # Важность признаков (если доступно)
        feature_importance = {}
        if hasattr(model, 'feature_importances_'):
            feature_importance = dict(zip(features, model.feature_importances_))
        elif hasattr(model, 'coef_'):
            feature_importance = dict(zip(features, np.abs(model.coef_[0])))
        
        # Сохранение результатов
        result = {
            'step': step,
            'features': features.copy(),
            'n_features': len(features),
            'metrics': metrics,
            'feature_importance': feature_importance,
            'y_pred_proba': y_pred_proba.copy(),
            'y_pred': y_pred.copy(),
            'y_true': self.y_test.copy(),
            'model': model.__class__.__name__
        }
        
        return result, y_pred_proba
    
    def forward_selection(self, model, max_features=None, cv=3, metric='f1'):
        """
        Forward Selection с сохранением всех результатов
        
        Parameters:
        -----------
        model : sklearn estimator
            Модель для обучения
        max_features : int, optional
            Максимальное количество признаков для отбора
        cv : int, default=3
            Количество фолдов для кросс-валидации (необязательно)
        """
        print("Запуск Forward Selection...")
        
        all_features = list(self.X.columns)
        if max_features is None:
            max_features = len(all_features)
            
        selected_features = []
        remaining_features = all_features.copy()
        best_metric_score = -np.inf
        step = 0
        
        pbar = tqdm(total=min(max_features, len(all_features)))
        
        while len(selected_features) < max_features and remaining_features:
            step += 1
            best_feature = None
            best_score = -np.inf
            
            for feature in remaining_features:
                candidate_features = selected_features + [feature]
                
                # Обучение и оценка
                result, _ = self._evaluate_model(model, candidate_features, 'forward', step)
                current_metric_score = result['metrics'][metric]
                
                if current_metric_score > best_score:
                    best_score = current_metric_score
                    best_feature = feature
                    best_result = result
            
            # Проверка улучшения
            if best_score > best_metric_score:
                best_metric_score = best_score
                selected_features.append(best_feature)
                remaining_features.remove(best_feature)
                
                # Сохранение результатов
                self.forward_results[len(selected_features)] = best_result
                print(f"Step {step}: Добавлен признак '{best_feature}', {metric}: {best_score:.4f}")
            else:
                print(f"Step {step}: Нет улучшений, останавливаемся")
                break
            
            pbar.update(1)
            pbar.set_postfix({f'{metric}': f'{best_score:.4f}', 'Features': len(selected_features)})
        
        pbar.close()
        print(f"Forward Selection завершен. Выбрано признаков: {len(selected_features)}")
        return selected_features
    
    def backward_elimination(self, model, min_features=1, metric='f1'):
        """
        Backward Elimination с сохранением всех результатов
        
        Parameters:
        -----------
        model : sklearn estimator
            Модель для обучения
        min_features : int, default=1
            Минимальное количество признаков
        """
        print("Запуск Backward Elimination...")
        
        selected_features = list(self.X.columns)
        best_metric_score = -np.inf
        step = 0
        
        pbar = tqdm(total=len(selected_features) - min_features)
        
        while len(selected_features) > min_features:
            step += 1
            worst_feature = None
            best_score = -np.inf
            
            for feature in selected_features:
                candidate_features = [f for f in selected_features if f != feature]
                
                # Обучение и оценка
                result, _ = self._evaluate_model(model, candidate_features, 'backward', step)
                current_metric_score = result['metrics'][metric]
                
                if current_metric_score > best_score:
                    best_score = current_metric_score
                    worst_feature = feature
                    best_result = result
            
            # Проверка улучшения
            if best_score > best_metric_score:
                best_metric_score = best_score
                selected_features.remove(worst_feature)
                
                # Сохранение результатов
                self.backward_results[len(selected_features)] = best_result
                print(f"Step {step}: Удален признак '{worst_feature}', {metric}: {best_score:.4f}")
            else:
                print(f"Step {step}: Удаление ухудшает результат, останавливаемся")
                break
            
            pbar.update(1)
            pbar.set_postfix({f'{metric}': f'{best_score:.4f}', 'Features': len(selected_features)})
        
        pbar.close()
        print(f"Backward Elimination завершен. Осталось признаков: {len(selected_features)}")
        return selected_features
    
    def find_optimal_threshold(self, method='forward', n_features=None):
        """
        Поиск оптимального порога для бинарной классификации
        
        Parameters:
        -----------
        method : str, 'forward' or 'backward'
            Метод отбора признаков
        n_features : int, optional
            Количество признаков для анализа
        """
        if method == 'forward' and n_features is None:
            n_features = max(self.forward_results.keys())
        elif method == 'backward' and n_features is None:
            n_features = min(self.backward_results.keys())
        
        if method == 'forward':
            result = self.forward_results[n_features]
        else:
            result = self.backward_results[n_features]
        
        y_true = result['y_true']
        y_pred_proba = result['y_pred_proba']
        
        # Поиск оптимального порога по F1
        thresholds = np.arange(0.1, 0.9, 0.01)
        # best_f1 = -1
        best_threshold = 0.5
        best_balanced_accuracy = -1
        
        for threshold in thresholds:
            y_pred = (y_pred_proba >= threshold).astype(int)
            # f1 = f1_score(y_true, y_pred)
            balanced_accuracy = balanced_accuracy_score(y_true, y_pred)
            # if f1 > best_f1:
            if balanced_accuracy > best_balanced_accuracy:
                best_balanced_accuracy = balanced_accuracy
                best_threshold = threshold
        
        # Дополнительно: оптимальный порог по Youden's J statistic
        fpr, tpr, thresholds_roc = roc_curve(y_true, y_pred_proba)
        j_scores = tpr - fpr
        best_j_threshold = thresholds_roc[np.argmax(j_scores)]
        
        self.best_threshold = best_threshold
        
        print(f"=== Оптимальные пороги ({method}, {n_features} признаков) ===")
        print(f"По Balanced Accuracy score: {best_threshold:.4f} (F1={best_balanced_accuracy:.4f})")
        print(f"По Youden's J: {best_j_threshold:.4f}")
        
        return best_threshold, best_j_threshold
    
    def visualize_probability_distribution(self, method='forward', n_features=None):
        """
        Визуализация распределения вероятностей
        
        Parameters:
        -----------
        method : str, 'forward' or 'backward'
            Метод отбора признаков
        n_features : int, optional
            Количество признаков для визуализации
        """
        if method == 'forward' and n_features is None:
            n_features = max(self.forward_results.keys())
        elif method == 'backward' and n_features is None:
            n_features = min(self.backward_results.keys())
        
        if method == 'forward':
            result = self.forward_results[n_features]
        else:
            result = self.backward_results[n_features]
        
        y_true = result['y_true']
        y_pred_proba = result['y_pred_proba']
        
        plt.figure(figsize=(15, 10))
        
        # 1. Распределение вероятностей для каждого класса
        plt.subplot(2, 2, 1)
        sns.histplot(data=pd.DataFrame({
            'Probability': y_pred_proba,
            'Class': ['Positive' if x == 1 else 'Negative' for x in y_true]
        }), x='Probability', hue='Class', bins=30, kde=True, alpha=0.6)
        plt.axvline(x=0.5, color='r', linestyle='--', alpha=0.7, label='Default threshold (0.5)')
        if hasattr(self, 'best_threshold'):
            plt.axvline(x=self.best_threshold, color='g', linestyle='-', alpha=0.7, 
                       label=f'Optimal threshold ({self.best_threshold:.3f})')
        plt.title(f'Распределение вероятностей ({method}, {n_features} признаков)')
        plt.xlabel('Вероятность класса 1')
        plt.ylabel('Частота')
        plt.legend()
        
        # 2. ROC кривая
        plt.subplot(2, 2, 2)
        fpr, tpr, thresholds = roc_curve(y_true, y_pred_proba)
        roc_auc = roc_auc_score(y_true, y_pred_proba)
        
        plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.3f})')
        plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('ROC кривая')
        plt.legend(loc="lower right")
        
        # 3. Precision-Recall кривая
        plt.subplot(2, 2, 3)
        precision, recall, _ = precision_recall_curve(y_true, y_pred_proba)
        plt.plot(recall, precision, color='blue', lw=2)
        plt.xlabel('Recall')
        plt.ylabel('Precision')
        plt.title('Precision-Recall кривая')
        plt.grid(True)
        
        # 4. Матрица ошибок с оптимальным порогом
        plt.subplot(2, 2, 4)
        y_pred_optimal = (y_pred_proba >= self.best_threshold).astype(int)
        cm = confusion_matrix(y_true, y_pred_optimal)
        
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                   xticklabels=['Predicted Negative', 'Predicted Positive'],
                   yticklabels=['Actual Negative', 'Actual Positive'])
        plt.title(f'Матрица ошибок (threshold={self.best_threshold:.3f})')
        
        plt.tight_layout()
        plt.show()
        
        # Дополнительная визуализация: распределение вероятностей по квантилям
        plt.figure(figsize=(12, 6))
        df_probs = pd.DataFrame({
            'Probability': y_pred_proba,
            'Class': y_true
        })
        
        plt.subplot(1, 2, 1)
        sns.boxplot(x='Class', y='Probability', data=df_probs)
        plt.title('Boxplot вероятностей по классам')
        plt.xlabel('Класс')
        plt.ylabel('Вероятность')
        
        plt.subplot(1, 2, 2)
        # Квантили вероятностей
        quantiles = np.percentile(y_pred_proba, [0, 25, 50, 75, 100])
        plt.hist(y_pred_proba, bins=20, alpha=0.7, edgecolor='black')
        for q in quantiles:
            plt.axvline(x=q, color='r', linestyle='--', alpha=0.5)
        plt.title('Гистограмма вероятностей с квантилями')
        plt.xlabel('Вероятность')
        plt.ylabel('Частота')
        
        plt.tight_layout()
        plt.show()
    
    def compare_feature_selection_methods(self, metric='f1'):
        """
        Сравнение результатов forward selection и backward elimination
        """
        if not self.forward_results and not self.backward_results:
            print("Нет результатов для сравнения. Запустите сначала forward_selection и backward_elimination.")
            return
        
        plt.figure(figsize=(15, 10))
        
        # 1. Сравнение ROC AUC по количеству признаков
        plt.subplot(2, 2, 1)
        
        if self.forward_results:
            forward_x = sorted(self.forward_results.keys())
            forward_y = [self.forward_results[x]['metrics']['roc_auc'] for x in forward_x]
            plt.plot(forward_x, forward_y, 'o-', label='Forward Selection', color='blue')
        
        if self.backward_results:
            backward_x = sorted(self.backward_results.keys())
            backward_y = [self.backward_results[x]['metrics']['roc_auc'] for x in backward_x]
            plt.plot(backward_x, backward_y, 's-', label='Backward Elimination', color='red')
        
        plt.xlabel('Количество признаков')
        plt.ylabel('ROC-AUC')
        plt.title('Сравнение ROC-AUC по количеству признаков')
        plt.legend()
        plt.grid(True)
        
        # 2. Сравнение F1 score
        plt.subplot(2, 2, 2)
        
        if self.forward_results:
            forward_f1 = [self.forward_results[x]['metrics']['f1'] for x in forward_x]
            plt.plot(forward_x, forward_f1, 'o-', label='Forward Selection', color='blue')
        
        if self.backward_results:
            backward_f1 = [self.backward_results[x]['metrics']['f1'] for x in backward_x]
            plt.plot(backward_x, backward_f1, 's-', label='Backward Elimination', color='red')
        
        plt.xlabel('Количество признаков')
        plt.ylabel('F1 Score')
        plt.title('Сравнение F1 Score по количеству признаков')
        plt.legend()
        plt.grid(True)

        # 3. Сравнение Balanced Accuracy
        plt.subplot(2, 2, 3)
        
        if self.forward_results:
            forward_balanced_accuracy = [self.forward_results[x]['metrics']['balanced_accuracy'] for x in forward_x]
            plt.plot(forward_x, forward_balanced_accuracy, 'o-', label='Forward Selection', color='blue')
        
        if self.backward_results:
            backward_balanced_accuracy = [self.backward_results[x]['metrics']['balanced_accuracy'] for x in backward_x]
            plt.plot(backward_x, backward_balanced_accuracy, 's-', label='Backward Elimination', color='red')
        
        plt.xlabel('Количество признаков')
        plt.ylabel('Balanced Accuracy')
        plt.title('Сравнение Balanced Accuracy по количеству признаков')
        plt.legend()
        plt.grid(True)
        
        # 4. Время обучения
        plt.subplot(2, 2, 4)
        
        if self.forward_results:
            forward_time = [self.forward_results[x]['metrics']['training_time'] for x in forward_x]
            plt.plot(forward_x, forward_time, 'o-', label='Forward Selection', color='blue')
        
        if self.backward_results:
            backward_time = [self.backward_results[x]['metrics']['training_time'] for x in backward_x]
            plt.plot(backward_x, backward_time, 's-', label='Backward Elimination', color='red')
        
        plt.xlabel('Количество признаков')
        plt.ylabel('Время обучения (сек)')
        plt.title('Сравнение времени обучения')
        plt.legend()
        plt.grid(True)
        
        # 4. Сравнение важности признаков для лучших моделей
        plt.subplot(2, 2, 4)
        
        best_forward = max(self.forward_results.items(), key=lambda x: x[1]['metrics'][metric])[1]
        best_backward = max(self.backward_results.items(), key=lambda x: x[1]['metrics'][metric])[1]
        
        # Объединяем важность признаков
        all_features = set(list(best_forward['feature_importance'].keys()) + 
                          list(best_backward['feature_importance'].keys()))
        
        forward_importance = [best_forward['feature_importance'].get(f, 0) for f in all_features]
        backward_importance = [best_backward['feature_importance'].get(f, 0) for f in all_features]
        
        x = np.arange(len(all_features))
        width = 0.35
        
        plt.bar(x - width/2, forward_importance, width, label='Forward Selection')
        plt.bar(x + width/2, backward_importance, width, label='Backward Elimination')
        plt.xlabel('Признаки')
        plt.ylabel('Важность')
        plt.title('Сравнение важности признаков')
        plt.xticks(x, list(all_features), rotation=45, ha='right')
        plt.legend()
        
        plt.tight_layout()
        plt.show()
    
    def get_best_features(self, method='forward', metric='f1'):
        """
        Получение лучших признаков по заданной метрике
        
        Parameters:
        -----------
        method : str, 'forward' or 'backward'
            Метод отбора признаков
        metric : str, default='roc_auc'
            Метрика для выбора лучших признаков
        """
        if method == 'forward':
            results = self.forward_results
        else:
            results = self.backward_results
        
        if not results:
            print(f"Нет результатов для метода {method}. Запустите сначала отбор признаков.")
            return None
        
        # Находим лучший результат по метрике
        best_result = max(results.items(), key=lambda x: x[1]['metrics'][metric])[1]
        
        print(f"=== Лучшие признаки ({method}) ===")
        print(f"Количество признаков: {best_result['n_features']}")
        print(f"Лучшая {metric}: {best_result['metrics'][metric]:.4f}")
        print(f"Признаки: {best_result['features']}")
        
        if best_result['feature_importance']:
            print("\nВажность признаков:")
            sorted_importance = sorted(best_result['feature_importance'].items(), 
                                     key=lambda x: x[1], reverse=True)
            for feature, importance in sorted_importance:
                print(f"  {feature}: {importance:.4f}")
        
        return best_result['features'], best_result
    
    def save_results_to_excel(self, filename='feature_selection_results.xlsx'):
        """
        Сохранение всех результатов в Excel файл
        
        Parameters:
        -----------
        filename : str, default='feature_selection_results.xlsx'
            Имя файла для сохранения
        """
        with pd.ExcelWriter(filename) as writer:
            # Forward Selection results
            if self.forward_results:
                forward_df = []
                for n_features, result in self.forward_results.items():
                    row = {
                        'Method': 'Forward',
                        'Step': result['step'],
                        'N_Features': result['n_features'],
                        'Features': ', '.join(result['features']),
                        'Accuracy': result['metrics']['accuracy'],
                        'Precision': result['metrics']['precision'],
                        'Recall': result['metrics']['recall'],
                        'F1': result['metrics']['f1'],
                        'ROC_AUC': result['metrics']['roc_auc'],
                        'Training_Time': result['metrics']['training_time']
                    }
                    
                    # Добавляем важность признаков
                    for feature, importance in result['feature_importance'].items():
                        row[f'Importance_{feature}'] = importance
                    
                    forward_df.append(row)
                
                pd.DataFrame(forward_df).to_excel(writer, sheet_name='Forward_Selection', index=False)
            
            # Backward Elimination results
            if self.backward_results:
                backward_df = []
                for n_features, result in self.backward_results.items():
                    row = {
                        'Method': 'Backward',
                        'Step': result['step'],
                        'N_Features': result['n_features'],
                        'Features': ', '.join(result['features']),
                        'Accuracy': result['metrics']['accuracy'],
                        'Precision': result['metrics']['precision'],
                        'Recall': result['metrics']['recall'],
                        'F1': result['metrics']['f1'],
                        'ROC_AUC': result['metrics']['roc_auc'],
                        'Training_Time': result['metrics']['training_time']
                    }
                    
                    # Добавляем важность признаков
                    for feature, importance in result['feature_importance'].items():
                        row[f'Importance_{feature}'] = importance
                    
                    backward_df.append(row)
                
                pd.DataFrame(backward_df).to_excel(writer, sheet_name='Backward_Elimination', index=False)
            
            # Сравнение результатов
            if self.forward_results and self.backward_results:
                comparison_data = []
                
                # Лучшие результаты для каждого метода
                best_forward = max(self.forward_results.items(), key=lambda x: x[1]['metrics']['f1'])[1]
                best_backward = max(self.backward_results.items(), key=lambda x: x[1]['metrics']['f1'])[1]
                
                comparison_data.append({
                    'Method': 'Forward_Selection',
                    'N_Features': best_forward['n_features'],
                    'Features': ', '.join(best_forward['features']),
                    'ROC_AUC': best_forward['metrics']['roc_auc'],
                    'F1': best_forward['metrics']['f1'],
                    'Accuracy': best_forward['metrics']['accuracy']
                })
                
                comparison_data.append({
                    'Method': 'Backward_Elimination',
                    'N_Features': best_backward['n_features'],
                    'Features': ', '.join(best_backward['features']),
                    'ROC_AUC': best_backward['metrics']['roc_auc'],
                    'F1': best_backward['metrics']['f1'],
                    'Accuracy': best_backward['metrics']['accuracy']
                })
                
                pd.DataFrame(comparison_data).to_excel(writer, sheet_name='Best_Results_Comparison', index=False)
        
        print(f"Результаты успешно сохранены в файл: {filename}")


# Пример использования:

# Загрузка данных (пример)
# from sklearn.datasets import make_classification

# # Генерация примера данных
# X, y = make_classification(
#     n_samples=1000,
#     n_features=20,
#     n_informative=10,
#     n_redundant=5,
#     n_classes=2,
#     random_state=42
# )

# feature_names = [f'feature_{i}' for i in range(20)]
# X_df = pd.DataFrame(X, columns=feature_names)
# y_series = pd.Series(y)

# # Инициализация анализатора
# analyzer = FeatureSelectionAnalyzer(X_df, y_series, test_size=0.2, random_state=42)

# # Выбор модели
# model_rf = RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)

# # Запуск forward selection
# print("=== FORWARD SELECTION ===")
# forward_features = analyzer.forward_selection(model_rf, max_features=15)

# # Запуск backward elimination
# print("\n=== BACKWARD ELIMINATION ===")
# backward_features = analyzer.backward_elimination(model_rf, min_features=5)

# # Сравнение методов
# print("\n=== СРАВНЕНИЕ МЕТОДОВ ===")
# analyzer.compare_feature_selection_methods()

# # Поиск оптимального порога для лучшей модели forward selection
# print("\n=== ПОИСК ОПТИМАЛЬНОГО ПОРОГА ===")
# best_threshold, _ = analyzer.find_optimal_threshold(method='forward')

# # Визуализация распределения вероятностей
# print("\n=== ВИЗУАЛИЗАЦИЯ РАСПРЕДЕЛЕНИЯ ВЕРОЯТНОСТЕЙ ===")
# analyzer.visualize_probability_distribution(method='forward')

# # Получение лучших признаков
# print("\n=== ЛУЧШИЕ ПРИЗНАКИ ===")
# best_forward_features, best_forward_result = analyzer.get_best_features(method='forward')
# best_backward_features, best_backward_result = analyzer.get_best_features(method='backward')

# # Сохранение результатов
# print("\n=== СОХРАНЕНИЕ РЕЗУЛЬТАТОВ ===")
# analyzer.save_results_to_excel('feature_selection_analysis.xlsx')

# print("\n=== ЗАКЛЮЧЕНИЕ ===")
# print(f"Лучший ROC AUC (Forward): {best_forward_result['metrics']['roc_auc']:.4f} с {len(best_forward_features)} признаками")
# print(f"Лучший ROC AUC (Backward): {best_backward_result['metrics']['roc_auc']:.4f} с {len(best_backward_features)} признаками")
# print(f"Оптимальный порог для бинарной классификации: {best_threshold:.4f}")

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
data = pd.read_excel("../../data_raw/DataSet_V49 (2).xlsx")

# %%
data = data.head(3_000)

# %%
cols_to_delete = [
    "Код пациента", "Name", "Дата STEMI", "Дата направления (Общий анализ крови)", 
    "Дата взятия биоматериала (Общий анализ крови)", "Дата выполнения (Общий анализ крови)", 
    "Дата направления (Общий анализ крови-экспрес)", "Дата взятия биоматериала (Общий анализ крови-экспрес)",
    "Дата выполнения (Общий анализ крови-экспрес)", "Начало операции(ИБ)(Новый)", "Конец операции(ИБ)(Новый)", 
    "дата поступления", "дата выписки", "дата смерти", "Исход заболевания", "Поступление в реанимацию", 
    "Выписка из реанимации", "Файл(Анализы)", "Файл(ИБ)","Наличие в БД", "Наличие в файле", "Bypass#", 
    "Повторная оперция", "Смерть в реанимации", "Причина смерти", "Осложнения", "SmokeIndex", "Ход операции", 
    "Общий анализ крови раньше операции", "Общий анализ крови_экспресс раньше операции", "Отделение", 
    "Запись требует проверки", "Индекс курения", "Летальный исход икка", "Диагноз", 
    "Дата и время развития SOFA 8 и более", "Время введения первого антибиотика", 
    "Набор данных (Данные Кокарев)", "Unnamed: 344", "В базе данных", 
    "SYNTAX Score", "ХСН фк", "КДР ЛЖ", "КСР ЛЖ", "ДАД(a)", "Кардиогенный шок",
    'длительность нахождения в стационаре'
]

cols_might_leak = [
    # Все столбцы с суффиксом (a) - измерены ПОСЛЕ поступления
    'САД(a)', 'ДАД(a)', 'ЧСС(а)', 'Нейтрофилы (абсолютное значение)(a)', 
    'Нейтрофилы (относительное значение)(a)', 'Лимфоциты (абсолютное значение)(a)', 
    'Лимфоциты (относительное значение)(a)', 'Моноциты (абсолютное значение)(a)', 
    'Моноциты (относительное значение)(a)', 'Эозинофилы (абсолютное значение)(a)', 
    'Эозинофилы (относительное значение)(a)', 'Базофилы (абсолютное значение)(a)', 
    'Базофилы (относительное значение)(a)', 'Эр(a)', 'Hb(a)', 'Гематокрит(a)', 
    'Тромбоциты(a)', 'СОЭ(a)', 'Эозинофилы(%)(a)', 'Палочкоядерные нейтрофилы(%)(a)', 
    'Cегментоядерные нейтрофилы(%)(a)', 'Лимфоциты(%)(a)', 'Моноциты(%)(a)', 
    'Миелоциты(%)(a)', 'Общий белок(a)', 'Глюкоза(a)', 'АСАТ(a)', 'АЛАТ(a)', 
    'Билирубин общий(a)', 'Холестерин общий(a)', 'Триглицериды(a)', 'Креатинин(a)', 
    'Мочевина(a)', 'ЛДГ(a)', 'КФК(a)', 'КФК-МВ(a)', 'ПТИ(a)', 'МНО(a)', 'ФБГ(a)', 
    'ТВ(a)', 'АПТВ(a)', 'eGFR (a)', 'Тропонин 1 (a)', 'Тропонин 1 > 0.1 (a)', 
    'Натрий (Na) (a)', 'Калий (K) (a)', 'Хлор (Cl) (a)', 'Кальций ионизированный (Ca+) (a)', 
    'pHARTmin (a)', 'pHARTmax (a)', 'pO2ARTmin (a)', 'pO2ARTmax (a)', 'pCO2min (a)', 
    'pCO2max (a)', 'SaO2min (a)', 'SaO2max (a)', 'LACTartMin (a)', 'LACTartMax (a)', 
    'BEArtMin (a)', 'BEArtMax (a)', 'HCO3ArtMin (a)', 'HCO3ArtMax (a)', 'PHVenMin (a)', 
    'PHVenMax (a)', 'PO2VenMin (a)', 'PO2VenMax (a)', 'PCO2VenMin (a)', 'PCO2VenMax (a)', 
    'ScvO2Min (a)', 'ScvO2Max (a)', 'LactVenMin (a)', 'LactVenMax (a)', 'BEVenMin (a)', 
    'BEVenMax (a)', 'HCO3VenMin (a)', 'HCO3VenMax (a)', 'BNP (a)', 'Отек легких(a)', 
    'ФВ ЛЖ (b)', 'СДЛА(a)',
    
    # Все временные показатели суток/часов/после развития
    'Часов до введения первого антибиотика', 'Часов в ОРИТ ДО развития SOFA 8', 
    'Часов в ОРИТ ПОСЛЕ развития SOFA 8', 'Максимальный прокальцитонин за сутки до развития SOFA 8', 
    'Максимальный ЛАКТАТ артерия за сутки до развития SOFA 8', 'Максимальный ЛАКТАТ вена за сутки до развития SOFA 8', 
    'Максимальный ЛАКТАТ артерия за сутки после развития SOFA 8', 'Максимальный ЛАКТАТ вена за сутки после развития SOFA 8', 
    'SOFA первый раз больше или равна 8 баллам', 'SOFA до развития 8 и более баллов', 
    'Количество часов применения антибиотика ДО развития SOFA 8 и более', 'Через сколько часов после развития SOFA 8 и более был введен антибиотик', 
    'APACHE сутки до развития SOFA 8 и более', 'APACHE сутки ПОСЛЕ развития SOFA 8 и более', 
    'АД среднее за сутки до развития SOFA 8', 'Среднее АД 1 сутки в орит', 'Минимальное АД 1 сут', 
    'Макс АД 1 сут', 'Среднее АД 3 сутки в орит', 'Минимальное АД 3 сут', 'Макс АД 3 сут', 
    'Среднее АД 7 сутки в орит', 'Минимальное АД 7 сут', 'Макс АД 7 сут', 'Среднее ЧСС 1 сутки', 
    'Мин ЧСС 1 сутки', 'Максимальное ЧСС 1 сутки', 'Среднее ЧСС 3 сутки', 'Мин ЧСС 3 сутки', 
    'Максимальное ЧСС 3 сутки', 'Среднее ЧСС 7 сутки', 'Мин ЧСС 7 сутки', 'Максимальное ЧСС 7 сутки',
    
    # Все показатели лечения и осложнений
    'ИВЛ', 'Вазопрессорная поддержка', 'Адреналин', 'Добутамин', 'Допмин', 'Норадреналин', 
    'Левосимендан', 'Мезатон', 'Max Aдреналин', 'Max Добутамин', 'Max Допмин', 'Max Норадреналин', 
    'Max Мезатона', 'Левофлоксацин антибиотик ДО развития SOFA 8 и более', 
    'Линезолид антибиотик ДО развития SOFA 8 и более', 'Меропенем антибиотик ДО развития SOFA 8 и более', 
    'Метронидазол антибиотик ДО развития SOFA 8 и более', 'Моксифлоксацин антибиотик ДО развития SOFA 8 и более', 
    'Нифуроксазид антибиотик ДО развития SOFA 8 и более', 'Фосфомицин антибиотик ДО развития SOFA 8 и более', 
    'Цефазолин антибиотик ДО развития SOFA 8 и более', 'Сульбактам антибиотик ДО развития SOFA 8 и более', 
    'Цефоперазон антибиотик ДО развития SOFA 8 и более', 'Цефтриаксон антибиотик ДО развития SOFA 8 и более', 
    'Антибиотик после развития SOFA 8 и более', 'Моксифлоксацин после развития SOFA 8 и более', 
    'Левофлоксацин после развития SOFA 8 и более', 'Азитромицин после развития SOFA 8 и более', 
    'Линезолид после развития SOFA 8 и более', 'Меропенем после развития SOFA 8 и более', 
    'Метронидазол после развития SOFA 8 и более', 'Нифуроксазид после развития SOFA 8 и более', 
    'Фосфомицин после развития SOFA 8 и более', 'Цефазолин после развития SOFA 8 и более', 
    'Сульбактам после развития SOFA 8 и более', 'Цефепим после развития SOFA 8 и более', 
    'Цефтриаксон после развития SOFA 8 и более', 'Лейкоциты больше 9 до назначения аб',
    
    # Все оценочные шкалы с временной привязкой
    'GRACE(Общее)>140', 'GRACE(Общее)>156', 'CADILLAC', 'РЕКОРД', 'PAMI', 'TIMI (Летальность)', 
    'CADILLAC (Низкий риск)', 'CADILLAC (Средний риск)', 'CADILLAC (Высокий риск)', 
    'РЕКОРД (Низкий риск)', 'РЕКОРД (Высокий риск)', 'GRACE (Низкий риск)', 'GRACE (Средний риск)', 
    'GRACE (Высокий риск)', 'TIMI (Летальность) (Низкий риск)', 'TIMI (Летальность) (Средний риск)', 
    'TIMI (Летальность) (Высокий риск)', 'PAMI (Низкий риск)', 'PAMI (Средний риск)', 
    'PAMI (Высокий риск)', 'Время ЧКВ'
]

# %%
for col in cols_to_delete:
    data.drop([col], axis=1, inplace=True)

# %%
for col in cols_might_leak: 
    try:
        data.drop([col], axis=1, inplace=True)
    except Exception: 
        pass

# %%
data.dropna(subset=['Смерть'], inplace=True)

# %%
data['Смерть'] = data['Смерть'].map({'Да': 1, 'Нет': 0})

# %%
category_cols = [
    "Sex", "STEMI", "ЧКВ", "Вид STEMI", "Инфаркт-зависимая артерия",
    "Поражение ствола","Инфаркт миокарда в анамнезе (<3)",
    "Инфаркт миокарда в анамнезе (>3)",'Инфаркт миокарда со стентированием в анамнезе',
    'ОНМК (иш) в анамнезе', 'ОНМК (гем) в анамнезе','Стентирование в анамнезе',
    'Тромболизис', 'Форма ФП', 'Калий', 'Дилатация предсердий','ФП b (после чкв)',
    'ФП a (в анамнезе)', 'ФП при окс (до чкв)', 'ФП постоянная форма', 'ФЖ',
    'Пробежки ЖТ', 'Рецидивирующая ЖТ', 'MKB', 'Класс ОСН по Killip',
    'ХСН стадия', 'АГ', 'Стенокардия (ИБ)', 'Стенокардия форма(ИБ)',
    'Стенокардия ФК (ИБ)', 'СД', 'ХБП', 'ЯБ', 'МКБ', 'ЖКБ', 'Стеноз аортального клапана (степень)',
    'Недостаточность трикуспидального клапана (степень)', 'НПВ', 'Экстренная операция(ИБ)(Новый)',
    'Вид операции(ИБ)(Новый)', 'повторные операции','Тип первой операции БД',
    'Тип повторной операции', 'GRACE(Общее)>140', 'интегрилин|эптифибатид|коромакс|агграстат',
    'Экстракардиальная артериопатия', 'Плохая мобильность', 'Открытая перация на сердце в анамнезе',
    'Срочность', 'Сопутствующие1', 'Сопутствующие2', 'Тропонин 1 > 0.1 (b)', 'Тропонин 1 > 0.1 (a)',
    'Тропонин 1 > 0.1', 'Smoking', 'Протокол коронарографии', 'Аортальный стеноз (Градиент)',
    'Аортальный стеноз (Заключение)', 'ХОБЛ (Новый столбец)', 'Коррекция А-В блокады',
    'Исход А-В блокады', 'Начало А-В блокады (До/после ЧКВ)', 'А-В блокада',
    'Стенокардия в диагнозе при поступлении', 'ПИКС в диагнозе при поступлении',
    'Инфаркт-зависимая артерия(Огригированная)', 'Инфаркт-зависимая артерия(Огригированная)2',
    'Ишемический инсульт (Выгрузка из ИБ - временный столбец)', 'Геморрагический инсульт (Выгрузка из ИБ - временный столбец)',
    'Инсульт (Выгрузка из ИБ - временный столбец)', 'Курит', 'GRACE(Общее)>156', 'Отек легких(b)',
    'Отек легких(a)', 'Отек легких', 'Медицинская помощь оказана за первые 4 часа',
    'Гипертоническая болезнь', 'ФВ < 40', 'CADILLAC (Низкий риск)', 'CADILLAC (Средний риск)',
    'CADILLAC (Высокий риск)', 'РЕКОРД (Низкий риск)', 'РЕКОРД (Высокий риск)',
    'GRACE (Низкий риск)', 'GRACE (Средний риск)', 'GRACE (Высокий риск)',
    'TIMI (Летальность) (Низкий риск)', 'TIMI (Летальность) (Средний риск)',
    'TIMI (Летальность) (Высокий риск)', 'PAMI (Низкий риск)', 'PAMI (Средний риск)',
    'PAMI (Высокий риск)', 'А-В блокаДа (Новый)', 'А-В блокада (степень)',
    'Используемый антибиотик ДО развития SOFA 8 и более',
    'Левофлоксацин антибиотик ДО развития SOFA 8 и более',
    'Линезолид антибиотик ДО развития SOFA 8 и более',
    'Меропенем антибиотик ДО развития SOFA 8 и более',
    'Метронидазол антибиотик ДО развития SOFA 8 и более',
    'Моксифлоксацин антибиотик ДО развития SOFA 8 и более',
    'Нифуроксазид антибиотик ДО развития SOFA 8 и более',
    'Фосфомицин антибиотик ДО развития SOFA 8 и более',
    'Цефазолин антибиотик ДО развития SOFA 8 и более',
    'Сульбактам антибиотик ДО развития SOFA 8 и более',
    'Цефоперазон антибиотик ДО развития SOFA 8 и более',
    'Цефтриаксон антибиотик ДО развития SOFA 8 и более',
    'Антибиотик после развития SOFA 8 и более',
    'Моксифлоксацин после развития SOFA 8 и более',
    'Левофлоксацин после развития SOFA 8 и более',
    'Азитромицин после развития SOFA 8 и более',
    'Линезолид после развития SOFA 8 и более',
    'Меропенем после развития SOFA 8 и более',
    'Метронидазол после развития SOFA 8 и более',
    'Нифуроксазид после развития SOFA 8 и более',
    'Фосфомицин после развития SOFA 8 и более',
    'Цефазолин после развития SOFA 8 и более',
    'Сульбактам после развития SOFA 8 и более',
    'Цефепим после развития SOFA 8 и более',
    'Цефтриаксон после развития SOFA 8 и более',
    'ИВЛ', 'Вазопрессорная поддержка', 'Адреналин',
    'Добутамин', 'Допмин', 'Норадреналин', 'Левосимендан',
    'Мезатон', 'UA (нестабильная стенокардия)','Синдромный диагноз','Смерть'
]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for col in category_cols:
    try:
        data[col] = data[col].fillna('missing')
        data[col] = data[col].astype(str)
        # data[col] = data[col].astype('category') 
        data[col] = le.fit_transform(data[col])
    except KeyError: 
        pass

# %%
X = data.drop(["Смерть"], axis=1)
y = data["Смерть"]

# %%
X = data.drop(['длительность нахождения в стационаре'], axis=1, inplace=True)

# %%
# Инициализация анализатора
analyzer = FeatureSelectionAnalyzer(X, y, test_size=0.2, random_state=42)

# Выбор модели
model_rf = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)  # уменьшено количество деревьев для скорости

# Запуск forward selection БЕЗ early stopping
print("=== FORWARD SELECTION (без early stopping) ===")
forward_features = analyzer.forward_selection(model_rf, max_features=None)  # ограничим до 10 признакей для демонстрации

# Запуск backward elimination БЕЗ early stopping
print("\n=== BACKWARD ELIMINATION (без early stopping) ===")
backward_features = analyzer.backward_elimination(model_rf, min_features=1)

# Сравнение методов
print("\n=== СРАВНЕНИЕ МЕТОДОВ ===")
analyzer.compare_feature_selection_methods()

# Поиск оптимального порога для лучшей модели forward selection
print("\n=== ПОИСК ОПТИМАЛЬНОГО ПОРОГА ===")
best_threshold, _ = analyzer.find_optimal_threshold(method='forward')

# Визуализация распределения вероятностей
print("\n=== ВИЗУАЛИЗАЦИЯ РАСПРЕДЕЛЕНИЯ ВЕРОЯТНОСТЕЙ ===")
analyzer.visualize_probability_distribution(method='forward')

# Получение лучших признакей из всех комбинаций
print("\n=== ЛУЧШИЕ ПРИЗНАКИ ИЗ ВСЕХ КОМБИНАЦИЙ ===")
best_forward_features, best_forward_result = analyzer.get_best_features(method='forward')
best_backward_features, best_backward_result = analyzer.get_best_features(method='backward')

# Сохранение результатов
print("\n=== СОХРАНЕНИЕ РЕЗУЛЬТАТОВ ===")
analyzer.save_results_to_excel('feature_selection_analysis_full.xlsx')

print("\n=== ЗАКЛЮЧЕНИЕ ===")
print(f"Лучший ROC AUC (Forward): {best_forward_result['metrics']['roc_auc']:.4f} с {len(best_forward_features)} признаками")
print(f"Лучший ROC AUC (Backward): {best_backward_result['metrics']['roc_auc']:.4f} с {len(best_backward_features)} признаками")
print(f"Оптимальный порог для бинарной классификации: {best_threshold:.4f}")

# %% [markdown]
# ----------------

# %%
scale_pos_weight = len(y[y == 0]) / max(1, len(y[y == 1]))
class_weight_dict = {0: 1, 1: scale_pos_weight}

print(scale_pos_weight)
print(class_weight_dict)
# Out:
# 27.89217391304348
# {0: 1, 1: 27.89217391304348}

# %%
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
import lightgbm

# %%
# Инициализация анализатора
analyzer = FeatureSelectionAnalyzer(X, y, test_size=0.2, random_state=42)

# Выбор модели
xgb_model = XGBClassifier(
    n_estimators=100,
    max_depth=5,
    learning_rate=0.1,
    scale_pos_weight=scale_pos_weight,  # борьба с дисбалансом
    missing=np.nan,  # явно указываем, что NaN - это пропуски
    random_state=42,
    eval_metric='logloss',  # для бинарной классификации
    tree_method='auto'  # автоматический выбор метода обучения
)  # уменьшено количество деревьев для скорости

# Запуск forward selection БЕЗ early stopping
print("=== FORWARD SELECTION (без early stopping) ===")
forward_features = analyzer.forward_selection(xgb_model, max_features=None)  # ограничим до 10 признакей для демонстрации

# Запуск backward elimination БЕЗ early stopping
print("\n=== BACKWARD ELIMINATION (без early stopping) ===")
backward_features = analyzer.backward_elimination(xgb_model, min_features=1)

# Сравнение методов
print("\n=== СРАВНЕНИЕ МЕТОДОВ ===")
analyzer.compare_feature_selection_methods()

# Поиск оптимального порога для лучшей модели forward selection
print("\n=== ПОИСК ОПТИМАЛЬНОГО ПОРОГА ===")
best_threshold, _ = analyzer.find_optimal_threshold(method='forward')

# Визуализация распределения вероятностей
print("\n=== ВИЗУАЛИЗАЦИЯ РАСПРЕДЕЛЕНИЯ ВЕРОЯТНОСТЕЙ ===")
analyzer.visualize_probability_distribution(method='forward')

# Получение лучших признакей из всех комбинаций
print("\n=== ЛУЧШИЕ ПРИЗНАКИ ИЗ ВСЕХ КОМБИНАЦИЙ ===")
best_forward_features, best_forward_result = analyzer.get_best_features(method='forward')
best_backward_features, best_backward_result = analyzer.get_best_features(method='backward')

# Сохранение результатов
print("\n=== СОХРАНЕНИЕ РЕЗУЛЬТАТОВ ===")
analyzer.save_results_to_excel('feature_selection_analysis_full.xlsx')

print("\n=== ЗАКЛЮЧЕНИЕ ===")
print(f"Лучший ROC AUC (Forward): {best_forward_result['metrics']['roc_auc']:.4f} с {len(best_forward_features)} признаками")
print(f"Лучший ROC AUC (Backward): {best_backward_result['metrics']['roc_auc']:.4f} с {len(best_backward_features)} признаками")
print(f"Оптимальный порог для бинарной классификации: {best_threshold:.4f}")

# %%
data["Смерть"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        1
#         ..
# 17425    0
# 17426    0
# 17427    0
# 17428    0
# 17429    0
# Name: Смерть, Length: 16613, dtype: int64

# %%
test = data[["Отек легких", "Смерть"]].dropna()

# %%
test
# Out:
#        СДЛА  Смерть
# 0      57.0       0
# 1      28.0       0
# 2      25.0       0
# 3      35.0       0
# 5      25.0       0
# ...     ...     ...
# 17425  30.0       0
# 17426  32.0       0
# 17427  25.0       0
# 17428  23.0       0
# 17429  25.0       0
#
# [13278 rows x 2 columns]

# %%
roc_auc_score(test["Смерть"], test["Отек легких"]) # ОСМ По киллип 3
# Out:
# 0.22131833634249093

# %%
# Инициализация анализатора
analyzer = FeatureSelectionAnalyzer(X, y, test_size=0.2, random_state=42)

# Выбор модели
model_rf = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)  # уменьшено количество деревьев для скорости

# Запуск forward selection БЕЗ early stopping
print("=== FORWARD SELECTION (без early stopping) ===")
forward_features = analyzer.forward_selection(model_rf, max_features=None)  # ограничим до 10 признакей для демонстрации

# Запуск backward elimination БЕЗ early stopping
print("\n=== BACKWARD ELIMINATION (без early stopping) ===")
backward_features = analyzer.backward_elimination(model_rf, min_features=1)

# Сравнение методов
print("\n=== СРАВНЕНИЕ МЕТОДОВ ===")
analyzer.compare_feature_selection_methods()

# Поиск оптимального порога для лучшей модели forward selection
print("\n=== ПОИСК ОПТИМАЛЬНОГО ПОРОГА ===")
best_threshold, _ = analyzer.find_optimal_threshold(method='forward')

# Визуализация распределения вероятностей
print("\n=== ВИЗУАЛИЗАЦИЯ РАСПРЕДЕЛЕНИЯ ВЕРОЯТНОСТЕЙ ===")
analyzer.visualize_probability_distribution(method='forward')

# Получение лучших признакей из всех комбинаций
print("\n=== ЛУЧШИЕ ПРИЗНАКИ ИЗ ВСЕХ КОМБИНАЦИЙ ===")
best_forward_features, best_forward_result = analyzer.get_best_features(method='forward')
best_backward_features, best_backward_result = analyzer.get_best_features(method='backward')

# Сохранение результатов
print("\n=== СОХРАНЕНИЕ РЕЗУЛЬТАТОВ ===")
analyzer.save_results_to_excel('feature_selection_analysis_full.xlsx')

print("\n=== ЗАКЛЮЧЕНИЕ ===")
print(f"Лучший f1 (Forward): {best_forward_result['metrics']['f1']:.4f} с {len(best_forward_features)} признаками")
print(f"Лучший f1 (Backward): {best_backward_result['metrics']['f1']:.4f} с {len(best_backward_features)} признаками")
print(f"Оптимальный порог для бинарной классификации: {best_threshold:.4f}")
# Out:
# === FORWARD SELECTION (без early stopping) ===
# Запуск Forward Selection...
#   0%|          | 0/252 [00:00<?, ?it/s]
#   0%|          | 1/252 [00:45<3:09:34, 45.32s/it]
#   0%|          | 1/252 [00:45<3:09:34, 45.32s/it, F1=0.4138, Features=1]
# Step 1: Добавлен признак 'ФВ < 40', F1: 0.4138
#   1%|          | 2/252 [01:30<3:07:39, 45.04s/it, F1=0.4138, Features=1]
#   1%|          | 2/252 [01:30<3:07:39, 45.04s/it, F1=0.5432, Features=2]
# Step 2: Добавлен признак 'Apache II', F1: 0.5432
#   1%|          | 3/252 [02:16<3:09:44, 45.72s/it, F1=0.5432, Features=2]
#   1%|          | 3/252 [02:16<3:09:44, 45.72s/it, F1=0.5698, Features=3]
# Step 3: Добавлен признак 'Глюкоза в мг/дл', F1: 0.5698
#   2%|▏         | 4/252 [03:08<3:18:06, 47.93s/it, F1=0.5698, Features=3]
#   2%|▏         | 4/252 [03:08<3:18:06, 47.93s/it, F1=0.5965, Features=4]
# Step 4: Добавлен признак 'LACTartMax (b)', F1: 0.5965
#   2%|▏         | 5/252 [03:58<3:21:19, 48.90s/it, F1=0.5965, Features=4]
#   2%|▏         | 5/252 [03:58<3:21:19, 48.90s/it, F1=0.6047, Features=5]
# Step 5: Добавлен признак 'LACTartMax', F1: 0.6047
#   2%|▏         | 6/252 [04:49<3:23:16, 49.58s/it, F1=0.6047, Features=5]
#   2%|▏         | 6/252 [04:49<3:23:16, 49.58s/it, F1=0.6127, Features=6]
# Step 6: Добавлен признак 'Моноциты(%)(b)', F1: 0.6127
#   3%|▎         | 7/252 [05:40<3:24:13, 50.01s/it, F1=0.6127, Features=6]
#   3%|▎         | 7/252 [05:40<3:24:13, 50.01s/it, F1=0.6207, Features=7]
# Step 7: Добавлен признак 'Стеноз митрального клапана (степень)', F1: 0.6207
#   3%|▎         | 7/252 [06:30<3:48:04, 55.86s/it, F1=0.6207, Features=7]
# Step 8: Нет улучшений, останавливаемся
# Forward Selection завершен. Выбрано признаков: 7
#
# === BACKWARD ELIMINATION (без early stopping) ===
# Запуск Backward Elimination...
#   0%|          | 0/251 [00:00<?, ?it/s]
#   0%|          | 1/251 [01:41<7:01:50, 101.24s/it]
#   0%|          | 1/251 [01:41<7:01:50, 101.24s/it, F1=0.5896, Features=251]
# Step 1: Удален признак 'Форма ФП', F1: 0.5896
#   0%|          | 1/251 [03:24<14:10:06, 204.02s/it, F1=0.5896, Features=251]
# Step 2: Удаление ухудшает результат, останавливаемся
# Backward Elimination завершен. Осталось признаков: 251
#
# === СРАВНЕНИЕ МЕТОДОВ ===
# === ПОИСК ОПТИМАЛЬНОГО ПОРОГА ===
# === Оптимальные пороги (forward, 7 признаков) ===
# По F1 score: 0.4300 (F1=0.6257)
# По Youden's J: 0.0306
#
# === ВИЗУАЛИЗАЦИЯ РАСПРЕДЕЛЕНИЯ ВЕРОЯТНОСТЕЙ ===
# === ЛУЧШИЕ ПРИЗНАКИ ИЗ ВСЕХ КОМБИНАЦИЙ ===
# === Лучшие признаки (forward) ===
# Количество признаков: 7
# Лучшая f1: 0.6207
# Признаки: ['ФВ < 40', 'Apache II', 'Глюкоза в мг/дл', 'LACTartMax (b)', 'LACTartMax', 'Моноциты(%)(b)', 'Стеноз митрального клапана (степень)']
#
# Важность признаков:
#   ФВ < 40: 0.3065
#   Apache II: 0.2620
#   Глюкоза в мг/дл: 0.2247
#   LACTartMax: 0.1005
#   LACTartMax (b): 0.0743
#   Моноциты(%)(b): 0.0303
#   Стеноз митрального клапана (степень): 0.0018
# === Лучшие признаки (backward) ===
# Количество признаков: 251
# Лучшая f1: 0.5896
# Признаки: ['Age', 'Sex', 'STEMI', 'ЧКВ', 'Вид STEMI', 'Инфаркт-зависимая артерия', 'Поражение ствола', 'Количество пораженных сосудов(Syntax)', 'Количество пораженных сосудов(Значимость)', 'TIMI', 'Инфаркт миокарда в анамнезе (<3)', 'Инфаркт миокарда в анамнезе (>3)', 'Инфаркт миокарда со стентированием в анамнезе', 'ОНМК (иш) в анамнезе', 'ОНМК (гем) в анамнезе', 'Стентирование в анамнезе', 'Тромболизис', 'Калий', 'Дилатация предсердий', 'ФП b (после чкв)', 'ФП a (в анамнезе)', 'ФП при окс (до чкв)', 'ФП постоянная форма', 'ФЖ', 'Пробежки ЖТ', 'Рецидивирующая ЖТ', 'MKB', 'Класс ОСН по Killip', 'ХСН стадия', 'ГБ стадия', 'ГБ риск', 'АГ', 'Стенокардия (ИБ)', 'Стенокардия форма(ИБ)', 'Стенокардия ФК (ИБ)', 'СД', 'ХБП', 'ЯБ', 'МКБ', 'ЖКБ', 'ФВ ЛЖ', 'EDV', 'МЖП', 'ЗСЛЖ', 'ПСПЖ', 'СДЛА', 'Размер правого желудочка', 'Стеноз аортального клапана (степень)', 'Недостаточность аортального клапана (степень)', 'Стеноз митрального клапана (степень)', 'Недостаточность митрального клапана (степень)', 'Недостаточность трикуспидального клапана (степень)', 'НПВ', 'НПВ диаметр', 'La1', 'La2', 'Ra1', 'Ra2', 'Гематокрит', 'Гемоглобин', 'Эритроциты', 'Лейкоциты', 'Тромбоциты', 'Нейтрофилы (абсолютное значение)', 'Нейтрофилы (относительное значение)', 'Лимфоциты (абсолютное значение)', 'Лимфоциты (относительное значение)', 'Моноциты (абсолютное значение)', 'Моноциты (относительное значение)', 'Эозинофилы (абсолютное значение)', 'Эозинофилы (относительное значение)', 'Базофилы (абсолютное значение)', 'Базофилы (относительное значение)', 'Сумма всех лейкоцитов', 'Средний объем эритроцита', 'Среднее содержание гемоглобина в эритроците', 'Ср, концентрация гемоглобина в эритроците', 'Распределение эритроцитов по объему (RDW-CV)', 'Распределение эритроцитов по объему (RDW-SD)', 'Средний объем тромбоцита (MPV)', 'Расчетная ширина распределения тромбоцитов', 'Тромбокрит', 'Коэффициент крупных тромбоцитов', 'СОЭ', 'С-реактивный белок', 'PLR (тромбоциты/лимфоциты абс) (61-239)', 'MLR (моноциты/лимфоциты)', 'LMR (лимфоциты абс/моноциты абс)', 'SII (тромбоциты*нейтрофилы абс / лимфоциты абс)', 'ELR (эозинофилы абс/лимфоциты абс', 'ELR %', 'ENR (эозин абс/нейтрофилы абс)', 'BLR (базофилы абс/лимфоциты абс)', 'SIRI (NxM)/L', 'PIV or AISI (NxMxPLT)/L', 'GLR (глюкоза мг/дл / лимф абс)', 'FLR (fibr/L abs)', 'RLR (RDW/ lymph abs)', 'MPV/PC (MPV/ PLT)', 'Глюкоза в мг/дл', 'Фибриноген', 'Эозинофилы(%)(b)', 'Палочкоядерные нейтрофилы(%)(b)', 'Cегментоядерные нейтрофилы(%)(b)', 'Лимфоциты(%)(b)', 'Моноциты(%)(b)', 'Общий белок(b)', 'Глюкоза(b)', 'АСАТ(b)', 'АЛАТ(b)', 'Билирубин общий(b)', 'Холестерин общий(b)', 'Триглицериды(b)', 'Креатинин(b)', 'Мочевина(b)', 'ЛДГ(b)', 'КФК(b)', 'КФК-МВ(b)', 'ПТИ(b)', 'МНО(b)', 'ТВ(b)', 'АПТВ(b)', 'Продолжительность операции', 'Экстренная операция(ИБ)(Новый)', 'Вид операции(ИБ)(Новый)', 'повторные операции', 'Тип первой операции БД', 'Тип повторной операции', 'Количество дней в реанимации', 'Apache II', 'GRACE(Общее)', 'интегрилин|эптифибатид|коромакс|агграстат', 'Рост', 'Вес', 'Индекс массы тела', 'Экстракардиальная артериопатия', 'Плохая мобильность', 'Открытая перация на сердце в анамнезе', 'Срочность', 'Систолическое АД(b)', 'Диастолического АД(b)', 'ЧСС (b)', 'P', 'PQ', 'QRS', 'QT', 'RR', 'Лейкоциты(a)', 'Сопутствующие1', 'Сопутствующие2', 'Креатинин', 'СКФ', 'Тропонин 1 (b)', 'Тропонин 1 > 0.1 (b)', 'Тропонин 1', 'Тропонин 1 > 0.1', 'Smoking', 'Протокол коронарографии', 'Аортальный стеноз (Градиент)', 'Аортальный стеноз (Заключение)', 'ХОБЛ (Новый столбец)', 'Коррекция А-В блокады', 'Исход А-В блокады', 'Начало А-В блокады (До/после ЧКВ)', 'А-В блокада', 'Стенокардия в диагнозе при поступлении', 'ПИКС в диагнозе при поступлении', 'Инфаркт-зависимая артерия(Огригированная)', 'Инфаркт-зависимая артерия(Огригированная)2', 'Ишемический инсульт (Выгрузка из ИБ - временный столбец)', 'Геморрагический инсульт (Выгрузка из ИБ - временный столбец)', 'Инсульт (Выгрузка из ИБ - временный столбец)', 'SpO2', 'Курит', 'Отек легких(b)', 'Отек лег ...
#
# Важность признаков:
#   ФВ < 40: 0.0661
#   Apache II: 0.0371
#   Age: 0.0291
#   Креатинин: 0.0234
#   Отек легких: 0.0207
#   PLR (тромбоциты/лимфоциты абс) (61-239): 0.0169
#   Нейтрофилы (абсолютное значение): 0.0164
#   ФВ ЛЖ: 0.0161
#   Систолическое АД(b): 0.0149
#   SII (тромбоциты*нейтрофилы абс / лимфоциты абс): 0.0144
#   Ra1: 0.0144
#   Лейкоциты: 0.0143
#   Вид операции(ИБ)(Новый): 0.0139
#   LACTartMax: 0.0136
#   Продолжительность операции: 0.0132
#   СДЛА: 0.0131
#   Диастолического АД(b): 0.0128
#   Нейтрофилы (относительное значение): 0.0125
#   ЧСС (b): 0.0125
#   GRACE(Общее): 0.0124
#   Лейкоциты(a): 0.0123
#   La2: 0.0120
#   Класс ОСН по Killip: 0.0118
#   Ra2: 0.0115
#   Лимфоциты (относительное значение): 0.0113
#   La1: 0.0111
#   НПВ диаметр: 0.0108
#   Количество дней в реанимации: 0.0101
#   Моноциты (относительное значение): 0.0098
#   Моноциты (абсолютное значение): 0.0096
#   MKB: 0.0093
#   МЖП: 0.0092
#   LACTartMin (b): 0.0091
#   СКФ: 0.0088
#   Эозинофилы (относительное значение): 0.0087
#   ЗСЛЖ: 0.0085
#   СОЭ: 0.0081
#   Гемоглобин: 0.0077
#   Гематокрит: 0.0075
#   Расчетная ширина распределения тромбоцитов: 0.0075
#   STEMI: 0.0075
#   SpO2: 0.0073
#   Коэффициент крупных тромбоцитов: 0.0070
#   Эозинофилы (абсолютное значение): 0.0069
#   LactVenMax: 0.0068
#   LACTartMax (b): 0.0066
#   Глюкоза в мг/дл: 0.0064
#   Тромбоциты: 0.0063
#   Размер правого желудочка: 0.0062
#   Эритроциты: 0.0062
#   Лимфоциты (абсолютное значение): 0.0058
#   killip: 0.0056
#   Средний объем тромбоцита (MPV): 0.0056
#   С-реактивный белок: 0.0055
#   ELR (эозинофилы абс/лимфоциты абс: 0.0053
#   Ср, концентрация гемоглобина в эритроците: 0.0053
#   Вес: 0.0052
#   MPV/PC (MPV/ PLT): 0.0052
#   Средний объем эритроцита: 0.0051
#   Используемый антибиотик ДО развития SOFA 8 и более: 0.0049
#   Распределение эритроцитов по объему (RDW-CV): 0.0049
#   ПСПЖ: 0.0048
#   RLR (RDW/ lymph abs): 0.0048
#   Индекс массы тела: 0.0046
#   Рост: 0.0046
#   Распределение эритроцитов по объему (RDW-SD): 0.0045
#   Мочевина(b): 0.0045
#   GLR (глюкоза мг/дл / лимф абс): 0.0045
#   Синдромный диагноз: 0.0044
#   Тромбокрит: 0.0041
#   Базофилы (абсолютное значение): 0.0041
#   Инфаркт-зависимая артерия: 0.0040
#   LactVenMin: 0.0040
#   Экстренная операция(ИБ)(Новый): 0.0039
#   Среднее содержание гемоглобина в эритроците: 0.0039
#   LACTartMin: 0.0037
#   Глюкоза(b): 0.0037
#   BLR (базофилы абс/лимфоциты абс): 0.0036
#   Тропонин 1: 0.0036
#   Сумма всех лейкоцитов: 0.0034
#   Фибриноген: 0.0032
#   ФП b (после чкв): 0.0031
#   Базофилы (относительное значение): 0.0031
#   Вид STEMI: 0.0031
#   ENR (эозин абс/нейтрофилы абс): 0.0031
#   Экстракардиальная артериопатия: 0.0030
#   Креатинин(b): 0.0030
#   ФП постоянная форма: 0.0030
#   Количество пораженных сосудов(Значимость): 0.0030
#   ФП при окс (до чкв): 0.0030
#   LMR (лимфоциты абс/моноциты абс): 0.0030
#   LactVenMax (b): 0.0029
#   Стенокардия в диагнозе при поступлении: 0.0027
#   SIRI (NxM)/L: 0.0025
#   Количество пораженных сосудов(Syntax): 0.0025
#   ОНМК (гем) в анамнезе: 0.0025
#   Аортальный стеноз (Градиент): 0.0025
#   ScvO2Max: 0.0024
#   pHARTmin (b): 0.0024
#   Sex: 0.0024
#   TIMI: 0.0024
#   Стентирование в анамнезе: 0.0023
#   MLR (моноциты/лимфоциты): 0.0023
#   Натрий (Na): 0.0023
#   Отек легких(b): 0.0022
#   pO2ARTmin: 0.0022
#   BEArtMax: 0.0022
#   HCO3ArtMin: 0.0021
#   АЛАТ(b): 0.0021
#   Хлор (Cl): 0.0021
#   Калий (K): 0.0021
#   BEVenMin: 0.0021
#   СД: 0.0021
#   FLR (fibr/L abs): 0.0020
#   ScvO2Min: 0.0020
#   SaO2min: 0.0020
#   PIV or AISI (NxMxPLT)/L: 0.0020
#   pHARTmin: 0.0020
#   pCO2min (b): 0.0020
#   ЧКВ: 0.0019
#   интегрилин|эптифибатид|коромакс|агграстат: 0.0019
#   АСАТ(b): 0.0019
#   BEArtMin: 0.0018
#   ГБ стадия: 0.0018
#   Инсульт (Выгрузка из ИБ - временный столбец): 0.0017
#   pO2ARTmax: 0.0017
#   pO2ARTmin (b): 0.0017
#   pCO2min: 0.0017
#   ГБ риск: 0.0016
#   ХБП: 0.0016
#   ФП a (в анамнезе): 0.0016
#   PCO2VenMax: 0.0016
#   Калий: 0.0015
#   PCO2VenMin: 0.0015
#   Стенокардия (ИБ): 0.0015
#   pO2ARTmax (b): 0.0015
#   PHVenMin: 0.0015
#   Инфаркт-зависимая артерия(Огригированная): 0.0015
#   HCO3ArtMax: 0.0015
#   HCO3ArtMax (b): 0.0015
#   RR: 0.0014
#   Курит: 0.0014
#   PO2VenMin: 0.0014
#   pCO2max (b): 0.0014
#   SaO2max: 0.0014
#   ELR %: 0.0014
#   PHVenMax: 0.0013
#   Сопутствующие1: 0.0013
#   Smoking: 0.0013
#   Срочность: 0.0013
#   BEArtMax (b): 0.0013
#   SaO2min (b): 0.0013
#   pHARTmax (b): 0.0013
#   Стенокардия форма(ИБ): 0.0012
#   pHARTmax: 0.0012
#   BEVenMax: 0.0012
#   HCO3ArtMin (b): 0.0012
#   QT: 0.0012
#   BEArtMin (b): 0.0011
#   Ишемический инсульт (Выгрузка из ИБ - временный столбец): 0.0011
#   PO2VenMax: 0.0011
#   pCO2max: 0.0011
#   LactVenMin (b): 0.0011
#   Стеноз аортального клапана (степень): 0.0011
#   Дилатация предсердий: 0.0010
#   PQ: 0.0010
#   НПВ: 0.0010
#   Общий белок(b): 0.0010
#   ОНМК (иш) в анамнезе: 0.0010
#   А-В блокаДа (Новый): 0.0010
#   QRS: 0.0010
#   Медицинская помощь оказана за первые 4 часа: 0.0010
#   Тромболизис: 0.0010
#   Аортальный стеноз (Заключение): 0.0010
#   Палочкоядерные нейтрофилы(%)(b): 0.0010
#   повторные операции: 0.0009
#   Сопутствующие2: 0.0009
#   UA (нестабильная стенокардия): 0.0009
#   BEVenMax (b): 0.0009
#   Инфаркт миокарда в анамнезе (>3): 0.0009
#   Инфаркт-зависимая артерия(Огригированная)2: 0.0009
#   PO2VenMax (b): 0.0009
#   Тропонин 1 > 0.1: 0.0009
#   ХОБЛ (Новый столбец): 0.0009
#   HCO3VenMax: 0.0008
#   ХСН стадия: 0.0008
#   Кальций ионизированный (Ca+): 0.0008
#   ScvO2Min (b): 0.0008
#   Моноциты(%)(b): 0.0008
#   BEVenMin (b): 0.0008
#   Cегментоядерные нейтрофилы(%)(b): 0.0008
#   Тип повторной операции: 0.0008
#   Тропонин 1 (b): 0.0008
#   SaO2max (b): 0.0008
#   ПТИ(b): 0.0008
#   P: 0.0008
#   Протокол коронарографии: 0.0007
#   АПТВ(b): 0.0007
#   HCO3VenMin: 0.0007
#   Поражение ствола: 0.0007
#   ТВ(b): 0.0007
#   А-В блокада: 0.0007
#   Исход А-В блокады: 0.0007
#   PCO2VenMin (b): 0.0007
#   ЯБ: 0.0007
#   PHVenMax (b): 0.0007
#   Тип первой операции БД: 0.0006
#   КФК-МВ(b): 0.0006
#   HCO3VenMax (b): 0.0006
#   Инфаркт миокарда со стентированием в анамнезе: 0.0006
#   МКБ: 0.0006
#   ФЖ: 0.0006
#   PO2VenMin (b): 0.0006
#   ПИКС в диагнозе при поступлении: 0.0006
#   Билирубин общий(b): 0.0006
#   ЛДГ(b): 0.0006
#   КФК(b): 0.0005
#   Стенокардия ФК (ИБ): 0.0005
#   Гипертоническая болезнь: 0.0005
#   Инфаркт миокарда в анамнезе (<3): 0.0005
#   HCO3VenMin (b): 0.0005
#   АГ: 0.0005
#   Геморрагический инсульт (Выгрузка из ИБ - временный столбец): 0.0005
#   МНО(b): 0.0005
#   PHVenMin (b): 0.0004
#   Калий (K) (b): 0.0004
#   PCO2VenMax (b): 0.0004
#   Холестерин общий(b): 0.0004
#   ScvO2Max (b): 0.0004
#   Триглицериды(b): 0.0004
#   BNP: 0.0003
#   Тропонин 1 > 0.1 (b): 0.0003
#   Начало А-В блокады (До/после ЧКВ): 0.0003
#   Лимфоциты(%)(b): 0.0002
#   А-В блокада (степень): 0.0002
#   Коррекция А-В блокады: 0.0002
#   ЖКБ: 0.0002
#   Открытая перация на сердце в анамнезе: 0.0001
#   Рецидивирующая ЖТ: 0.0001
#   Недостаточность трикуспидального клапана (степень): 0.0001
#   Недостаточность митрального клапана (степень): 0.0001
#   Недостаточность аортального клапана (степень): 0.0001
#   Плохая мобильность: 0.0001
#   Пробежки ЖТ: 0.0001
#   Хлор (Cl) (b): 0.0001
#   Эозинофилы(%)(b): 0.0001
#   Натрий (Na) (b): 0.0000
#   Стеноз митрального клапана (степень): 0.0000
#   EDV: 0.0000
#   Кальций ионизированный (Ca+) (b): 0.0000
#   BNP (b): 0.0000
#
# === СОХРАНЕНИЕ РЕЗУЛЬТАТОВ ===
# Результаты успешно сохранены в файл: feature_selection_analysis_full.xlsx
#
# === ЗАКЛЮЧЕНИЕ ===
# Лучший f1 (Forward): 0.6207 с 7 признаками
# Лучший f1 (Backward): 0.5896 с 251 признаками
# Оптимальный порог для бинарной классификации: 0.4300

# %%
import pandas as pd

# %%
df = pd.read_csv("prepared_data.csv")

print(f"Данные успешно загружены! Размер: {df.shape}")
print(f"Занимаемая память: {df.memory_usage(deep=True).sum() / 1024**2:.2f} MB")
# Out:
# Данные успешно загружены! Размер: (16613, 192)
# Занимаемая память: 21.12 MB

# %%
X = df.drop(["target", "Отек легких"], axis=1)
y = df["target"]

# %%
def clean_column_names(df):
    """
    Очищает имена колонок от символов, которые не принимает XGBoost
    """
    new_columns = []
    for col in df.columns:
        # Удаляем запрещенные символы
        clean_col = col.replace('[', '_').replace(']', '_').replace('<', '_lt_')
        # Удаляем другие потенциально проблемные символы
        clean_col = clean_col.replace('>', '_gt_').replace(' ', '_').replace(':', '_')
        clean_col = clean_col.replace('(', '_').replace(')', '_').replace(',', '_')
        clean_col = clean_col.replace('{', '_').replace('}', '_').replace('|', '_')
        # Удаляем последовательные подчеркивания
        clean_col = '_'.join(filter(None, clean_col.split('_')))
        # Удаляем подчеркивания в начале и конце
        clean_col = clean_col.strip('_')
        # Если имя начинается с цифры, добавляем префикс
        if clean_col and clean_col[0].isdigit():
            clean_col = 'f_' + clean_col
        new_columns.append(clean_col)
    
    # Создаем копию DataFrame с новыми именами колонок
    df_clean = df.copy()
    df_clean.columns = new_columns
    return df_clean

# Применяем к вашим данным
X_clean = clean_column_names(X)

# %%
analyzer = FeatureSelectionAnalyzer(X_clean, y, test_size=0.2, random_state=42)

# %%
# Запуск forward selection БЕЗ early stopping
print("=== FORWARD SELECTION (без early stopping) ===")
forward_features = analyzer.forward_selection(xgb_model, max_features=None)  # ограничим до 10 признакей для демонстрации

# Запуск backward elimination БЕЗ early stopping
print("\n=== BACKWARD ELIMINATION (без early stopping) ===")
backward_features = analyzer.backward_elimination(xgb_model, min_features=1)

# Сравнение методов
print("\n=== СРАВНЕНИЕ МЕТОДОВ ===")
analyzer.compare_feature_selection_methods()

# Поиск оптимального порога для лучшей модели forward selection
print("\n=== ПОИСК ОПТИМАЛЬНОГО ПОРОГА ===")
best_threshold, _ = analyzer.find_optimal_threshold(method='forward')

# Визуализация распределения вероятностей
print("\n=== ВИЗУАЛИЗАЦИЯ РАСПРЕДЕЛЕНИЯ ВЕРОЯТНОСТЕЙ ===")
analyzer.visualize_probability_distribution(method='forward')

# Получение лучших признакей из всех комбинаций
print("\n=== ЛУЧШИЕ ПРИЗНАКИ ИЗ ВСЕХ КОМБИНАЦИЙ ===")
best_forward_features, best_forward_result = analyzer.get_best_features(method='forward')
best_backward_features, best_backward_result = analyzer.get_best_features(method='backward')

# Сохранение результатов
print("\n=== СОХРАНЕНИЕ РЕЗУЛЬТАТОВ ===")
analyzer.save_results_to_excel('feature_selection_analysis_full.xlsx')

print("\n=== ЗАКЛЮЧЕНИЕ ===")
print(f"Лучший ROC AUC (Forward): {best_forward_result['metrics']['roc_auc']:.4f} с {len(best_forward_features)} признаками")
print(f"Лучший ROC AUC (Backward): {best_backward_result['metrics']['roc_auc']:.4f} с {len(best_backward_features)} признаками")
print(f"Оптимальный порог для бинарной классификации: {best_threshold:.4f}")

# %%
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
import lightgbm
import time

# %%
scale_pos_weight = len(y[y == 0]) / max(1, len(y[y == 1]))
class_weight_dict = {0: 1, 1: scale_pos_weight}

print(f"scale pos weight: {scale_pos_weight}")
# Out:
# scale pos weight: 27.89217391304348

# %%
xgb_model = XGBClassifier(
    n_estimators=100,
    max_depth=5,
    learning_rate=0.1,
    scale_pos_weight=scale_pos_weight,  # борьба с дисбалансом
    missing=np.nan,  # явно указываем, что NaN - это пропуски
    random_state=42,
    eval_metric='logloss',  # для бинарной классификации
    tree_method='auto'  # автоматический выбор метода обучения
)

# %%
lgb_model = LGBMClassifier(
    n_estimators=100,
    max_depth=5,
    learning_rate=0.1,
    class_weight=class_weight_dict,  # борьба с дисбалансом
    random_state=42,
    verbose=-1,  # подавляем вывод (задается при инициализации, а не в fit)
    # early_stopping_rounds=50  # задается при инициализации
)

# %%
cat_model = CatBoostClassifier(
    iterations=100,
    depth=5,
    learning_rate=0.1,
    class_weights=[1, scale_pos_weight],  # борьба с дисбалансом
    random_state=42,
    verbose=False,
    eval_metric='Logloss',
    early_stopping_rounds=50  # задается при инициализации
)

# %% [markdown]
# # XGB

# %% [markdown]
# ### XGB Forward selection

# %%
print("=== FORWARD SELECTION ===")
forward_features = analyzer.forward_selection(xgb_model, max_features=None, metric='balanced_accuracy')  # ограничим до 10 признакей для демонстрации
# Out:
# === FORWARD SELECTION ===
# Запуск Forward Selection...
#   0%|          | 0/417 [00:00<?, ?it/s]

# %% [markdown]
# ### XGB Backward elimination

# %%
1
# Out:
# 1

# %%
print("\n=== BACKWARD ELIMINATION ===")
backward_features = analyzer.backward_elimination(xgb_model, min_features=1, metric='balanced_accuracy')

# %%
print("Hello world")
# Out:
# Hello world

# %%
backward_features
# Out:
# ['Age',
#  'Sex',
#  'STEMI',
#  'ЧКВ',
#  'Вид_STEMI',
#  'Инфаркт-зависимая_артерия',
#  'Поражение_ствола',
#  'Количество_пораженных_сосудов_Syntax',
#  'Количество_пораженных_сосудов_Значимость',
#  'TIMI',
#  'Инфаркт_миокарда_в_анамнезе_lt_3',
#  'Инфаркт_миокарда_в_анамнезе_gt_3',
#  'Инфаркт_миокарда_со_стентированием_в_анамнезе',
#  'ОНМК_иш_в_анамнезе',
#  'ОНМК_гем_в_анамнезе',
#  'Стентирование_в_анамнезе',
#  'Тромболизис',
#  'Форма_ФП',
#  'Калий',
#  'Дилатация_предсердий',
#  'ФП_b_после_чкв',
#  'ФП_a_в_анамнезе',
#  'ФП_при_окс_до_чкв',
#  'ФП_постоянная_форма',
#  'ФЖ',
#  'Пробежки_ЖТ',
#  'Рецидивирующая_ЖТ',
#  'MKB',
#  'Класс_ОСН_по_Killip',
#  'ХСН_стадия',
#  'ГБ_стадия',
#  'ГБ_риск',
#  'АГ',
#  'Стенокардия_ИБ',
#  'Стенокардия_форма_ИБ',
#  'Стенокардия_ФК_ИБ',
#  'СД',
#  'ХБП',
#  'ЯБ',
#  'МКБ',
#  'ЖКБ',
#  'ФВ_ЛЖ_b',
#  'ФВ_ЛЖ',
#  'EDV',
#  'МЖП',
#  'ЗСЛЖ',
#  'ПСПЖ',
#  'СДЛА',
#  'Размер_правого_желудочка',
#  'Стеноз_аортального_клапана_степень',
#  'Недостаточность_аортального_клапана_степень',
#  'Стеноз_митрального_клапана_степень',
#  'Недостаточность_митрального_клапана_степень',
#  'Недостаточность_трикуспидального_клапана_степень',
#  'НПВ',
#  'НПВ_диаметр',
#  'La1',
#  'La2',
#  'Ra1',
#  'Ra2',
#  'Гематокрит',
#  'Гемоглобин',
#  'Эритроциты',
#  'Лейкоциты',
#  'Тромбоциты',
#  'Нейтрофилы_абсолютное_значение',
#  'Нейтрофилы_относительное_значение',
#  'Лимфоциты_абсолютное_значение',
#  'Лимфоциты_относительное_значение',
#  'Моноциты_абсолютное_значение',
#  'Моноциты_относительное_значение',
#  'Эозинофилы_абсолютное_значение',
#  'Эозинофилы_относительное_значение',
#  'Базофилы_абсолютное_значение',
#  'Базофилы_относительное_значение',
#  'Сумма_всех_лейкоцитов',
#  'Средний_объем_эритроцита',
#  'Среднее_содержание_гемоглобина_в_эритроците',
#  'Ср_концентрация_гемоглобина_в_эритроците',
#  'Распределение_эритроцитов_по_объему_RDW-CV',
#  'Распределение_эритроцитов_по_объему_RDW-SD',
#  'Расчетная_ширина_распределения_тромбоцитов',
#  'Тромбокрит',
#  'Коэффициент_крупных_тромбоцитов',
#  'СОЭ',
#  'С-реактивный_белок',
#  'PLR_тромбоциты/лимфоциты_абс_61-239',
#  'MLR_моноциты/лимфоциты',
#  'LMR_лимфоциты_абс/моноциты_абс',
#  'SII_тромбоциты*нейтрофилы_абс_/_лимфоциты_абс',
#  'ELR_эозинофилы_абс/лимфоциты_абс',
#  'ELR_%',
#  'ENR_эозин_абс/нейтрофилы_абс',
#  'BLR_базофилы_абс/лимфоциты_абс',
#  'SIRI_NxM_/L',
#  'PIV_or_AISI_NxMxPLT_/L',
#  'GLR_глюкоза_мг/дл_/_лимф_абс',
#  'FLR_fibr/L_abs',
#  'RLR_RDW/_lymph_abs',
#  'MPV/PC_MPV/_PLT',
#  'Глюкоза_в_мг/дл',
#  'Фибриноген',
#  'Эозинофилы_%_b',
#  'Палочкоядерные_нейтрофилы_%_b',
#  'Cегментоядерные_нейтрофилы_%_b',
#  'Лимфоциты_%_b',
#  'Моноциты_%_b',
#  'Общий_белок_b',
#  'Глюкоза_b',
#  'АСАТ_b',
#  'АЛАТ_b',
#  'Билирубин_общий_b',
#  'Холестерин_общий_b',
#  'Триглицериды_b',
#  'Креатинин_b',
#  'Мочевина_b',
#  'ЛДГ_b',
#  'КФК_b',
#  'КФК-МВ_b',
#  'ПТИ_b',
#  'МНО_b',
#  'ТВ_b',
#  'АПТВ_b',
#  'Продолжительность_операции',
#  'Экстренная_операция_ИБ_Новый',
#  'Вид_операции_ИБ_Новый',
#  'повторные_операции',
#  'Тип_первой_операции_БД',
#  'Тип_повторной_операции',
#  'Количество_дней_в_реанимации',
#  'Apache_II',
#  'GRACE_Общее',
#  'GRACE_Общее_gt_140',
#  'интегрилин_эптифибатид_коромакс_агграстат',
#  'Рост',
#  'Вес',
#  'Индекс_массы_тела',
#  'Экстракардиальная_артериопатия',
#  'Плохая_мобильность',
#  'Открытая_перация_на_сердце_в_анамнезе',
#  'Срочность',
#  'Систолическое_АД_b',
#  'Диастолического_АД_b',
#  'ЧСС_b',
#  'САД_a',
#  'ЧСС_а',
#  'P',
#  'PQ',
#  'QRS',
#  'QT',
#  'RR',
#  'Лейкоциты_a',
#  'Нейтрофилы_абсолютное_значение_a',
#  'Лимфоциты_абсолютное_значение_a',
#  'Моноциты_абсолютное_значение_a',
#  'Эозинофилы_абсолютное_значение_a',
#  'Базофилы_абсолютное_значение_a',
#  'Эр_a',
#  'Hb_a',
#  'Гематокрит_a',
#  'Тромбоциты_a',
#  'СОЭ_a',
#  'Эозинофилы_%_a',
#  'Палочкоядерные_нейтрофилы_%_a',
#  'Cегментоядерные_нейтрофилы_%_a',
#  'Лимфоциты_%_a',
#  'Моноциты_%_a',
#  'Миелоциты_%_a',
#  'Общий_белок_a',
#  'Глюкоза_a',
#  'АСАТ_a',
#  'АЛАТ_a',
#  'Билирубин_общий_a',
#  'Холестерин_общий_a',
#  'Триглицериды_a',
#  'Креатинин_a',
#  'Мочевина_a',
#  'ЛДГ_a',
#  'КФК_a',
#  'КФК-МВ_a',
#  'ПТИ_a',
#  'МНО_a',
#  'ФБГ_a',
#  'ТВ_a',
#  'АПТВ_a',
#  'Сопутствующие1',
#  'Сопутствующие2',
#  'eGFR_a',
#  'Креатинин',
#  'СКФ',
#  'Тропонин_1_b',
#  'Тропонин_1_gt_0.1_b',
#  'Тропонин_1_gt_0.1_a',
#  'Тропонин_1',
#  'Тропонин_1_gt_0.1',
#  'Smoking',
#  'Протокол_коронарографии',
#  'Аортальный_стеноз_Градиент',
#  'Аортальный_стеноз_Заключение',
#  'ХОБЛ_Новый_столбец',
#  'Коррекция_А-В_блокады',
#  'Исход_А-В_блокады',
#  'Начало_А-В_блокады_До/после_ЧКВ',
#  'А-В_блокада',
#  'Стенокардия_в_диагнозе_при_поступлении',
#  'ПИКС_в_диагнозе_при_поступлении',
#  'Инфаркт-зависимая_артерия_Огригированная',
#  'Инфаркт-зависимая_артерия_Огригированная_2',
#  'Ишемический_инсульт_Выгрузка_из_ИБ_-_временный_столбец',
#  'Геморрагический_инсульт_Выгрузка_из_ИБ_-_временный_столбец',
#  'Инсульт_Выгрузка_из_ИБ_-_временный_столбец',
#  'SpO2',
#  'Курит',
#  'GRACE_Общее_gt_156',
#  'Отек_легких_b',
#  'Отек_легких_a',
#  'Отек_легких',
#  'Медицинская_помощь_оказана_за_первые_4_часа',
#  'Гипертоническая_болезнь',
#  'ФВ_lt_40',
#  'CADILLAC',
#  'РЕКОРД',
#  'PAMI',
#  'TIMI_Летальность',
#  'CADILLAC_Низкий_риск',
#  'CADILLAC_Средний_риск',
#  'CADILLAC_Высокий_риск',
#  'РЕКОРД_Низкий_риск',
#  'РЕКОРД_Высокий_риск',
#  'GRACE_Низкий_риск',
#  'GRACE_Средний_риск',
#  'GRACE_Высокий_риск',
#  'TIMI_Летальность_Низкий_риск',
#  'TIMI_Летальность_Средний_риск',
#  'TIMI_Летальность_Высокий_риск',
#  'PAMI_Низкий_риск',
#  'PAMI_Средний_риск',
#  'PAMI_Высокий_риск',
#  'Время_ЧКВ',
#  'А-В_блокаДа_Новый',
#  'А-В_блокада_степень',
#  'Часов_до_введения_первого_антибиотика',
#  'Часов_в_ОРИТ_ДО_развития_SOFA_8',
#  'Часов_в_ОРИТ_ПОСЛЕ_развития_SOFA_8',
#  'Максимальный_прокальцитонин_за_сутки_до_развития_SOFA_8',
#  'Максимальный_ЛАКТАТ_артерия_за_сутки_до_развития_SOFA_8',
#  'Максимальный_ЛАКТАТ_вена_за_сутки_до_развития_SOFA_8',
#  'Максимальный_ЛАКТАТ_артерия_за_сутки_после_развития_SOFA_8',
#  'Максимальный_ЛАКТАТ_вена_за_сутки_после_развития_SOFA_8',
#  'SOFA_первый_раз_больше_или_равна_8_баллам',
#  'SOFA_до_развития_8_и_более_баллов',
#  'Используемый_антибиотик_ДО_развития_SOFA_8_и_более',
#  'Левофлоксацин_антибиотик_ДО_развития_SOFA_8_и_более',
#  'Линезолид_антибиотик_ДО_развития_SOFA_8_и_более',
#  'Меропенем_антибиотик_ДО_развития_SOFA_8_и_более',
#  'Метронидазол_антибиотик_ДО_развития_SOFA_8_и_более',
#  'Моксифлоксацин_антибиотик_ДО_развития_SOFA_8_и_более',
#  'Нифуроксазид_антибиотик_ДО_развития_SOFA_8_и_более',
#  'Фосфомицин_антибиотик_ДО_развития_SOFA_8_и_более',
#  'Цефазолин_антибиотик_ДО_развития_SOFA_8_и_более',
#  'Сульбактам_антибиотик_ДО_развития_SOFA_8_и_более',
#  'Цефоперазон_антибиотик_ДО_развития_SOFA_8_и_более',
#  'Цефтриаксон_антибиотик_ДО_развития_SOFA_8_и_более',
#  'Количество_часов_применения_антибиотика_ДО_развития_SOFA_8_и_более',
#  'Антибиотик_после_развития_SOFA_8_и_более',
#  'Моксифлоксацин_после_развития_SOFA_8_и_более',
#  'Левофлоксацин_после_развития_SOFA_8_и_более',
#  'Азитромицин_после_развития_SOFA_8_и_более',
#  'Линезолид_после_развития_SOFA_8_и_более',
#  'Меропенем_после_развития_SOFA_8_и_более',
#  'Метронидазол_после_развития_SOFA_8_и_более',
#  'Нифуроксазид_после_развития_SOFA_8_и_более',
#  'Фосфомицин_после_развития_SOFA_8_и_более',
#  'Цефазолин_после_развития_SOFA_8_и_более',
#  'Сульбактам_после_развития_SOFA_8_и_более',
#  'Цефепим_после_развития_SOFA_8_и_более',
#  'Цефтриаксон_после_развития_SOFA_8_и_более',
#  'Через_сколько_часов_после_развития_SOFA_8_и_более_был_введен_антибиотик',
#  'APACHE_сутки_до_развития_SOFA_8_и_более',
#  'APACHE_сутки_ПОСЛЕ_развития_SOFA_8_и_более',
#  'АД_среднее_за_сутки_до_развития_SOFA_8',
#  'Среднее_АД_1_сутки_в_орит',
#  'Минимальное_АД_1_сут',
#  'Среднее_АД_3_сутки_в_орит',
#  'Минимальное_АД_3_сут',
#  'Макс_АД_3_сут',
#  'Среднее_АД_7_сутки_в_орит',
#  'Минимальное_АД_7_сут',
#  'Макс_АД_7_сут',
#  'Среднее_ЧСС_1_сутки',
#  'Мин_ЧСС_1_сутки',
#  'Максимальное_ЧСС_1_сутки',
#  'Среднее_ЧСС_3_сутки',
#  'Мин_ЧСС_3_сутки',
#  'Максимальное_ЧСС_3_сутки',
#  'Среднее_ЧСС_7_сутки',
#  'Мин_ЧСС_7_сутки',
#  'Максимальное_ЧСС_7_сутки',
#  'Лейкоциты_больше_9_до_назначения_аб',
#  'ИВЛ',
#  'Вазопрессорная_поддержка',
#  'Адреналин',
#  'Добутамин',
#  'Допмин',
#  'Норадреналин',
#  'Левосимендан',
#  'Мезатон',
#  'Max_Aдреналин',
#  'Max_Добутамин',
#  'Max_Допмин',
#  'Max_Норадреналин',
#  'Max_Мезатона',
#  'UA_нестабильная_стенокардия',
#  'Синдромный_диагноз',
#  'killip',
#  'Натрий_Na_b',
#  'Калий_K_b',
#  'Хлор_Cl_b',
#  'Кальций_ионизированный_Ca+_b',
#  'Натрий_Na_a',
#  'Калий_K_a',
#  'Хлор_Cl_a',
#  'Кальций_ионизированный_Ca+_a',
#  'Натрий_Na',
#  'Калий_K',
#  'Хлор_Cl',
#  'Кальций_ионизированный_Ca+',
#  'pHARTmin_b',
#  'pHARTmin_a',
#  'pHARTmin',
#  'pHARTmax_b',
#  'pHARTmax_a',
#  'pHARTmax',
#  'pO2ARTmin_b',
#  'pO2ARTmin_a',
#  'pO2ARTmin',
#  'pO2ARTmax_b',
#  'pO2ARTmax_a',
#  'pO2ARTmax',
#  'pCO2min_b',
#  'pCO2min_a',
#  'pCO2min',
#  'pCO2max_b',
#  'pCO2max_a',
#  'pCO2max',
#  'SaO2min_b',
#  'SaO2min_a',
#  'SaO2min',
#  'SaO2max_b',
#  'SaO2max_a',
#  'SaO2max',
#  'LACTartMin_b',
#  'LACTartMin_a',
#  'LACTartMin',
#  'LACTartMax_b',
#  'LACTartMax_a',
#  'LACTartMax',
#  'BEArtMin_b',
#  'BEArtMin_a',
#  'BEArtMin',
#  'BEArtMax_b',
#  'BEArtMax_a',
#  'BEArtMax',
#  'HCO3ArtMin_b',
#  'HCO3ArtMin_a',
#  'HCO3ArtMin',
#  'HCO3ArtMax_b',
#  'HCO3ArtMax_a',
#  'HCO3ArtMax',
#  'PHVenMin_b',
#  'PHVenMin_a',
#  'PHVenMin',
#  'PHVenMax_b',
#  'PHVenMax_a',
#  'PHVenMax',
#  'PO2VenMin_b',
#  'PO2VenMin_a',
#  'PO2VenMin',
#  'PO2VenMax_b',
#  'PO2VenMax_a',
#  'PO2VenMax',
#  'PCO2VenMin_b',
#  'PCO2VenMin_a',
#  'PCO2VenMin',
#  'PCO2VenMax_b',
#  'PCO2VenMax_a',
#  'PCO2VenMax',
#  'ScvO2Min_b',
#  'ScvO2Min_a',
#  'ScvO2Min',
#  'ScvO2Max_b',
#  'ScvO2Max_a',
#  'ScvO2Max',
#  'LactVenMin_b',
#  'LactVenMin_a',
#  'LactVenMin',
#  'LactVenMax_b',
#  'LactVenMax_a',
#  'LactVenMax',
#  'BEVenMin_b',
#  'BEVenMin_a',
#  'BEVenMin',
#  'BEVenMax_b',
#  'BEVenMax_a',
#  'BEVenMax',
#  'HCO3VenMin_b',
#  'HCO3VenMin_a',
#  'HCO3VenMin',
#  'HCO3VenMax_b',
#  'HCO3VenMax_a',
#  'HCO3VenMax',
#  'BNP_b',
#  'BNP_a',
#  'BNP']

# %%
print("\n=== СРАВНЕНИЕ МЕТОДОВ ===")
analyzer.compare_feature_selection_methods()
# Out:
# === СРАВНЕНИЕ МЕТОДОВ ===

# %%
print("\n=== ПОИСК ОПТИМАЛЬНОГО ПОРОГА ===")
best_threshold, _ = analyzer.find_optimal_threshold(method='forward')
# Out:
# === ПОИСК ОПТИМАЛЬНОГО ПОРОГА ===
# === Оптимальные пороги (forward, 13 признаков) ===
# По Balanced Accuracy score: 0.5000 (F1=0.9203)
# По Youden's J: 0.5012

# %%
print("\n=== ПОИСК ОПТИМАЛЬНОГО ПОРОГА ===")
best_threshold, _ = analyzer.find_optimal_threshold(method='backward')
# Out:
# === ПОИСК ОПТИМАЛЬНОГО ПОРОГА ===
# === Оптимальные пороги (backward, 414 признаков) ===
# По Balanced Accuracy score: 0.1700 (F1=0.9074)
# По Youden's J: 0.0786

# %%
print("\n=== ВИЗУАЛИЗАЦИЯ РАСПРЕДЕЛЕНИЯ ВЕРОЯТНОСТЕЙ ===")
analyzer.visualize_probability_distribution(method='forward')
# Out:
# === ВИЗУАЛИЗАЦИЯ РАСПРЕДЕЛЕНИЯ ВЕРОЯТНОСТЕЙ ===

# %%
print("\n=== ВИЗУАЛИЗАЦИЯ РАСПРЕДЕЛЕНИЯ ВЕРОЯТНОСТЕЙ ===")
analyzer.visualize_probability_distribution(method='backward')
# Out:
# === ВИЗУАЛИЗАЦИЯ РАСПРЕДЕЛЕНИЯ ВЕРОЯТНОСТЕЙ ===

# %%
# Получение лучших признакей из всех комбинаций
print("\n=== ЛУЧШИЕ ПРИЗНАКИ ИЗ ВСЕХ КОМБИНАЦИЙ ===")
best_forward_features, best_forward_result = analyzer.get_best_features(method='forward')
best_backward_features, best_backward_result = analyzer.get_best_features(method='backward')
# Out:
# === ЛУЧШИЕ ПРИЗНАКИ ИЗ ВСЕХ КОМБИНАЦИЙ ===
# === Лучшие признаки (forward) ===
# Количество признаков: 13
# Лучшая f1: 0.4407
# Признаки: ['Мочевина_a', 'Синдромный_диагноз', 'ХСН_стадия', 'GRACE_Высокий_риск', 'BLR_базофилы_абс/лимфоциты_абс', 'ФВ_lt_40', 'MKB', 'ЧСС_b', 'Натрий_Na_a', 'Часов_до_введения_первого_антибиотика', 'Калий', 'повторные_операции', 'Курит']
#
# Важность признаков:
#   Мочевина_a: 0.1974
#   Синдромный_диагноз: 0.1498
#   ФВ_lt_40: 0.1481
#   GRACE_Высокий_риск: 0.0835
#   ХСН_стадия: 0.0791
#   ЧСС_b: 0.0708
#   Натрий_Na_a: 0.0626
#   MKB: 0.0570
#   BLR_базофилы_абс/лимфоциты_абс: 0.0466
#   Курит: 0.0392
#   повторные_операции: 0.0271
#   Калий: 0.0257
#   Часов_до_введения_первого_антибиотика: 0.0133
# === Лучшие признаки (backward) ===
# Количество признаков: 414
# Лучшая f1: 0.6977
# Признаки: ['Age', 'Sex', 'STEMI', 'ЧКВ', 'Вид_STEMI', 'Инфаркт-зависимая_артерия', 'Поражение_ствола', 'Количество_пораженных_сосудов_Syntax', 'Количество_пораженных_сосудов_Значимость', 'TIMI', 'Инфаркт_миокарда_в_анамнезе_lt_3', 'Инфаркт_миокарда_в_анамнезе_gt_3', 'Инфаркт_миокарда_со_стентированием_в_анамнезе', 'ОНМК_иш_в_анамнезе', 'ОНМК_гем_в_анамнезе', 'Стентирование_в_анамнезе', 'Тромболизис', 'Форма_ФП', 'Калий', 'Дилатация_предсердий', 'ФП_b_после_чкв', 'ФП_a_в_анамнезе', 'ФП_при_окс_до_чкв', 'ФП_постоянная_форма', 'ФЖ', 'Пробежки_ЖТ', 'Рецидивирующая_ЖТ', 'MKB', 'Класс_ОСН_по_Killip', 'ХСН_стадия', 'ГБ_стадия', 'ГБ_риск', 'АГ', 'Стенокардия_ИБ', 'Стенокардия_форма_ИБ', 'Стенокардия_ФК_ИБ', 'СД', 'ХБП', 'ЯБ', 'МКБ', 'ЖКБ', 'ФВ_ЛЖ_b', 'ФВ_ЛЖ', 'EDV', 'МЖП', 'ЗСЛЖ', 'ПСПЖ', 'СДЛА', 'Размер_правого_желудочка', 'Стеноз_аортального_клапана_степень', 'Недостаточность_аортального_клапана_степень', 'Стеноз_митрального_клапана_степень', 'Недостаточность_митрального_клапана_степень', 'Недостаточность_трикуспидального_клапана_степень', 'НПВ', 'НПВ_диаметр', 'La1', 'La2', 'Ra1', 'Ra2', 'Гематокрит', 'Гемоглобин', 'Эритроциты', 'Лейкоциты', 'Тромбоциты', 'Нейтрофилы_абсолютное_значение', 'Нейтрофилы_относительное_значение', 'Лимфоциты_абсолютное_значение', 'Лимфоциты_относительное_значение', 'Моноциты_абсолютное_значение', 'Моноциты_относительное_значение', 'Эозинофилы_абсолютное_значение', 'Эозинофилы_относительное_значение', 'Базофилы_абсолютное_значение', 'Базофилы_относительное_значение', 'Сумма_всех_лейкоцитов', 'Средний_объем_эритроцита', 'Среднее_содержание_гемоглобина_в_эритроците', 'Ср_концентрация_гемоглобина_в_эритроците', 'Распределение_эритроцитов_по_объему_RDW-CV', 'Распределение_эритроцитов_по_объему_RDW-SD', 'Расчетная_ширина_распределения_тромбоцитов', 'Тромбокрит', 'Коэффициент_крупных_тромбоцитов', 'СОЭ', 'С-реактивный_белок', 'PLR_тромбоциты/лимфоциты_абс_61-239', 'MLR_моноциты/лимфоциты', 'LMR_лимфоциты_абс/моноциты_абс', 'SII_тромбоциты*нейтрофилы_абс_/_лимфоциты_абс', 'ELR_эозинофилы_абс/лимфоциты_абс', 'ELR_%', 'ENR_эозин_абс/нейтрофилы_абс', 'BLR_базофилы_абс/лимфоциты_абс', 'SIRI_NxM_/L', 'PIV_or_AISI_NxMxPLT_/L', 'GLR_глюкоза_мг/дл_/_лимф_абс', 'FLR_fibr/L_abs', 'RLR_RDW/_lymph_abs', 'MPV/PC_MPV/_PLT', 'Глюкоза_в_мг/дл', 'Фибриноген', 'Эозинофилы_%_b', 'Палочкоядерные_нейтрофилы_%_b', 'Cегментоядерные_нейтрофилы_%_b', 'Лимфоциты_%_b', 'Моноциты_%_b', 'Общий_белок_b', 'Глюкоза_b', 'АСАТ_b', 'АЛАТ_b', 'Билирубин_общий_b', 'Холестерин_общий_b', 'Триглицериды_b', 'Креатинин_b', 'Мочевина_b', 'ЛДГ_b', 'КФК_b', 'КФК-МВ_b', 'ПТИ_b', 'МНО_b', 'ТВ_b', 'АПТВ_b', 'Продолжительность_операции', 'Экстренная_операция_ИБ_Новый', 'Вид_операции_ИБ_Новый', 'повторные_операции', 'Тип_первой_операции_БД', 'Тип_повторной_операции', 'Количество_дней_в_реанимации', 'Apache_II', 'GRACE_Общее', 'GRACE_Общее_gt_140', 'интегрилин_эптифибатид_коромакс_агграстат', 'Рост', 'Вес', 'Индекс_массы_тела', 'Экстракардиальная_артериопатия', 'Плохая_мобильность', 'Открытая_перация_на_сердце_в_анамнезе', 'Срочность', 'Систолическое_АД_b', 'Диастолического_АД_b', 'ЧСС_b', 'САД_a', 'ЧСС_а', 'P', 'PQ', 'QRS', 'QT', 'RR', 'Лейкоциты_a', 'Нейтрофилы_абсолютное_значение_a', 'Лимфоциты_абсолютное_значение_a', 'Моноциты_абсолютное_значение_a', 'Эозинофилы_абсолютное_значение_a', 'Базофилы_абсолютное_значение_a', 'Эр_a', 'Hb_a', 'Гематокрит_a', 'Тромбоциты_a', 'СОЭ_a', 'Эозинофилы_%_a', 'Палочкоядерные_нейтрофилы_%_a', 'Cегментоядерные_нейтрофилы_%_a', 'Лимфоциты_%_a', 'Моноциты_%_a', 'Миелоциты_%_a', 'Общий_белок_a', 'Глюкоза_a', 'АСАТ_a', 'АЛАТ_a', 'Билирубин_общий_a', 'Холестерин_общий_a', 'Триглицериды_a', 'Креатинин_a', 'Мочевина_a', 'ЛДГ_a', 'КФК_a', 'КФК-МВ_a', 'ПТИ_a', 'МНО_a', 'ФБГ_a', 'ТВ_a', 'АПТВ_a', 'Сопутствующие1', 'Сопутствующие2', 'eGFR_a', 'Креатинин', 'СКФ', 'Тропонин_1_b', 'Тропонин_1_gt_0.1_b', 'Тропонин_1_gt_0.1_a', 'Тропонин_1', 'Тропонин_1_gt_0.1', 'Smoking', 'Протокол_коронарографии', 'Аортальный_стеноз_Градиент', 'Аортальный_с ...
#
# Важность признаков:
#   Отек_легких: 0.2179
#   Синдромный_диагноз: 0.0507
#   Нейтрофилы_относительное_значение: 0.0327
#   Мочевина_a: 0.0286
#   Вид_операции_ИБ_Новый: 0.0187
#   STEMI: 0.0184
#   CADILLAC_Низкий_риск: 0.0164
#   Нейтрофилы_абсолютное_значение_a: 0.0130
#   GRACE_Низкий_риск: 0.0123
#   Нейтрофилы_абсолютное_значение: 0.0106
#   Эозинофилы_относительное_значение: 0.0104
#   Max_Допмин: 0.0103
#   Вид_STEMI: 0.0098
#   Тропонин_1_gt_0.1_a: 0.0097
#   Отек_легких_a: 0.0093
#   СДЛА: 0.0093
#   ФВ_lt_40: 0.0089
#   SIRI_NxM_/L: 0.0083
#   Креатинин: 0.0082
#   Apache_II: 0.0077
#   RLR_RDW/_lymph_abs: 0.0072
#   PLR_тромбоциты/лимфоциты_абс_61-239: 0.0070
#   ЧСС_а: 0.0067
#   LactVenMax_a: 0.0066
#   ЗСЛЖ: 0.0066
#   Хлор_Cl_a: 0.0066
#   Гематокрит_a: 0.0064
#   Количество_пораженных_сосудов_Значимость: 0.0064
#   ФП_при_окс_до_чкв: 0.0063
#   Калий_K_a: 0.0063
#   Hb_a: 0.0062
#   ЛДГ_a: 0.0060
#   Натрий_Na: 0.0059
#   МНО_a: 0.0057
#   ФВ_ЛЖ: 0.0054
#   Триглицериды_a: 0.0054
#   pO2ARTmax_a: 0.0053
#   АГ: 0.0053
#   Моноциты_%_b: 0.0053
#   Размер_правого_желудочка: 0.0052
#   Эозинофилы_абсолютное_значение_a: 0.0051
#   Глюкоза_a: 0.0051
#   Макс_АД_3_сут: 0.0049
#   АЛАТ_a: 0.0049
#   Вес: 0.0047
#   Диастолического_АД_b: 0.0046
#   Натрий_Na_a: 0.0046
#   Фибриноген: 0.0044
#   Базофилы_относительное_значение: 0.0044
#   Стенокардия_ИБ: 0.0041
#   ЛДГ_b: 0.0041
#   Калий_K: 0.0040
#   Экстренная_операция_ИБ_Новый: 0.0039
#   CADILLAC: 0.0038
#   Ra1: 0.0037
#   LACTartMax: 0.0037
#   ЧСС_b: 0.0037
#   Стенокардия_в_диагнозе_при_поступлении: 0.0035
#   Сопутствующие1: 0.0035
#   Моноциты_относительное_значение: 0.0035
#   Гемоглобин: 0.0034
#   САД_a: 0.0034
#   MPV/PC_MPV/_PLT: 0.0034
#   Общий_белок_a: 0.0034
#   PO2VenMax_a: 0.0033
#   АСАТ_a: 0.0033
#   Среднее_содержание_гемоглобина_в_эритроците: 0.0033
#   TIMI_Летальность: 0.0033
#   Распределение_эритроцитов_по_объему_RDW-CV: 0.0033
#   pHARTmax_a: 0.0032
#   СКФ: 0.0032
#   Коэффициент_крупных_тромбоцитов: 0.0032
#   КФК-МВ_b: 0.0031
#   Креатинин_a: 0.0031
#   ФБГ_a: 0.0031
#   Лимфоциты_абсолютное_значение_a: 0.0030
#   Распределение_эритроцитов_по_объему_RDW-SD: 0.0030
#   Креатинин_b: 0.0029
#   LactVenMin_a: 0.0029
#   SOFA_до_развития_8_и_более_баллов: 0.0029
#   PCO2VenMax_a: 0.0029
#   LACTartMax_a: 0.0029
#   Отек_легких_b: 0.0028
#   Максимальный_ЛАКТАТ_артерия_за_сутки_до_развития_SOFA_8: 0.0028
#   PAMI: 0.0028
#   MKB: 0.0027
#   SII_тромбоциты*нейтрофилы_абс_/_лимфоциты_абс: 0.0027
#   Лейкоциты: 0.0027
#   Хлор_Cl: 0.0026
#   QT: 0.0026
#   Ra2: 0.0026
#   С-реактивный_белок: 0.0025
#   PIV_or_AISI_NxMxPLT_/L: 0.0025
#   Продолжительность_операции: 0.0025
#   Тропонин_1_gt_0.1: 0.0025
#   pO2ARTmin_a: 0.0024
#   LACTartMin_a: 0.0024
#   Лимфоциты_%_a: 0.0024
#   Max_Aдреналин: 0.0024
#   PHVenMin_a: 0.0024
#   Моноциты_абсолютное_значение: 0.0023
#   Max_Норадреналин: 0.0023
#   HCO3ArtMin_b: 0.0023
#   ELR_%: 0.0022
#   BLR_базофилы_абс/лимфоциты_абс: 0.0022
#   ТВ_a: 0.0022
#   pCO2min_a: 0.0022
#   ПТИ_b: 0.0021
#   Средний_объем_эритроцита: 0.0021
#   Лимфоциты_относительное_значение: 0.0021
#   Расчетная_ширина_распределения_тромбоцитов: 0.0021
#   Мин_ЧСС_1_сутки: 0.0021
#   ПТИ_a: 0.0021
#   Эритроциты: 0.0021
#   Гематокрит: 0.0021
#   Лимфоциты_абсолютное_значение: 0.0021
#   Тромбоциты_a: 0.0021
#   APACHE_сутки_до_развития_SOFA_8_и_более: 0.0020
#   ХОБЛ_Новый_столбец: 0.0020
#   Глюкоза_b: 0.0020
#   LMR_лимфоциты_абс/моноциты_абс: 0.0020
#   Рост: 0.0020
#   ScvO2Max_a: 0.0020
#   LactVenMax_b: 0.0020
#   Норадреналин: 0.0020
#   Моноциты_%_a: 0.0019
#   LACTartMin_b: 0.0019
#   APACHE_сутки_ПОСЛЕ_развития_SOFA_8_и_более: 0.0019
#   Форма_ФП: 0.0019
#   повторные_операции: 0.0018
#   ENR_эозин_абс/нейтрофилы_абс: 0.0018
#   Эозинофилы_абсолютное_значение: 0.0018
#   Базофилы_абсолютное_значение: 0.0018
#   Лейкоциты_a: 0.0018
#   Количество_дней_в_реанимации: 0.0018
#   Сумма_всех_лейкоцитов: 0.0017
#   Минимальное_АД_7_сут: 0.0017
#   Age: 0.0017
#   Палочкоядерные_нейтрофилы_%_a: 0.0017
#   Тромбокрит: 0.0017
#   Систолическое_АД_b: 0.0017
#   LACTartMax_b: 0.0017
#   BEVenMax: 0.0017
#   SpO2: 0.0017
#   Тропонин_1: 0.0016
#   BEArtMax_a: 0.0016
#   НПВ_диаметр: 0.0016
#   GRACE_Общее: 0.0016
#   TIMI_Летальность_Средний_риск: 0.0016
#   BEArtMin_a: 0.0015
#   Глюкоза_в_мг/дл: 0.0015
#   SaO2max: 0.0015
#   Количество_пораженных_сосудов_Syntax: 0.0015
#   PCO2VenMin: 0.0015
#   ТВ_b: 0.0015
#   SaO2max_b: 0.0015
#   СОЭ: 0.0014
#   АСАТ_b: 0.0014
#   Мочевина_b: 0.0014
#   Класс_ОСН_по_Killip: 0.0013
#   PQ: 0.0013
#   BEVenMin_a: 0.0013
#   TIMI: 0.0013
#   интегрилин_эптифибатид_коромакс_агграстат: 0.0013
#   PHVenMax_a: 0.0013
#   PO2VenMin_a: 0.0013
#   Максимальное_ЧСС_1_сутки: 0.0013
#   Sex: 0.0013
#   RR: 0.0012
#   Калий: 0.0012
#   pO2ARTmin_b: 0.0012
#   РЕКОРД: 0.0012
#   GLR_глюкоза_мг/дл_/_лимф_абс: 0.0012
#   СОЭ_a: 0.0012
#   Часов_в_ОРИТ_ПОСЛЕ_развития_SOFA_8: 0.0011
#   Ср_концентрация_гемоглобина_в_эритроците: 0.0011
#   Протокол_коронарографии: 0.0011
#   Smoking: 0.0011
#   BEArtMax_b: 0.0011
#   HCO3VenMin_a: 0.0011
#   pO2ARTmax_b: 0.0010
#   GRACE_Общее_gt_156: 0.0010
#   La1: 0.0010
#   Минимальное_АД_3_сут: 0.0010
#   PCO2VenMin_a: 0.0010
#   SaO2min_b: 0.0010
#   La2: 0.0010
#   МКБ: 0.0009
#   КФК_b: 0.0009
#   АПТВ_a: 0.0009
#   АПТВ_b: 0.0009
#   КФК-МВ_a: 0.0009
#   Максимальный_ЛАКТАТ_артерия_за_сутки_после_развития_SOFA_8: 0.0009
#   LactVenMax: 0.0009
#   МЖП: 0.0009
#   Инфаркт-зависимая_артерия: 0.0008
#   Среднее_АД_1_сутки_в_орит: 0.0008
#   ELR_эозинофилы_абс/лимфоциты_абс: 0.0008
#   pHARTmin_a: 0.0008
#   Эозинофилы_%_b: 0.0007
#   ОНМК_иш_в_анамнезе: 0.0007
#   ГБ_стадия: 0.0007
#   ФВ_ЛЖ_b: 0.0007
#   SaO2max_a: 0.0007
#   PO2VenMax_b: 0.0007
#   MLR_моноциты/лимфоциты: 0.0006
#   Тромбоциты: 0.0006
#   ГБ_риск: 0.0006
#   Эр_a: 0.0005
#   Триглицериды_b: 0.0005
#   Часов_до_введения_первого_антибиотика: 0.0005
#   Мин_ЧСС_7_сутки: 0.0005
#   Срочность: 0.0004
#   Моноциты_абсолютное_значение_a: 0.0004
#   Общий_белок_b: 0.0004
#   SaO2min_a: 0.0004
#   Билирубин_общий_b: 0.0004
#   pCO2min_b: 0.0003
#   Мин_ЧСС_3_сутки: 0.0003
#   Добутамин: 0.0003
#   Cегментоядерные_нейтрофилы_%_a: 0.0003
#   pHARTmax_b: 0.0003
#   Аортальный_стеноз_Градиент: 0.0003
#   Стенокардия_ФК_ИБ: 0.0003
#   Инфаркт-зависимая_артерия_Огригированная: 0.0002
#   pCO2max_b: 0.0002
#   Среднее_ЧСС_3_сутки: 0.0002
#   Индекс_массы_тела: 0.0002
#   Сопутствующие2: 0.0002
#   Билирубин_общий_a: 0.0002
#   Холестерин_общий_a: 0.0001
#   BEVenMax_b: 0.0001
#   Стенокардия_форма_ИБ: 0.0001
#   Максимальный_ЛАКТАТ_вена_за_сутки_после_развития_SOFA_8: 0.0001
#   Тропонин_1_b: 0.0001
#   Среднее_АД_7_сутки_в_орит: 0.0001
#   Эозинофилы_%_a: 0.0001
#   Тромболизис: 0.0001
#   Среднее_ЧСС_7_сутки: 0.0001
#   ХСН_стадия: 0.0001
#   Инфаркт-зависимая_артерия_Огригированная_2: 0.0001
#   Максимальное_ЧСС_7_сутки: 0.0001
#   Допмин: 0.0000
#   killip: 0.0000
#   Инфаркт_миокарда_в_анамнезе_lt_3: 0.0000
#   ЧКВ: 0.0000
#   Поражение_ствола: 0.0000
#   Инфаркт_миокарда_в_анамнезе_gt_3: 0.0000
#   Инфаркт_миокарда_со_стентированием_в_анамнезе: 0.0000
#   ОНМК_гем_в_анамнезе: 0.0000
#   Стентирование_в_анамнезе: 0.0000
#   Дилатация_предсердий: 0.0000
#   ФП_b_после_чкв: 0.0000
#   ФП_a_в_анамнезе: 0.0000
#   ФП_постоянная_форма: 0.0000
#   ФЖ: 0.0000
#   Пробежки_ЖТ: 0.0000
#   Рецидивирующая_ЖТ: 0.0000
#   СД: 0.0000
#   ХБП: 0.0000
#   ЯБ: 0.0000
#   ЖКБ: 0.0000
#   EDV: 0.0000
#   ПСПЖ: 0.0000
#   Стеноз_аортального_клапана_степень: 0.0000
#   Недостаточность_аортального_клапана_степень: 0.0000
#   Стеноз_митрального_клапана_степень: 0.0000
#   Недостаточность_митрального_клапана_степень: 0.0000
#   Недостаточность_трикуспидального_клапана_степень: 0.0000
#   НПВ: 0.0000
#   FLR_fibr/L_abs: 0.0000
#   Палочкоядерные_нейтрофилы_%_b: 0.0000
#   Cегментоядерные_нейтрофилы_%_b: 0.0000
#   Лимфоциты_%_b: 0.0000
#   АЛАТ_b: 0.0000
#   Холестерин_общий_b: 0.0000
#   МНО_b: 0.0000
#   Тип_первой_операции_БД: 0.0000
#   Тип_повторной_операции: 0.0000
#   GRACE_Общее_gt_140: 0.0000
#   Экстракардиальная_артериопатия: 0.0000
#   Плохая_мобильность: 0.0000
#   Открытая_перация_на_сердце_в_анамнезе: 0.0000
#   P: 0.0000
#   QRS: 0.0000
#   Базофилы_абсолютное_значение_a: 0.0000
#   Миелоциты_%_a: 0.0000
#   КФК_a: 0.0000
#   eGFR_a: 0.0000
#   Тропонин_1_gt_0.1_b: 0.0000
#   Аортальный_стеноз_Заключение: 0.0000
#   Коррекция_А-В_блокады: 0.0000
#   Исход_А-В_блокады: 0.0000
#   Начало_А-В_блокады_До/после_ЧКВ: 0.0000
#   А-В_блокада: 0.0000
#   ПИКС_в_диагнозе_при_поступлении: 0.0000
#   Ишемический_инсульт_Выгрузка_из_ИБ_-_временный_столбец: 0.0000
#   Геморрагический_инсульт_Выгрузка_из_ИБ_-_временный_столбец: 0.0000
#   Инсульт_Выгрузка_из_ИБ_-_временный_столбец: 0.0000
#   Курит: 0.0000
#   Медицинская_помощь_оказана_за_первые_4_часа: 0.0000
#   Гипертоническая_болезнь: 0.0000
#   CADILLAC_Средний_риск: 0.0000
#   CADILLAC_Высокий_риск: 0.0000
#   РЕКОРД_Низкий_риск: 0.0000
#   РЕКОРД_Высокий_риск: 0.0000
#   GRACE_Средний_риск: 0.0000
#   GRACE_Высокий_риск: 0.0000
#   TIMI_Летальность_Низкий_риск: 0.0000
#   TIMI_Летальность_Высокий_риск: 0.0000
#   PAMI_Низкий_риск: 0.0000
#   PAMI_Средний_риск: 0.0000
#   PAMI_Высокий_риск: 0.0000
#   Время_ЧКВ: 0.0000
#   А-В_блокаДа_Новый: 0.0000
#   А-В_блокада_степень: 0.0000
#   Часов_в_ОРИТ_ДО_развития_SOFA_8: 0.0000
#   Максимальный_прокальцитонин_за_сутки_до_развития_SOFA_8: 0.0000
#   Максимальный_ЛАКТАТ_вена_за_сутки_до_развития_SOFA_8: 0.0000
#   SOFA_первый_раз_больше_или_равна_8_баллам: 0.0000
#   Используемый_антибиотик_ДО_развития_SOFA_8_и_более: 0.0000
#   Левофлоксацин_антибиотик_ДО_развития_SOFA_8_и_более: 0.0000
#   Линезолид_антибиотик_ДО_развития_SOFA_8_и_более: 0.0000
#   Меропенем_антибиотик_ДО_развития_SOFA_8_и_более: 0.0000
#   Метронидазол_антибиотик_ДО_развития_SOFA_8_и_более: 0.0000
#   Моксифлоксацин_антибиотик_ДО_развития_SOFA_8_и_более: 0.0000
#   Нифуроксазид_антибиотик_ДО_развития_SOFA_8_и_более: 0.0000
#   Фосфомицин_антибиотик_ДО_развития_SOFA_8_и_более: 0.0000
#   Цефазолин_антибиотик_ДО_развития_SOFA_8_и_более: 0.0000
#   Сульбактам_антибиотик_ДО_развития_SOFA_8_и_более: 0.0000
#   Цефоперазон_антибиотик_ДО_развития_SOFA_8_и_более: 0.0000
#   Цефтриаксон_антибиотик_ДО_развития_SOFA_8_и_более: 0.0000
#   Количество_часов_применения_антибиотика_ДО_развития_SOFA_8_и_более: 0.0000
#   Антибиотик_после_развития_SOFA_8_и_более: 0.0000
#   Моксифлоксацин_после_развития_SOFA_8_и_более: 0.0000
#   Левофлоксацин_после_развития_SOFA_8_и_более: 0.0000
#   Азитромицин_после_развития_SOFA_8_и_более: 0.0000
#   Линезолид_после_развития_SOFA_8_и_более: 0.0000
#   Меропенем_после_развития_SOFA_8_и_более: 0.0000
#   Метронидазол_после_развития_SOFA_8_и_более: 0.0000
#   Нифуроксазид_после_развития_SOFA_8_и_более: 0.0000
#   Фосфомицин_после_развития_SOFA_8_и_более: 0.0000
#   Цефазолин_после_развития_SOFA_8_и_более: 0.0000
#   Сульбактам_после_развития_SOFA_8_и_более: 0.0000
#   Цефепим_после_развития_SOFA_8_и_более: 0.0000
#   Цефтриаксон_после_развития_SOFA_8_и_более: 0.0000
#   Через_сколько_часов_после_развития_SOFA_8_и_более_был_введен_антибиотик: 0.0000
#   АД_среднее_за_сутки_до_развития_SOFA_8: 0.0000
#   Минимальное_АД_1_сут: 0.0000
#   Среднее_АД_3_сутки_в_орит: 0.0000
#   Макс_АД_7_сут: 0.0000
#   Среднее_ЧСС_1_сутки: 0.0000
#   Максимальное_ЧСС_3_сутки: 0.0000
#   Лейкоциты_больше_9_до_назначения_аб: 0.0000
#   ИВЛ: 0.0000
#   Вазопрессорная_поддержка: 0.0000
#   Адреналин: 0.0000
#   Левосимендан: 0.0000
#   Мезатон: 0.0000
#   Max_Добутамин: 0.0000
#   Max_Мезатона: 0.0000
#   UA_нестабильная_стенокардия: 0.0000
#   Натрий_Na_b: 0.0000
#   Калий_K_b: 0.0000
#   Хлор_Cl_b: 0.0000
#   Кальций_ионизированный_Ca+_b: 0.0000
#   Кальций_ионизированный_Ca+_a: 0.0000
#   Кальций_ионизированный_Ca+: 0.0000
#   pHARTmin_b: 0.0000
#   pHARTmin: 0.0000
#   pHARTmax: 0.0000
#   pO2ARTmin: 0.0000
#   pO2ARTmax: 0.0000
#   pCO2min: 0.0000
#   pCO2max_a: 0.0000
#   pCO2max: 0.0000
#   SaO2min: 0.0000
#   LACTartMin: 0.0000
#   BEArtMin_b: 0.0000
#   BEArtMin: 0.0000
#   BEArtMax: 0.0000
#   HCO3ArtMin_a: 0.0000
#   HCO3ArtMin: 0.0000
#   HCO3ArtMax_b: 0.0000
#   HCO3ArtMax_a: 0.0000
#   HCO3ArtMax: 0.0000
#   PHVenMin_b: 0.0000
#   PHVenMin: 0.0000
#   PHVenMax_b: 0.0000
#   PHVenMax: 0.0000
#   PO2VenMin_b: 0.0000
#   PO2VenMin: 0.0000
#   PO2VenMax: 0.0000
#   PCO2VenMin_b: 0.0000
#   PCO2VenMax_b: 0.0000
#   PCO2VenMax: 0.0000
#   ScvO2Min_b: 0.0000
#   ScvO2Min_a: 0.0000
#   ScvO2Min: 0.0000
#   ScvO2Max_b: 0.0000
#   ScvO2Max: 0.0000
#   LactVenMin_b: 0.0000
#   LactVenMin: 0.0000
#   BEVenMin_b: 0.0000
#   BEVenMin: 0.0000
#   BEVenMax_a: 0.0000
#   HCO3VenMin_b: 0.0000
#   HCO3VenMin: 0.0000
#   HCO3VenMax_b: 0.0000
#   HCO3VenMax_a: 0.0000
#   HCO3VenMax: 0.0000
#   BNP_b: 0.0000
#   BNP_a: 0.0000
#   BNP: 0.0000

# %%
print("\n=== СОХРАНЕНИЕ РЕЗУЛЬТАТОВ ===")
analyzer.save_results_to_excel('xgb_ba_1.xlsx')
# Out:
# === СОХРАНЕНИЕ РЕЗУЛЬТАТОВ ===
# Результаты успешно сохранены в файл: xgb_ba_1.xlsx

# %%
print("\n=== ЗАКЛЮЧЕНИЕ ===")
print(f"Лучший ROC AUC (Forward): {best_forward_result['metrics']['roc_auc']:.4f} с {len(best_forward_features)} признаками")
print(f"Лучший ROC AUC (Backward): {best_backward_result['metrics']['roc_auc']:.4f} с {len(best_backward_features)} признаками")
print(f"Оптимальный порог для бинарной классификации: {best_threshold:.4f}")
# Out:
# === ЗАКЛЮЧЕНИЕ ===
# Лучший ROC AUC (Forward): 0.9533 с 13 признаками
# Лучший ROC AUC (Backward): 0.9716 с 414 признаками
# Оптимальный порог для бинарной классификации: 0.1700

# %% [markdown]
# # LGB

# %%
# === ВСТАВЬ В ПЕРВУЮ ЯЧЕЙКУ ЛЮБОГО НОУТБУКА ===
import sys, os
os.environ['PYTHONUNBUFFERED'] = '1'
sys.stdout.reconfigure(line_buffering=True) if hasattr(sys.stdout, 'reconfigure') else None
print("✅ Вывод теперь мгновенный!")
# ===========================================
# Out:
# ✅ Вывод теперь мгновенный!

# %%
analyzer = FeatureSelectionAnalyzer(X_clean, y, test_size=0.2, random_state=42)

# %%
print("=== FORWARD SELECTION ===")
forward_features = analyzer.forward_selection(lgb_model, max_features=None, metric='balanced_accuracy')  # ограничим до 10 признакей для демонстрации
# Out:
# === FORWARD SELECTION ===
# Запуск Forward Selection...
#   0%|          | 0/417 [00:00<?, ?it/s]

# %%
print("=== BACKWARD SELECTION ===")
forward_features = analyzer.backward_elimination(lgb_model, max_features=None, metric='balanced_accuracy')  # ограничим до 10 признакей для демонстрации

# %%
1
# Out:
# 1

# %%
print("\n=== СРАВНЕНИЕ МЕТОДОВ ===")
analyzer.compare_feature_selection_methods()
# Out:
# === СРАВНЕНИЕ МЕТОДОВ ===

# %%
print("\n=== BACKWARD ELIMINATION ===")
backward_features = analyzer.backward_elimination(lgb_model, min_features=1, metric='balanced_accuracy')

# %%
print("Hello world")
# Out:
# Hello world

# %%
print("\n=== ПОИСК ОПТИМАЛЬНОГО ПОРОГА ===")
best_threshold, _ = analyzer.find_optimal_threshold(method='forward')
# Out:
# === ПОИСК ОПТИМАЛЬНОГО ПОРОГА ===
# === Оптимальные пороги (forward, 7 признаков) ===
# По Balanced Accuracy score: 0.5000 (F1=0.9065)
# По Youden's J: 0.5082

# %%
print("\n=== ПОИСК ОПТИМАЛЬНОГО ПОРОГА ===")
best_threshold, _ = analyzer.find_optimal_threshold(method='backward')
# Out:
# === ПОИСК ОПТИМАЛЬНОГО ПОРОГА ===
# === Оптимальные пороги (backward, 416 признаков) ===
# По Balanced Accuracy score: 0.1200 (F1=0.9030)
# По Youden's J: 0.0523

# %%
print("\n=== ВИЗУАЛИЗАЦИЯ РАСПРЕДЕЛЕНИЯ ВЕРОЯТНОСТЕЙ ===")
analyzer.visualize_probability_distribution(method='forward')
# Out:
# === ВИЗУАЛИЗАЦИЯ РАСПРЕДЕЛЕНИЯ ВЕРОЯТНОСТЕЙ ===

# %%
print("\n=== ВИЗУАЛИЗАЦИЯ РАСПРЕДЕЛЕНИЯ ВЕРОЯТНОСТЕЙ ===")
analyzer.visualize_probability_distribution(method='backward')
# Out:
# === ВИЗУАЛИЗАЦИЯ РАСПРЕДЕЛЕНИЯ ВЕРОЯТНОСТЕЙ ===

# %%
# Получение лучших признакей из всех комбинаций
print("\n=== ЛУЧШИЕ ПРИЗНАКИ ИЗ ВСЕХ КОМБИНАЦИЙ ===")
best_forward_features, best_forward_result = analyzer.get_best_features(method='forward')
best_backward_features, best_backward_result = analyzer.get_best_features(method='backward')
# Out:
# === ЛУЧШИЕ ПРИЗНАКИ ИЗ ВСЕХ КОМБИНАЦИЙ ===
# === Лучшие признаки (forward) ===
# Количество признаков: 7
# Лучшая f1: 0.3882
# Признаки: ['Мочевина_a', 'Отек_легких_a', 'BLR_базофилы_абс/лимфоциты_абс', 'Экстренная_операция_ИБ_Новый', 'ФВ_lt_40', 'Age', 'Используемый_антибиотик_ДО_развития_SOFA_8_и_более']
#
# Важность признаков:
#   Мочевина_a: 619.0000
#   Age: 466.0000
#   BLR_базофилы_абс/лимфоциты_абс: 408.0000
#   Отек_легких_a: 130.0000
#   Экстренная_операция_ИБ_Новый: 95.0000
#   ФВ_lt_40: 89.0000
#   Используемый_антибиотик_ДО_развития_SOFA_8_и_более: 33.0000
# === Лучшие признаки (backward) ===
# Количество признаков: 416
# Лучшая f1: 0.6716
# Признаки: ['Age', 'Sex', 'STEMI', 'ЧКВ', 'Вид_STEMI', 'Инфаркт-зависимая_артерия', 'Поражение_ствола', 'Количество_пораженных_сосудов_Syntax', 'Количество_пораженных_сосудов_Значимость', 'TIMI', 'Инфаркт_миокарда_в_анамнезе_lt_3', 'Инфаркт_миокарда_в_анамнезе_gt_3', 'Инфаркт_миокарда_со_стентированием_в_анамнезе', 'ОНМК_иш_в_анамнезе', 'ОНМК_гем_в_анамнезе', 'Стентирование_в_анамнезе', 'Тромболизис', 'Форма_ФП', 'Калий', 'Дилатация_предсердий', 'ФП_b_после_чкв', 'ФП_a_в_анамнезе', 'ФП_при_окс_до_чкв', 'ФП_постоянная_форма', 'ФЖ', 'Пробежки_ЖТ', 'Рецидивирующая_ЖТ', 'MKB', 'Класс_ОСН_по_Killip', 'ХСН_стадия', 'ГБ_стадия', 'ГБ_риск', 'АГ', 'Стенокардия_ИБ', 'Стенокардия_форма_ИБ', 'Стенокардия_ФК_ИБ', 'СД', 'ХБП', 'ЯБ', 'МКБ', 'ЖКБ', 'ФВ_ЛЖ_b', 'ФВ_ЛЖ', 'EDV', 'МЖП', 'ЗСЛЖ', 'ПСПЖ', 'СДЛА', 'Размер_правого_желудочка', 'Стеноз_аортального_клапана_степень', 'Недостаточность_аортального_клапана_степень', 'Стеноз_митрального_клапана_степень', 'Недостаточность_митрального_клапана_степень', 'Недостаточность_трикуспидального_клапана_степень', 'НПВ', 'НПВ_диаметр', 'La1', 'La2', 'Ra1', 'Ra2', 'Гематокрит', 'Гемоглобин', 'Эритроциты', 'Лейкоциты', 'Тромбоциты', 'Нейтрофилы_абсолютное_значение', 'Нейтрофилы_относительное_значение', 'Лимфоциты_абсолютное_значение', 'Лимфоциты_относительное_значение', 'Моноциты_абсолютное_значение', 'Моноциты_относительное_значение', 'Эозинофилы_абсолютное_значение', 'Эозинофилы_относительное_значение', 'Базофилы_абсолютное_значение', 'Базофилы_относительное_значение', 'Сумма_всех_лейкоцитов', 'Средний_объем_эритроцита', 'Среднее_содержание_гемоглобина_в_эритроците', 'Ср_концентрация_гемоглобина_в_эритроците', 'Распределение_эритроцитов_по_объему_RDW-CV', 'Распределение_эритроцитов_по_объему_RDW-SD', 'Средний_объем_тромбоцита_MPV', 'Расчетная_ширина_распределения_тромбоцитов', 'Тромбокрит', 'Коэффициент_крупных_тромбоцитов', 'СОЭ', 'С-реактивный_белок', 'PLR_тромбоциты/лимфоциты_абс_61-239', 'MLR_моноциты/лимфоциты', 'LMR_лимфоциты_абс/моноциты_абс', 'SII_тромбоциты*нейтрофилы_абс_/_лимфоциты_абс', 'ELR_эозинофилы_абс/лимфоциты_абс', 'ELR_%', 'ENR_эозин_абс/нейтрофилы_абс', 'BLR_базофилы_абс/лимфоциты_абс', 'SIRI_NxM_/L', 'PIV_or_AISI_NxMxPLT_/L', 'GLR_глюкоза_мг/дл_/_лимф_абс', 'FLR_fibr/L_abs', 'RLR_RDW/_lymph_abs', 'MPV/PC_MPV/_PLT', 'Глюкоза_в_мг/дл', 'Фибриноген', 'Эозинофилы_%_b', 'Палочкоядерные_нейтрофилы_%_b', 'Cегментоядерные_нейтрофилы_%_b', 'Лимфоциты_%_b', 'Моноциты_%_b', 'Общий_белок_b', 'Глюкоза_b', 'АСАТ_b', 'АЛАТ_b', 'Билирубин_общий_b', 'Холестерин_общий_b', 'Триглицериды_b', 'Креатинин_b', 'Мочевина_b', 'ЛДГ_b', 'КФК_b', 'КФК-МВ_b', 'ПТИ_b', 'МНО_b', 'ТВ_b', 'АПТВ_b', 'Продолжительность_операции', 'Экстренная_операция_ИБ_Новый', 'Вид_операции_ИБ_Новый', 'повторные_операции', 'Тип_первой_операции_БД', 'Тип_повторной_операции', 'Количество_дней_в_реанимации', 'Apache_II', 'GRACE_Общее', 'GRACE_Общее_gt_140', 'интегрилин_эптифибатид_коромакс_агграстат', 'Рост', 'Вес', 'Индекс_массы_тела', 'Экстракардиальная_артериопатия', 'Плохая_мобильность', 'Открытая_перация_на_сердце_в_анамнезе', 'Срочность', 'Систолическое_АД_b', 'Диастолического_АД_b', 'ЧСС_b', 'САД_a', 'ЧСС_а', 'P', 'PQ', 'QRS', 'QT', 'RR', 'Лейкоциты_a', 'Нейтрофилы_абсолютное_значение_a', 'Лимфоциты_абсолютное_значение_a', 'Моноциты_абсолютное_значение_a', 'Эозинофилы_абсолютное_значение_a', 'Базофилы_абсолютное_значение_a', 'Эр_a', 'Hb_a', 'Гематокрит_a', 'Тромбоциты_a', 'СОЭ_a', 'Эозинофилы_%_a', 'Палочкоядерные_нейтрофилы_%_a', 'Cегментоядерные_нейтрофилы_%_a', 'Лимфоциты_%_a', 'Миелоциты_%_a', 'Общий_белок_a', 'Глюкоза_a', 'АСАТ_a', 'АЛАТ_a', 'Билирубин_общий_a', 'Холестерин_общий_a', 'Триглицериды_a', 'Креатинин_a', 'Мочевина_a', 'ЛДГ_a', 'КФК_a', 'КФК-МВ_a', 'ПТИ_a', 'МНО_a', 'ФБГ_a', 'ТВ_a', 'АПТВ_a', 'Сопутствующие1', 'Сопутствующие2', 'eGFR_a', 'Креатинин', 'СКФ', 'Тропонин_1_b', 'Тропонин_1_gt_0.1_b', 'Тропонин_1_a', 'Тропонин_1_gt_0.1_a', 'Тропонин_1', 'Тропонин_1_gt_0.1', 'Smoking', 'Протокол_коронарографии', 'Аортальный ...
#
# Важность признаков:
#   Apache_II: 68.0000
#   Нейтрофилы_абсолютное_значение_a: 48.0000
#   Нейтрофилы_относительное_значение: 47.0000
#   Креатинин: 45.0000
#   ФВ_lt_40: 43.0000
#   СДЛА: 42.0000
#   Мочевина_a: 42.0000
#   МНО_a: 41.0000
#   MKB: 37.0000
#   Отек_легких: 36.0000
#   ЧСС_b: 35.0000
#   ФВ_ЛЖ: 33.0000
#   Глюкоза_a: 33.0000
#   Нейтрофилы_абсолютное_значение: 30.0000
#   Размер_правого_желудочка: 28.0000
#   Моноциты_относительное_значение: 25.0000
#   Количество_дней_в_реанимации: 25.0000
#   САД_a: 25.0000
#   ТВ_a: 25.0000
#   Вид_операции_ИБ_Новый: 24.0000
#   Лейкоциты_a: 23.0000
#   La2: 21.0000
#   Ra2: 21.0000
#   Эритроциты: 21.0000
#   Лимфоциты_относительное_значение: 20.0000
#   Эозинофилы_относительное_значение: 20.0000
#   Коэффициент_крупных_тромбоцитов: 20.0000
#   С-реактивный_белок: 20.0000
#   Стенокардия_в_диагнозе_при_поступлении: 20.0000
#   Age: 19.0000
#   СКФ: 19.0000
#   GRACE_Общее: 18.0000
#   Вес: 18.0000
#   Среднее_содержание_гемоглобина_в_эритроците: 17.0000
#   ПТИ_a: 17.0000
#   SpO2: 17.0000
#   Гематокрит: 16.0000
#   Распределение_эритроцитов_по_объему_RDW-SD: 16.0000
#   СОЭ: 16.0000
#   Лимфоциты_абсолютное_значение_a: 15.0000
#   Синдромный_диагноз: 15.0000
#   Натрий_Na_a: 15.0000
#   ЗСЛЖ: 14.0000
#   Моноциты_абсолютное_значение: 14.0000
#   Систолическое_АД_b: 14.0000
#   CADILLAC: 14.0000
#   PAMI: 14.0000
#   APACHE_сутки_ПОСЛЕ_развития_SOFA_8_и_более: 14.0000
#   МЖП: 13.0000
#   Лейкоциты: 13.0000
#   Лимфоциты_абсолютное_значение: 13.0000
#   Средний_объем_эритроцита: 13.0000
#   PLR_тромбоциты/лимфоциты_абс_61-239: 13.0000
#   Продолжительность_операции: 13.0000
#   Max_Норадреналин: 13.0000
#   Тромбокрит: 12.0000
#   SII_тромбоциты*нейтрофилы_абс_/_лимфоциты_абс: 12.0000
#   GLR_глюкоза_мг/дл_/_лимф_абс: 12.0000
#   RLR_RDW/_lymph_abs: 12.0000
#   ЧСС_а: 12.0000
#   Эозинофилы_абсолютное_значение_a: 12.0000
#   АЛАТ_a: 12.0000
#   ФБГ_a: 12.0000
#   Количество_пораженных_сосудов_Значимость: 11.0000
#   Средний_объем_тромбоцита_MPV: 11.0000
#   Натрий_Na: 11.0000
#   Стенокардия_ИБ: 10.0000
#   Ra1: 10.0000
#   Гемоглобин: 10.0000
#   Фибриноген: 10.0000
#   Рост: 10.0000
#   РЕКОРД: 10.0000
#   TIMI_Летальность: 10.0000
#   Максимальный_ЛАКТАТ_артерия_за_сутки_до_развития_SOFA_8: 10.0000
#   НПВ_диаметр: 9.0000
#   Тромбоциты: 9.0000
#   Распределение_эритроцитов_по_объему_RDW-CV: 9.0000
#   Индекс_массы_тела: 9.0000
#   Эр_a: 9.0000
#   Тромбоциты_a: 9.0000
#   Отек_легких_a: 9.0000
#   APACHE_сутки_до_развития_SOFA_8_и_более: 9.0000
#   Max_Aдреналин: 9.0000
#   Базофилы_абсолютное_значение: 8.0000
#   Сумма_всех_лейкоцитов: 8.0000
#   MPV/PC_MPV/_PLT: 8.0000
#   Мочевина_b: 8.0000
#   Лимфоциты_%_a: 8.0000
#   Тропонин_1_a: 8.0000
#   LACTartMax: 8.0000
#   STEMI: 7.0000
#   Ср_концентрация_гемоглобина_в_эритроците: 7.0000
#   АСАТ_b: 7.0000
#   Минимальное_АД_3_сут: 7.0000
#   SaO2max_b: 7.0000
#   BEArtMin_a: 7.0000
#   LactVenMax_a: 7.0000
#   Эозинофилы_абсолютное_значение: 6.0000
#   Глюкоза_в_мг/дл: 6.0000
#   Триглицериды_b: 6.0000
#   Гематокрит_a: 6.0000
#   Калий_K: 6.0000
#   Хлор_Cl: 6.0000
#   LactVenMax_b: 6.0000
#   Количество_пораженных_сосудов_Syntax: 5.0000
#   La1: 5.0000
#   ENR_эозин_абс/нейтрофилы_абс: 5.0000
#   Креатинин_b: 5.0000
#   АСАТ_a: 5.0000
#   АПТВ_a: 5.0000
#   Часов_в_ОРИТ_ПОСЛЕ_развития_SOFA_8: 5.0000
#   Калий_K_a: 5.0000
#   SaO2min_b: 5.0000
#   LACTartMax_b: 5.0000
#   Вид_STEMI: 4.0000
#   ФП_при_окс_до_чкв: 4.0000
#   Расчетная_ширина_распределения_тромбоцитов: 4.0000
#   ELR_эозинофилы_абс/лимфоциты_абс: 4.0000
#   Общий_белок_b: 4.0000
#   АЛАТ_b: 4.0000
#   Hb_a: 4.0000
#   Триглицериды_a: 4.0000
#   ПИКС_в_диагнозе_при_поступлении: 4.0000
#   CADILLAC_Низкий_риск: 4.0000
#   Часов_в_ОРИТ_ДО_развития_SOFA_8: 4.0000
#   Максимальный_ЛАКТАТ_артерия_за_сутки_после_развития_SOFA_8: 4.0000
#   BEArtMin_b: 4.0000
#   Калий: 3.0000
#   Класс_ОСН_по_Killip: 3.0000
#   ФВ_ЛЖ_b: 3.0000
#   Базофилы_относительное_значение: 3.0000
#   BLR_базофилы_абс/лимфоциты_абс: 3.0000
#   SIRI_NxM_/L: 3.0000
#   ПТИ_b: 3.0000
#   Экстренная_операция_ИБ_Новый: 3.0000
#   Палочкоядерные_нейтрофилы_%_a: 3.0000
#   Креатинин_a: 3.0000
#   ЛДГ_a: 3.0000
#   ХОБЛ_Новый_столбец: 3.0000
#   TIMI_Летальность_Средний_риск: 3.0000
#   Максимальный_ЛАКТАТ_вена_за_сутки_после_развития_SOFA_8: 3.0000
#   Через_сколько_часов_после_развития_SOFA_8_и_более_был_введен_антибиотик: 3.0000
#   Макс_АД_3_сут: 3.0000
#   Мин_ЧСС_1_сутки: 3.0000
#   Max_Допмин: 3.0000
#   Хлор_Cl_a: 3.0000
#   pCO2max_a: 3.0000
#   PO2VenMax_a: 3.0000
#   BEVenMin_a: 3.0000
#   HCO3VenMin_a: 3.0000
#   Стеноз_аортального_клапана_степень: 2.0000
#   MLR_моноциты/лимфоциты: 2.0000
#   ELR_%: 2.0000
#   Моноциты_%_b: 2.0000
#   Глюкоза_b: 2.0000
#   ТВ_b: 2.0000
#   RR: 2.0000
#   Сопутствующие1: 2.0000
#   Тропонин_1_gt_0.1_a: 2.0000
#   Аортальный_стеноз_Градиент: 2.0000
#   Инфаркт-зависимая_артерия_Огригированная: 2.0000
#   GRACE_Общее_gt_156: 2.0000
#   Часов_до_введения_первого_антибиотика: 2.0000
#   pO2ARTmin_b: 2.0000
#   pO2ARTmax_b: 2.0000
#   SaO2min_a: 2.0000
#   LACTartMin_b: 2.0000
#   ScvO2Max_a: 2.0000
#   BEVenMin_b: 2.0000
#   BNP_a: 2.0000
#   Sex: 1.0000
#   ЧКВ: 1.0000
#   Инфаркт-зависимая_артерия: 1.0000
#   TIMI: 1.0000
#   Инфаркт_миокарда_в_анамнезе_gt_3: 1.0000
#   Инфаркт_миокарда_со_стентированием_в_анамнезе: 1.0000
#   Тромболизис: 1.0000
#   ФП_постоянная_форма: 1.0000
#   ГБ_стадия: 1.0000
#   ГБ_риск: 1.0000
#   АГ: 1.0000
#   Стенокардия_ФК_ИБ: 1.0000
#   ПСПЖ: 1.0000
#   LMR_лимфоциты_абс/моноциты_абс: 1.0000
#   PIV_or_AISI_NxMxPLT_/L: 1.0000
#   FLR_fibr/L_abs: 1.0000
#   Cегментоядерные_нейтрофилы_%_b: 1.0000
#   ЛДГ_b: 1.0000
#   КФК-МВ_b: 1.0000
#   МНО_b: 1.0000
#   интегрилин_эптифибатид_коромакс_агграстат: 1.0000
#   Диастолического_АД_b: 1.0000
#   Моноциты_абсолютное_значение_a: 1.0000
#   Базофилы_абсолютное_значение_a: 1.0000
#   Cегментоядерные_нейтрофилы_%_a: 1.0000
#   Общий_белок_a: 1.0000
#   Тропонин_1: 1.0000
#   Тропонин_1_gt_0.1: 1.0000
#   Аортальный_стеноз_Заключение: 1.0000
#   А-В_блокада: 1.0000
#   Медицинская_помощь_оказана_за_первые_4_часа: 1.0000
#   Гипертоническая_болезнь: 1.0000
#   А-В_блокада_степень: 1.0000
#   Максимальный_ЛАКТАТ_вена_за_сутки_до_развития_SOFA_8: 1.0000
#   Среднее_АД_3_сутки_в_орит: 1.0000
#   Максимальное_ЧСС_7_сутки: 1.0000
#   Адреналин: 1.0000
#   Левосимендан: 1.0000
#   killip: 1.0000
#   pHARTmin_b: 1.0000
#   pHARTmax_a: 1.0000
#   pCO2min_b: 1.0000
#   pCO2min: 1.0000
#   pCO2max_b: 1.0000
#   pCO2max: 1.0000
#   LACTartMin_a: 1.0000
#   LACTartMax_a: 1.0000
#   BEArtMin: 1.0000
#   BEArtMax_a: 1.0000
#   HCO3ArtMax_b: 1.0000
#   HCO3ArtMax_a: 1.0000
#   PHVenMin_b: 1.0000
#   PHVenMax_a: 1.0000
#   PO2VenMin_a: 1.0000
#   PCO2VenMax_a: 1.0000
#   PCO2VenMax: 1.0000
#   LactVenMin_b: 1.0000
#   LactVenMin_a: 1.0000
#   BEVenMax_a: 1.0000
#   HCO3VenMax_b: 1.0000
#   HCO3VenMax_a: 1.0000
#   Поражение_ствола: 0.0000
#   Инфаркт_миокарда_в_анамнезе_lt_3: 0.0000
#   ОНМК_иш_в_анамнезе: 0.0000
#   ОНМК_гем_в_анамнезе: 0.0000
#   Стентирование_в_анамнезе: 0.0000
#   Форма_ФП: 0.0000
#   Дилатация_предсердий: 0.0000
#   ФП_b_после_чкв: 0.0000
#   ФП_a_в_анамнезе: 0.0000
#   ФЖ: 0.0000
#   Пробежки_ЖТ: 0.0000
#   Рецидивирующая_ЖТ: 0.0000
#   ХСН_стадия: 0.0000
#   Стенокардия_форма_ИБ: 0.0000
#   СД: 0.0000
#   ХБП: 0.0000
#   ЯБ: 0.0000
#   МКБ: 0.0000
#   ЖКБ: 0.0000
#   EDV: 0.0000
#   Недостаточность_аортального_клапана_степень: 0.0000
#   Стеноз_митрального_клапана_степень: 0.0000
#   Недостаточность_митрального_клапана_степень: 0.0000
#   Недостаточность_трикуспидального_клапана_степень: 0.0000
#   НПВ: 0.0000
#   Эозинофилы_%_b: 0.0000
#   Палочкоядерные_нейтрофилы_%_b: 0.0000
#   Лимфоциты_%_b: 0.0000
#   Билирубин_общий_b: 0.0000
#   Холестерин_общий_b: 0.0000
#   КФК_b: 0.0000
#   АПТВ_b: 0.0000
#   повторные_операции: 0.0000
#   Тип_первой_операции_БД: 0.0000
#   Тип_повторной_операции: 0.0000
#   GRACE_Общее_gt_140: 0.0000
#   Экстракардиальная_артериопатия: 0.0000
#   Плохая_мобильность: 0.0000
#   Открытая_перация_на_сердце_в_анамнезе: 0.0000
#   Срочность: 0.0000
#   P: 0.0000
#   PQ: 0.0000
#   QRS: 0.0000
#   QT: 0.0000
#   СОЭ_a: 0.0000
#   Эозинофилы_%_a: 0.0000
#   Миелоциты_%_a: 0.0000
#   Билирубин_общий_a: 0.0000
#   Холестерин_общий_a: 0.0000
#   КФК_a: 0.0000
#   КФК-МВ_a: 0.0000
#   Сопутствующие2: 0.0000
#   eGFR_a: 0.0000
#   Тропонин_1_b: 0.0000
#   Тропонин_1_gt_0.1_b: 0.0000
#   Smoking: 0.0000
#   Протокол_коронарографии: 0.0000
#   Коррекция_А-В_блокады: 0.0000
#   Исход_А-В_блокады: 0.0000
#   Начало_А-В_блокады_До/после_ЧКВ: 0.0000
#   Инфаркт-зависимая_артерия_Огригированная_2: 0.0000
#   Ишемический_инсульт_Выгрузка_из_ИБ_-_временный_столбец: 0.0000
#   Геморрагический_инсульт_Выгрузка_из_ИБ_-_временный_столбец: 0.0000
#   Инсульт_Выгрузка_из_ИБ_-_временный_столбец: 0.0000
#   Курит: 0.0000
#   Отек_легких_b: 0.0000
#   CADILLAC_Средний_риск: 0.0000
#   CADILLAC_Высокий_риск: 0.0000
#   РЕКОРД_Низкий_риск: 0.0000
#   РЕКОРД_Высокий_риск: 0.0000
#   GRACE_Низкий_риск: 0.0000
#   GRACE_Средний_риск: 0.0000
#   GRACE_Высокий_риск: 0.0000
#   TIMI_Летальность_Низкий_риск: 0.0000
#   TIMI_Летальность_Высокий_риск: 0.0000
#   PAMI_Низкий_риск: 0.0000
#   PAMI_Средний_риск: 0.0000
#   PAMI_Высокий_риск: 0.0000
#   Время_ЧКВ: 0.0000
#   А-В_блокаДа_Новый: 0.0000
#   Максимальный_прокальцитонин_за_сутки_до_развития_SOFA_8: 0.0000
#   SOFA_первый_раз_больше_или_равна_8_баллам: 0.0000
#   SOFA_до_развития_8_и_более_баллов: 0.0000
#   Используемый_антибиотик_ДО_развития_SOFA_8_и_более: 0.0000
#   Левофлоксацин_антибиотик_ДО_развития_SOFA_8_и_более: 0.0000
#   Линезолид_антибиотик_ДО_развития_SOFA_8_и_более: 0.0000
#   Меропенем_антибиотик_ДО_развития_SOFA_8_и_более: 0.0000
#   Метронидазол_антибиотик_ДО_развития_SOFA_8_и_более: 0.0000
#   Моксифлоксацин_антибиотик_ДО_развития_SOFA_8_и_более: 0.0000
#   Нифуроксазид_антибиотик_ДО_развития_SOFA_8_и_более: 0.0000
#   Фосфомицин_антибиотик_ДО_развития_SOFA_8_и_более: 0.0000
#   Цефазолин_антибиотик_ДО_развития_SOFA_8_и_более: 0.0000
#   Сульбактам_антибиотик_ДО_развития_SOFA_8_и_более: 0.0000
#   Цефоперазон_антибиотик_ДО_развития_SOFA_8_и_более: 0.0000
#   Цефтриаксон_антибиотик_ДО_развития_SOFA_8_и_более: 0.0000
#   Количество_часов_применения_антибиотика_ДО_развития_SOFA_8_и_более: 0.0000
#   Антибиотик_после_развития_SOFA_8_и_более: 0.0000
#   Моксифлоксацин_после_развития_SOFA_8_и_более: 0.0000
#   Левофлоксацин_после_развития_SOFA_8_и_более: 0.0000
#   Азитромицин_после_развития_SOFA_8_и_более: 0.0000
#   Линезолид_после_развития_SOFA_8_и_более: 0.0000
#   Меропенем_после_развития_SOFA_8_и_более: 0.0000
#   Метронидазол_после_развития_SOFA_8_и_более: 0.0000
#   Нифуроксазид_после_развития_SOFA_8_и_более: 0.0000
#   Фосфомицин_после_развития_SOFA_8_и_более: 0.0000
#   Цефазолин_после_развития_SOFA_8_и_более: 0.0000
#   Сульбактам_после_развития_SOFA_8_и_более: 0.0000
#   Цефепим_после_развития_SOFA_8_и_более: 0.0000
#   Цефтриаксон_после_развития_SOFA_8_и_более: 0.0000
#   АД_среднее_за_сутки_до_развития_SOFA_8: 0.0000
#   Среднее_АД_1_сутки_в_орит: 0.0000
#   Минимальное_АД_1_сут: 0.0000
#   Макс_АД_1_сут: 0.0000
#   Среднее_АД_7_сутки_в_орит: 0.0000
#   Минимальное_АД_7_сут: 0.0000
#   Макс_АД_7_сут: 0.0000
#   Среднее_ЧСС_1_сутки: 0.0000
#   Максимальное_ЧСС_1_сутки: 0.0000
#   Среднее_ЧСС_3_сутки: 0.0000
#   Мин_ЧСС_3_сутки: 0.0000
#   Максимальное_ЧСС_3_сутки: 0.0000
#   Среднее_ЧСС_7_сутки: 0.0000
#   Мин_ЧСС_7_сутки: 0.0000
#   Лейкоциты_больше_9_до_назначения_аб: 0.0000
#   ИВЛ: 0.0000
#   Вазопрессорная_поддержка: 0.0000
#   Добутамин: 0.0000
#   Допмин: 0.0000
#   Норадреналин: 0.0000
#   Мезатон: 0.0000
#   Max_Добутамин: 0.0000
#   Max_Мезатона: 0.0000
#   UA_нестабильная_стенокардия: 0.0000
#   Натрий_Na_b: 0.0000
#   Калий_K_b: 0.0000
#   Хлор_Cl_b: 0.0000
#   Кальций_ионизированный_Ca+_b: 0.0000
#   Кальций_ионизированный_Ca+_a: 0.0000
#   Кальций_ионизированный_Ca+: 0.0000
#   pHARTmin_a: 0.0000
#   pHARTmin: 0.0000
#   pHARTmax_b: 0.0000
#   pHARTmax: 0.0000
#   pO2ARTmin_a: 0.0000
#   pO2ARTmin: 0.0000
#   pO2ARTmax_a: 0.0000
#   pO2ARTmax: 0.0000
#   pCO2min_a: 0.0000
#   SaO2min: 0.0000
#   SaO2max_a: 0.0000
#   SaO2max: 0.0000
#   LACTartMin: 0.0000
#   BEArtMax_b: 0.0000
#   BEArtMax: 0.0000
#   HCO3ArtMin_b: 0.0000
#   HCO3ArtMin_a: 0.0000
#   HCO3ArtMin: 0.0000
#   HCO3ArtMax: 0.0000
#   PHVenMin_a: 0.0000
#   PHVenMin: 0.0000
#   PHVenMax_b: 0.0000
#   PHVenMax: 0.0000
#   PO2VenMin_b: 0.0000
#   PO2VenMin: 0.0000
#   PO2VenMax_b: 0.0000
#   PO2VenMax: 0.0000
#   PCO2VenMin_b: 0.0000
#   PCO2VenMin_a: 0.0000
#   PCO2VenMin: 0.0000
#   PCO2VenMax_b: 0.0000
#   ScvO2Min_b: 0.0000
#   ScvO2Min_a: 0.0000
#   ScvO2Min: 0.0000
#   ScvO2Max_b: 0.0000
#   ScvO2Max: 0.0000
#   LactVenMin: 0.0000
#   LactVenMax: 0.0000
#   BEVenMin: 0.0000
#   BEVenMax_b: 0.0000
#   BEVenMax: 0.0000
#   HCO3VenMin_b: 0.0000
#   HCO3VenMin: 0.0000
#   HCO3VenMax: 0.0000
#   BNP_b: 0.0000
#   BNP: 0.0000

# %%
print("\n=== СОХРАНЕНИЕ РЕЗУЛЬТАТОВ ===")
analyzer.save_results_to_excel('lgb_ba.xlsx')
# Out:
# === СОХРАНЕНИЕ РЕЗУЛЬТАТОВ ===
# Результаты успешно сохранены в файл: lgb_ba.xlsx

# %%
print("\n=== ЗАКЛЮЧЕНИЕ ===")
print(f"Лучший ROC AUC (Forward): {best_forward_result['metrics']['roc_auc']:.4f} с {len(best_forward_features)} признаками")
print(f"Лучший ROC AUC (Backward): {best_backward_result['metrics']['roc_auc']:.4f} с {len(best_backward_features)} признаками")
print(f"Оптимальный порог для бинарной классификации: {best_threshold:.4f}")
# Out:
# === ЗАКЛЮЧЕНИЕ ===
# Лучший ROC AUC (Forward): 0.9421 с 7 признаками
# Лучший ROC AUC (Backward): 0.9695 с 416 признаками
# Оптимальный порог для бинарной классификации: 0.1200

# %% [markdown]
# # CatBoost

# %%
analyzer = FeatureSelectionAnalyzer(X_clean, y, test_size=0.2, random_state=42)

# %%
print("=== FORWARD SELECTION ===")
forward_features = analyzer.forward_selection(cat_model, max_features=None, metric='balanced_accuracy')  # ограничим до 10 признакей для демонстрации
# Out:
# === FORWARD SELECTION ===
# Запуск Forward Selection...
#   0%|          | 0/417 [00:00<?, ?it/s]
#   0%|          | 1/417 [00:38<4:25:16, 38.26s/it]
#   0%|          | 1/417 [00:38<4:25:16, 38.26s/it, balanced_accuracy=0.7943, Features=1]
# Step 1: Добавлен признак 'Мочевина_a', balanced_accuracy: 0.7943
#   0%|          | 2/417 [01:26<5:03:31, 43.88s/it, balanced_accuracy=0.7943, Features=1]
#   0%|          | 2/417 [01:26<5:03:31, 43.88s/it, balanced_accuracy=0.8300, Features=2]
# Step 2: Добавлен признак 'Синдромный_диагноз', balanced_accuracy: 0.8300
#   1%|          | 3/417 [02:16<5:21:49, 46.64s/it, balanced_accuracy=0.8300, Features=2]
#   1%|          | 3/417 [02:16<5:21:49, 46.64s/it, balanced_accuracy=0.8469, Features=3]
# Step 3: Добавлен признак 'MKB', balanced_accuracy: 0.8469
#   1%|          | 4/417 [03:04<5:26:52, 47.49s/it, balanced_accuracy=0.8469, Features=3]
#   1%|          | 4/417 [03:04<5:26:52, 47.49s/it, balanced_accuracy=0.8678, Features=4]
# Step 4: Добавлен признак 'СДЛА', balanced_accuracy: 0.8678
#   1%|          | 5/417 [03:55<5:33:44, 48.60s/it, balanced_accuracy=0.8678, Features=4]
#   1%|          | 5/417 [03:55<5:33:44, 48.60s/it, balanced_accuracy=0.8938, Features=5]
# Step 5: Добавлен признак 'Стенокардия_в_диагнозе_при_поступлении', balanced_accuracy: 0.8938
#   1%|▏         | 6/417 [04:47<5:40:59, 49.78s/it, balanced_accuracy=0.8938, Features=5]
#   1%|▏         | 6/417 [04:47<5:40:59, 49.78s/it, balanced_accuracy=0.9091, Features=6]
# Step 6: Добавлен признак 'Вид_операции_ИБ_Новый', balanced_accuracy: 0.9091
#   2%|▏         | 7/417 [05:37<5:41:50, 50.02s/it, balanced_accuracy=0.9091, Features=6]
#   2%|▏         | 7/417 [05:37<5:41:50, 50.02s/it, balanced_accuracy=0.9196, Features=7]
# Step 7: Добавлен признак 'CADILLAC_Средний_риск', balanced_accuracy: 0.9196
#   2%|▏         | 8/417 [06:28<5:42:34, 50.26s/it, balanced_accuracy=0.9196, Features=7]
#   2%|▏         | 8/417 [06:28<5:42:34, 50.26s/it, balanced_accuracy=0.9247, Features=8]
# Step 8: Добавлен признак 'Глюкоза_в_мг/дл', balanced_accuracy: 0.9247
#   2%|▏         | 9/417 [07:19<5:43:54, 50.58s/it, balanced_accuracy=0.9247, Features=8]
#   2%|▏         | 9/417 [07:19<5:43:54, 50.58s/it, balanced_accuracy=0.9270, Features=9]
# Step 9: Добавлен признак 'ОНМК_гем_в_анамнезе', balanced_accuracy: 0.9270

# %%
print("\n=== BACKWARD ELIMINATION ===")
backward_features = analyzer.backward_elimination(cat_model, min_features=1, metric='balanced_accuracy')
# Out:
#   0%|          | 1/416 [05:41<39:19:59, 341.20s/it]
#   0%|          | 1/416 [05:41<39:19:59, 341.20s/it, balanced_accuracy=0.9137, Features=416]
# Step 1: Удален признак 'Плохая_мобильность', balanced_accuracy: 0.9137
#   0%|          | 1/416 [11:18<78:11:00, 678.22s/it, balanced_accuracy=0.9137, Features=416]
# Step 2: Удаление ухудшает результат, останавливаемся
# Backward Elimination завершен. Осталось признаков: 416

# %%
table = pd.read_excel("lgb_2.xlsx")

# %%
table
# Out:
#      Method  Step  N_Features  \
# 0   Forward     1           1
# 1   Forward     2           2
# 2   Forward     3           3
# 3   Forward     4           4
# 4   Forward     5           5
# 5   Forward     6           6
# 6   Forward     7           7
# 7   Forward     8           8
# 8   Forward     9           9
# 9   Forward    10          10
# 10  Forward    11          11
# 11  Forward    12          12
# 12  Forward    13          13
# 13  Forward    14          14
# 14  Forward    15          15
# 15  Forward    16          16
# 16  Forward    17          17
# 17  Forward    18          18
# 18  Forward    19          19
# 19  Forward    20          20
# 20  Forward    21          21
# 21  Forward    22          22
# 22  Forward    23          23
# 23  Forward    24          24
#
#                                              Features  Accuracy  Precision  \
# 0                                       Отек_легких_a  0.935901   0.236559
# 1              Отек_легких_a, Гипертоническая_болезнь  0.931688   0.243119
# 2   Отек_легких_a, Гипертоническая_болезнь, Адреналин  0.931688   0.254386
# 3   Отек_легких_a, Гипертоническая_болезнь, Адрена...  0.934698   0.266055
# 4   Отек_легких_a, Гипертоническая_болезнь, Адрена...  0.934698   0.268182
# 5   Отек_легких_a, Гипертоническая_болезнь, Адрена...  0.935600   0.271889
# 6   Отек_легких_a, Гипертоническая_болезнь, Адрена...  0.926873   0.257576
# 7   Отек_легких_a, Гипертоническая_болезнь, Адрена...  0.928378   0.262548
# 8   Отек_легких_a, Гипертоническая_болезнь, Адрена...  0.922359   0.257627
# 9   Отек_легких_a, Гипертоническая_болезнь, Адрена...  0.927475   0.276596
# 10  Отек_легких_a, Гипертоническая_болезнь, Адрена...  0.933494   0.315972
# 11  Отек_легких_a, Гипертоническая_болезнь, Адрена...  0.941619   0.348659
# 12  Отек_легких_a, Гипертоническая_болезнь, Адрена...  0.949142   0.386555
# 13  Отек_легких_a, Гипертоническая_болезнь, Адрена...  0.952152   0.404348
# 14  Отек_легких_a, Гипертоническая_болезнь, Адрена...  0.956365   0.432432
# 15  Отек_легких_a, Гипертоническая_болезнь, Адрена...  0.961180   0.464646
# 16  Отек_легких_a, Гипертоническая_болезнь, Адрена...  0.961180   0.465347
# 17  Отек_легких_a, Гипертоническая_болезнь, Адрена...  0.962684   0.477387
# 18  Отек_легких_a, Гипертоническая_болезнь, Адрена...  0.963587   0.484848
# 19  Отек_легких_a, Гипертоническая_болезнь, Адрена...  0.964791   0.494792
# 20  Отек_легких_a, Гипертоническая_болезнь, Адрена...  0.964189   0.490099
# 21  Отек_легких_a, Гипертоническая_болезнь, Адрена...  0.967499   0.518919
# 22  Отек_легких_a, Гипертоническая_болезнь, Адрена...  0.969606   0.539326
# 23  Отек_легких_a, Гипертоническая_болезнь, Адрена...  0.971411   0.556180
#
#       Recall        F1   ROC_AUC  Training_Time  ...  \
# 0   0.382609  0.292359  0.676194       3.819139  ...
# 1   0.460870  0.318318  0.732004       9.368924  ...
# 2   0.504348  0.338192  0.759570      13.096042  ...
# 3   0.504348  0.348348  0.789049      15.308106  ...
# 4   0.513043  0.352239  0.791727      15.691161  ...
# 5   0.513043  0.355422  0.794866      16.874929  ...
# 6   0.591304  0.358839  0.814542      18.417949  ...
# 7   0.591304  0.363636  0.821552      18.331583  ...
# 8   0.660870  0.370732  0.839078      19.777493  ...
# 9   0.678261  0.392947  0.850913      19.527713  ...
# 10  0.791304  0.451613  0.926193      19.348826  ...
# 11  0.791304  0.484043  0.940089      21.137310  ...
# 12  0.800000  0.521246  0.943370      22.137665  ...
# 13  0.808696  0.539130  0.943603      21.840563  ...
# 14  0.834783  0.569733  0.953219      22.354859  ...
# 15  0.800000  0.587859  0.949394      21.897779  ...
# 16  0.817391  0.593060  0.956602      22.485458  ...
# 17  0.826087  0.605096  0.968873      21.830341  ...
# 18  0.834783  0.613419  0.968065      21.794443  ...
# 19  0.826087  0.618893  0.967862      22.036701  ...
# 20  0.860870  0.624606  0.962916      21.655272  ...
# 21  0.834783  0.640000  0.966692      22.527401  ...
# 22  0.834783  0.655290  0.968505      22.419294  ...
# 23  0.860870  0.675768  0.969286      22.352612  ...
#
#     Importance_Коэффициент_крупных_тромбоцитов  Importance_MPV/PC_MPV/_PLT  \
# 0                                          NaN                         NaN
# 1                                          NaN                         NaN
# 2                                          NaN                         NaN
# 3                                          NaN                         NaN
# 4                                          NaN                         NaN
# 5                                          NaN                         NaN
# 6                                          NaN                         NaN
# 7                                          NaN                         NaN
# 8                                          NaN                         NaN
# 9                                          NaN                         NaN
# 10                                         NaN                         NaN
# 11                                         NaN                         NaN
# 12                                         NaN                         NaN
# 13                                         NaN                         NaN
# 14                                       317.0                         NaN
# 15                                       245.0                       199.0
# 16                                       243.0                       187.0
# 17                                       190.0                       196.0
# 18                                       181.0                       188.0
# 19                                       192.0                       183.0
# 20                                       165.0                       157.0
# 21                                       180.0                       154.0
# 22                                       182.0                       153.0
# 23                                       149.0                       136.0
#
#     Importance_Стенокардия_в_диагнозе_при_поступлении  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                               99.0
# 17                                               76.0
# 18                                               74.0
# 19                                               76.0
# 20                                               63.0
# 21                                               67.0
# 22                                               66.0
# 23                                               69.0
#
#     Importance_Базофилы_относительное_значение  Importance_Ra1  \
# 0                                          NaN             NaN
# 1                                          NaN             NaN
# 2                                          NaN             NaN
# 3                                          NaN             NaN
# 4                                          NaN             NaN
# 5                                          NaN             NaN
# 6                                          NaN             NaN
# 7                                          NaN             NaN
# 8                                          NaN             NaN
# 9                                          NaN             NaN
# 10                                         NaN             NaN
# 11                                         NaN             NaN
# 12                                         NaN             NaN
# 13                                         NaN             NaN
# 14                                         NaN             NaN
# 15                                         NaN             NaN
# 16                                         NaN             NaN
# 17                                       138.0             NaN
# 18                                       133.0           129.0
# 19                                       137.0           124.0
# 20                                       106.0            96.0
# 21                                       120.0           113.0
# 22                                       117.0           111.0
# 23                                       106.0           100.0
#
#     Importance_CADILLAC_Средний_риск_1  Importance_ФВ_ЛЖ  \
# 0                                  NaN               NaN
# 1                                  NaN               NaN
# 2                                  NaN               NaN
# 3                                  NaN               NaN
# 4                                  NaN               NaN
# 5                                  NaN               NaN
# 6                                  NaN               NaN
# 7                                  NaN               NaN
# 8                                  NaN               NaN
# 9                                  NaN               NaN
# 10                                 NaN               NaN
# 11                                 NaN               NaN
# 12                                 NaN               NaN
# 13                                 NaN               NaN
# 14                                 NaN               NaN
# 15                                 NaN               NaN
# 16                                 NaN               NaN
# 17                                 NaN               NaN
# 18                                 NaN               NaN
# 19                                 4.0               NaN
# 20                                 1.0             168.0
# 21                                 2.0             170.0
# 22                                 3.0             167.0
# 23                                 1.0             163.0
#
#     Importance_Стенокардия_ИБ  Importance_ЗСЛЖ  Importance_SpO2
# 0                         NaN              NaN              NaN
# 1                         NaN              NaN              NaN
# 2                         NaN              NaN              NaN
# 3                         NaN              NaN              NaN
# 4                         NaN              NaN              NaN
# 5                         NaN              NaN              NaN
# 6                         NaN              NaN              NaN
# 7                         NaN              NaN              NaN
# 8                         NaN              NaN              NaN
# 9                         NaN              NaN              NaN
# 10                        NaN              NaN              NaN
# 11                        NaN              NaN              NaN
# 12                        NaN              NaN              NaN
# 13                        NaN              NaN              NaN
# 14                        NaN              NaN              NaN
# 15                        NaN              NaN              NaN
# 16                        NaN              NaN              NaN
# 17                        NaN              NaN              NaN
# 18                        NaN              NaN              NaN
# 19                        NaN              NaN              NaN
# 20                        NaN              NaN              NaN
# 21                       59.0              NaN              NaN
# 22                       57.0             49.0              NaN
# 23                       64.0             48.0             72.0
#
# [24 rows x 34 columns]

# %%
print("\n=== ПОИСК ОПТИМАЛЬНОГО ПОРОГА ===")
best_threshold, _ = analyzer.find_optimal_threshold(method='forward')
# Out:
# === ПОИСК ОПТИМАЛЬНОГО ПОРОГА ===
# === Оптимальные пороги (forward, 9 признаков) ===
# По Balanced Accuracy score: 0.5200 (F1=0.9295)
# По Youden's J: 0.5267

# %%
print("\n=== ПОИСК ОПТИМАЛЬНОГО ПОРОГА ===")
best_threshold, _ = analyzer.find_optimal_threshold(method='backward')
# Out:
# === ПОИСК ОПТИМАЛЬНОГО ПОРОГА ===
# === Оптимальные пороги (backward, 416 признаков) ===
# По Balanced Accuracy score: 0.3000 (F1=0.9151)
# По Youden's J: 0.3062

# %%
print("\n=== СРАВНЕНИЕ МЕТОДОВ ===")
analyzer.compare_feature_selection_methods()
# Out:
# === СРАВНЕНИЕ МЕТОДОВ ===

# %%
print("\n=== ВИЗУАЛИЗАЦИЯ РАСПРЕДЕЛЕНИЯ ВЕРОЯТНОСТЕЙ ===")
analyzer.visualize_probability_distribution(method='forward')
# Out:
# === ВИЗУАЛИЗАЦИЯ РАСПРЕДЕЛЕНИЯ ВЕРОЯТНОСТЕЙ ===

# %%
print("\n=== ВИЗУАЛИЗАЦИЯ РАСПРЕДЕЛЕНИЯ ВЕРОЯТНОСТЕЙ ===")
analyzer.visualize_probability_distribution(method='backward')
# Out:
# === ВИЗУАЛИЗАЦИЯ РАСПРЕДЕЛЕНИЯ ВЕРОЯТНОСТЕЙ ===

# %%
# Получение лучших признакей из всех комбинаций
print("\n=== ЛУЧШИЕ ПРИЗНАКИ ИЗ ВСЕХ КОМБИНАЦИЙ ===")
best_forward_features, best_forward_result = analyzer.get_best_features(method='forward')
best_backward_features, best_backward_result = analyzer.get_best_features(method='backward')
# Out:
# === ЛУЧШИЕ ПРИЗНАКИ ИЗ ВСЕХ КОМБИНАЦИЙ ===
# === Лучшие признаки (forward) ===
# Количество признаков: 9
# Лучшая f1: 0.4355
# Признаки: ['Мочевина_a', 'Синдромный_диагноз', 'MKB', 'СДЛА', 'Стенокардия_в_диагнозе_при_поступлении', 'Вид_операции_ИБ_Новый', 'CADILLAC_Средний_риск', 'Глюкоза_в_мг/дл', 'ОНМК_гем_в_анамнезе']
#
# Важность признаков:
#   СДЛА: 22.0970
#   Мочевина_a: 19.5068
#   Синдромный_диагноз: 14.8289
#   MKB: 13.3804
#   Вид_операции_ИБ_Новый: 12.4358
#   CADILLAC_Средний_риск: 7.2380
#   Глюкоза_в_мг/дл: 5.5496
#   Стенокардия_в_диагнозе_при_поступлении: 4.4085
#   ОНМК_гем_в_анамнезе: 0.5549
# === Лучшие признаки (backward) ===
# Количество признаков: 416
# Лучшая f1: 0.5714
# Признаки: ['Age', 'Sex', 'STEMI', 'ЧКВ', 'Вид_STEMI', 'Инфаркт-зависимая_артерия', 'Поражение_ствола', 'Количество_пораженных_сосудов_Syntax', 'Количество_пораженных_сосудов_Значимость', 'TIMI', 'Инфаркт_миокарда_в_анамнезе_lt_3', 'Инфаркт_миокарда_в_анамнезе_gt_3', 'Инфаркт_миокарда_со_стентированием_в_анамнезе', 'ОНМК_иш_в_анамнезе', 'ОНМК_гем_в_анамнезе', 'Стентирование_в_анамнезе', 'Тромболизис', 'Форма_ФП', 'Калий', 'Дилатация_предсердий', 'ФП_b_после_чкв', 'ФП_a_в_анамнезе', 'ФП_при_окс_до_чкв', 'ФП_постоянная_форма', 'ФЖ', 'Пробежки_ЖТ', 'Рецидивирующая_ЖТ', 'MKB', 'Класс_ОСН_по_Killip', 'ХСН_стадия', 'ГБ_стадия', 'ГБ_риск', 'АГ', 'Стенокардия_ИБ', 'Стенокардия_форма_ИБ', 'Стенокардия_ФК_ИБ', 'СД', 'ХБП', 'ЯБ', 'МКБ', 'ЖКБ', 'ФВ_ЛЖ_b', 'ФВ_ЛЖ', 'EDV', 'МЖП', 'ЗСЛЖ', 'ПСПЖ', 'СДЛА', 'Размер_правого_желудочка', 'Стеноз_аортального_клапана_степень', 'Недостаточность_аортального_клапана_степень', 'Стеноз_митрального_клапана_степень', 'Недостаточность_митрального_клапана_степень', 'Недостаточность_трикуспидального_клапана_степень', 'НПВ', 'НПВ_диаметр', 'La1', 'La2', 'Ra1', 'Ra2', 'Гематокрит', 'Гемоглобин', 'Эритроциты', 'Лейкоциты', 'Тромбоциты', 'Нейтрофилы_абсолютное_значение', 'Нейтрофилы_относительное_значение', 'Лимфоциты_абсолютное_значение', 'Лимфоциты_относительное_значение', 'Моноциты_абсолютное_значение', 'Моноциты_относительное_значение', 'Эозинофилы_абсолютное_значение', 'Эозинофилы_относительное_значение', 'Базофилы_абсолютное_значение', 'Базофилы_относительное_значение', 'Сумма_всех_лейкоцитов', 'Средний_объем_эритроцита', 'Среднее_содержание_гемоглобина_в_эритроците', 'Ср_концентрация_гемоглобина_в_эритроците', 'Распределение_эритроцитов_по_объему_RDW-CV', 'Распределение_эритроцитов_по_объему_RDW-SD', 'Средний_объем_тромбоцита_MPV', 'Расчетная_ширина_распределения_тромбоцитов', 'Тромбокрит', 'Коэффициент_крупных_тромбоцитов', 'СОЭ', 'С-реактивный_белок', 'PLR_тромбоциты/лимфоциты_абс_61-239', 'MLR_моноциты/лимфоциты', 'LMR_лимфоциты_абс/моноциты_абс', 'SII_тромбоциты*нейтрофилы_абс_/_лимфоциты_абс', 'ELR_эозинофилы_абс/лимфоциты_абс', 'ELR_%', 'ENR_эозин_абс/нейтрофилы_абс', 'BLR_базофилы_абс/лимфоциты_абс', 'SIRI_NxM_/L', 'PIV_or_AISI_NxMxPLT_/L', 'GLR_глюкоза_мг/дл_/_лимф_абс', 'FLR_fibr/L_abs', 'RLR_RDW/_lymph_abs', 'MPV/PC_MPV/_PLT', 'Глюкоза_в_мг/дл', 'Фибриноген', 'Эозинофилы_%_b', 'Палочкоядерные_нейтрофилы_%_b', 'Cегментоядерные_нейтрофилы_%_b', 'Лимфоциты_%_b', 'Моноциты_%_b', 'Общий_белок_b', 'Глюкоза_b', 'АСАТ_b', 'АЛАТ_b', 'Билирубин_общий_b', 'Холестерин_общий_b', 'Триглицериды_b', 'Креатинин_b', 'Мочевина_b', 'ЛДГ_b', 'КФК_b', 'КФК-МВ_b', 'ПТИ_b', 'МНО_b', 'ТВ_b', 'АПТВ_b', 'Продолжительность_операции', 'Экстренная_операция_ИБ_Новый', 'Вид_операции_ИБ_Новый', 'повторные_операции', 'Тип_первой_операции_БД', 'Тип_повторной_операции', 'Количество_дней_в_реанимации', 'Apache_II', 'GRACE_Общее', 'GRACE_Общее_gt_140', 'интегрилин_эптифибатид_коромакс_агграстат', 'Рост', 'Вес', 'Индекс_массы_тела', 'Экстракардиальная_артериопатия', 'Открытая_перация_на_сердце_в_анамнезе', 'Срочность', 'Систолическое_АД_b', 'Диастолического_АД_b', 'ЧСС_b', 'САД_a', 'ЧСС_а', 'P', 'PQ', 'QRS', 'QT', 'RR', 'Лейкоциты_a', 'Нейтрофилы_абсолютное_значение_a', 'Лимфоциты_абсолютное_значение_a', 'Моноциты_абсолютное_значение_a', 'Эозинофилы_абсолютное_значение_a', 'Базофилы_абсолютное_значение_a', 'Эр_a', 'Hb_a', 'Гематокрит_a', 'Тромбоциты_a', 'СОЭ_a', 'Эозинофилы_%_a', 'Палочкоядерные_нейтрофилы_%_a', 'Cегментоядерные_нейтрофилы_%_a', 'Лимфоциты_%_a', 'Моноциты_%_a', 'Миелоциты_%_a', 'Общий_белок_a', 'Глюкоза_a', 'АСАТ_a', 'АЛАТ_a', 'Билирубин_общий_a', 'Холестерин_общий_a', 'Триглицериды_a', 'Креатинин_a', 'Мочевина_a', 'ЛДГ_a', 'КФК_a', 'КФК-МВ_a', 'ПТИ_a', 'МНО_a', 'ФБГ_a', 'ТВ_a', 'АПТВ_a', 'Сопутствующие1', 'Сопутствующие2', 'eGFR_a', 'Креатинин', 'СКФ', 'Тропонин_1_b', 'Тропонин_1_gt_0.1_b', 'Тропонин_1_a', 'Тропонин_1_gt_0.1_a', 'Тропонин_1', 'Тропонин_1_gt_0.1', 'Smoking', 'Протокол_коронарографии', 'Аортальный_стено ...
#
# Важность признаков:
#   Отек_легких: 5.0314
#   Эозинофилы_относительное_значение: 4.9437
#   ФВ_lt_40: 4.7856
#   Стенокардия_в_диагнозе_при_поступлении: 3.2231
#   Синдромный_диагноз: 2.9327
#   STEMI: 2.8240
#   BEArtMin_b: 2.5048
#   Apache_II: 2.2922
#   MKB: 1.9902
#   Стенокардия_ИБ: 1.8929
#   Размер_правого_желудочка: 1.8447
#   ФВ_ЛЖ: 1.6370
#   ЧСС_b: 1.4482
#   Отек_легких_a: 1.2837
#   Натрий_Na: 1.2704
#   Креатинин: 1.2571
#   Вид_операции_ИБ_Новый: 1.2234
#   СДЛА: 1.2155
#   Лимфоциты_относительное_значение: 1.2119
#   Гематокрит_a: 1.1939
#   Стенокардия_форма_ИБ: 1.1334
#   Геморрагический_инсульт_Выгрузка_из_ИБ_-_временный_столбец: 1.1173
#   Калий_K_a: 1.1017
#   МНО_a: 1.0978
#   ЧСС_а: 1.0745
#   LACTartMax_a: 1.0565
#   САД_a: 1.0160
#   La1: 1.0146
#   Нейтрофилы_абсолютное_значение_a: 1.0084
#   Эозинофилы_абсолютное_значение_a: 0.9814
#   PAMI_Низкий_риск: 0.9797
#   Вид_STEMI: 0.9633
#   Hb_a: 0.9421
#   Эозинофилы_абсолютное_значение: 0.9054
#   Количество_пораженных_сосудов_Значимость: 0.8850
#   Систолическое_АД_b: 0.8220
#   Нейтрофилы_абсолютное_значение: 0.7918
#   HCO3ArtMin: 0.7730
#   СКФ: 0.7154
#   Общий_белок_a: 0.7037
#   ФП_b_после_чкв: 0.6918
#   ХБП: 0.6899
#   АЛАТ_a: 0.6848
#   Аортальный_стеноз_Градиент: 0.6835
#   Эритроциты: 0.6450
#   Глюкоза_a: 0.6288
#   Тромбоциты_a: 0.5592
#   Лимфоциты_абсолютное_значение: 0.5455
#   Коэффициент_крупных_тромбоцитов: 0.5197
#   Базофилы_абсолютное_значение: 0.5181
#   PLR_тромбоциты/лимфоциты_абс_61-239: 0.5082
#   С-реактивный_белок: 0.4953
#   LactVenMax_a: 0.4934
#   pO2ARTmin_b: 0.4817
#   Натрий_Na_a: 0.4739
#   PAMI: 0.4709
#   РЕКОРД_Высокий_риск: 0.4698
#   Max_Норадреналин: 0.4694
#   ELR_эозинофилы_абс/лимфоциты_абс: 0.4640
#   Эр_a: 0.4578
#   Вес: 0.4533
#   ПТИ_a: 0.4510
#   pO2ARTmin: 0.3936
#   GRACE_Общее: 0.3904
#   GRACE_Общее_gt_140: 0.3888
#   LactVenMin_b: 0.3860
#   SaO2min_b: 0.3798
#   Креатинин_a: 0.3797
#   АСАТ_a: 0.3791
#   Хлор_Cl_a: 0.3754
#   Гематокрит: 0.3657
#   Продолжительность_операции: 0.3654
#   Допмин: 0.3564
#   Калий_K: 0.3537
#   Срочность: 0.3377
#   Экстракардиальная_артериопатия: 0.3310
#   Нейтрофилы_относительное_значение: 0.3293
#   MLR_моноциты/лимфоциты: 0.3208
#   RR: 0.3176
#   ТВ_a: 0.3115
#   Ra2: 0.3109
#   Сумма_всех_лейкоцитов: 0.3035
#   SaO2min_a: 0.2911
#   ГБ_стадия: 0.2889
#   Класс_ОСН_по_Killip: 0.2845
#   Мезатон: 0.2844
#   ФП_при_окс_до_чкв: 0.2801
#   SII_тромбоциты*нейтрофилы_абс_/_лимфоциты_абс: 0.2779
#   Индекс_массы_тела: 0.2748
#   Мочевина_a: 0.2732
#   Ср_концентрация_гемоглобина_в_эритроците: 0.2608
#   Фибриноген: 0.2587
#   Базофилы_относительное_значение: 0.2584
#   Моноциты_абсолютное_значение: 0.2551
#   ФБГ_a: 0.2512
#   Лимфоциты_абсолютное_значение_a: 0.2456
#   BEVenMin: 0.2415
#   Количество_дней_в_реанимации: 0.2397
#   Курит: 0.2352
#   Холестерин_общий_a: 0.2347
#   CADILLAC: 0.2262
#   Гемоглобин: 0.2255
#   pCO2min: 0.2135
#   Расчетная_ширина_распределения_тромбоцитов: 0.2110
#   PHVenMin_a: 0.2077
#   PAMI_Высокий_риск: 0.2055
#   НПВ: 0.2046
#   Макс_АД_3_сут: 0.1952
#   pCO2max_b: 0.1932
#   Лейкоциты: 0.1910
#   TIMI_Летальность_Высокий_риск: 0.1889
#   Тип_первой_операции_БД: 0.1830
#   GRACE_Высокий_риск: 0.1796
#   Лейкоциты_a: 0.1737
#   Рост: 0.1666
#   Глюкоза_в_мг/дл: 0.1624
#   HCO3VenMax: 0.1594
#   pHARTmin: 0.1587
#   Адреналин: 0.1576
#   Количество_пораженных_сосудов_Syntax: 0.1565
#   Тропонин_1_a: 0.1553
#   HCO3VenMax_b: 0.1482
#   Эозинофилы_%_b: 0.1481
#   APACHE_сутки_ПОСЛЕ_развития_SOFA_8_и_более: 0.1474
#   Age: 0.1468
#   РЕКОРД: 0.1460
#   Добутамин: 0.1441
#   Среднее_содержание_гемоглобина_в_эритроците: 0.1434
#   BEArtMax: 0.1401
#   PAMI_Средний_риск: 0.1361
#   HCO3VenMin_a: 0.1360
#   ХОБЛ_Новый_столбец: 0.1330
#   Инфаркт-зависимая_артерия: 0.1324
#   Инфаркт_миокарда_со_стентированием_в_анамнезе: 0.1322
#   Диастолического_АД_b: 0.1302
#   LactVenMin: 0.1274
#   PHVenMax_b: 0.1254
#   QT: 0.1200
#   SpO2: 0.1193
#   TIMI: 0.1190
#   ГБ_риск: 0.1178
#   CADILLAC_Низкий_риск: 0.1169
#   Отек_легких_b: 0.1153
#   Средний_объем_тромбоцита_MPV: 0.1133
#   killip: 0.1099
#   BLR_базофилы_абс/лимфоциты_абс: 0.1090
#   La2: 0.1075
#   PHVenMin: 0.1037
#   Палочкоядерные_нейтрофилы_%_b: 0.1026
#   ЯБ: 0.1012
#   BEArtMin_a: 0.1004
#   ОНМК_иш_в_анамнезе: 0.0997
#   BEVenMin_b: 0.0996
#   Тромбокрит: 0.0993
#   Моноциты_относительное_значение: 0.0963
#   CADILLAC_Высокий_риск: 0.0954
#   КФК_a: 0.0951
#   LACTartMin_a: 0.0931
#   Триглицериды_a: 0.0890
#   Max_Aдреналин: 0.0875
#   pCO2max: 0.0873
#   Калий: 0.0858
#   BEArtMax_a: 0.0854
#   МЖП: 0.0847
#   BEVenMax: 0.0847
#   Креатинин_b: 0.0841
#   BEVenMax_b: 0.0808
#   Распределение_эритроцитов_по_объему_RDW-SD: 0.0795
#   Средний_объем_эритроцита: 0.0794
#   НПВ_диаметр: 0.0762
#   А-В_блокаДа_Новый: 0.0749
#   АСАТ_b: 0.0740
#   LACTartMin_b: 0.0739
#   Тропонин_1_gt_0.1: 0.0687
#   Минимальное_АД_3_сут: 0.0670
#   TIMI_Летальность_Средний_риск: 0.0656
#   интегрилин_эптифибатид_коромакс_агграстат: 0.0626
#   SIRI_NxM_/L: 0.0607
#   PO2VenMax_b: 0.0594
#   Лимфоциты_%_b: 0.0581
#   АПТВ_a: 0.0542
#   СОЭ_a: 0.0538
#   GLR_глюкоза_мг/дл_/_лимф_абс: 0.0514
#   Моноциты_%_a: 0.0503
#   Хлор_Cl: 0.0495
#   LMR_лимфоциты_абс/моноциты_абс: 0.0485
#   Ra1: 0.0479
#   Тромболизис: 0.0469
#   LACTartMax_b: 0.0461
#   КФК-МВ_a: 0.0460
#   SaO2min: 0.0452
#   ПИКС_в_диагнозе_при_поступлении: 0.0441
#   ХСН_стадия: 0.0439
#   Форма_ФП: 0.0436
#   Sex: 0.0419
#   АЛАТ_b: 0.0406
#   ФВ_ЛЖ_b: 0.0355
#   Тропонин_1_gt_0.1_a: 0.0352
#   pO2ARTmax: 0.0340
#   ПСПЖ: 0.0304
#   HCO3VenMin_b: 0.0265
#   Максимальное_ЧСС_1_сутки: 0.0257
#   Сопутствующие2: 0.0251
#   АПТВ_b: 0.0242
#   Сопутствующие1: 0.0233
#   Глюкоза_b: 0.0233
#   Цефтриаксон_антибиотик_ДО_развития_SOFA_8_и_более: 0.0217
#   Максимальный_ЛАКТАТ_артерия_за_сутки_после_развития_SOFA_8: 0.0194
#   pO2ARTmax_a: 0.0192
#   СОЭ: 0.0182
#   pHARTmax: 0.0152
#   LACTartMin: 0.0145
#   BNP_a: 0.0128
#   Хлор_Cl_b: 0.0110
#   CADILLAC_Средний_риск: 0.0083
#   Максимальный_ЛАКТАТ_артерия_за_сутки_до_развития_SOFA_8: 0.0076
#   Поражение_ствола: 0.0074
#   Часов_в_ОРИТ_ПОСЛЕ_развития_SOFA_8: 0.0061
#   Базофилы_абсолютное_значение_a: 0.0042
#   BEVenMin_a: 0.0023
#   Кальций_ионизированный_Ca+_b: 0.0017
#   СД: 0.0016
#   PHVenMax: 0.0000
#   ЧКВ: 0.0000
#   Инфаркт_миокарда_в_анамнезе_lt_3: 0.0000
#   Инфаркт_миокарда_в_анамнезе_gt_3: 0.0000
#   ОНМК_гем_в_анамнезе: 0.0000
#   Стентирование_в_анамнезе: 0.0000
#   Дилатация_предсердий: 0.0000
#   ФП_a_в_анамнезе: 0.0000
#   ФП_постоянная_форма: 0.0000
#   ФЖ: 0.0000
#   Пробежки_ЖТ: 0.0000
#   Рецидивирующая_ЖТ: 0.0000
#   АГ: 0.0000
#   Стенокардия_ФК_ИБ: 0.0000
#   МКБ: 0.0000
#   ЖКБ: 0.0000
#   EDV: 0.0000
#   ЗСЛЖ: 0.0000
#   Стеноз_аортального_клапана_степень: 0.0000
#   Недостаточность_аортального_клапана_степень: 0.0000
#   Стеноз_митрального_клапана_степень: 0.0000
#   Недостаточность_митрального_клапана_степень: 0.0000
#   Недостаточность_трикуспидального_клапана_степень: 0.0000
#   Тромбоциты: 0.0000
#   Распределение_эритроцитов_по_объему_RDW-CV: 0.0000
#   ELR_%: 0.0000
#   ENR_эозин_абс/нейтрофилы_абс: 0.0000
#   PIV_or_AISI_NxMxPLT_/L: 0.0000
#   FLR_fibr/L_abs: 0.0000
#   RLR_RDW/_lymph_abs: 0.0000
#   MPV/PC_MPV/_PLT: 0.0000
#   Cегментоядерные_нейтрофилы_%_b: 0.0000
#   Моноциты_%_b: 0.0000
#   Общий_белок_b: 0.0000
#   Билирубин_общий_b: 0.0000
#   Холестерин_общий_b: 0.0000
#   Триглицериды_b: 0.0000
#   Мочевина_b: 0.0000
#   ЛДГ_b: 0.0000
#   КФК_b: 0.0000
#   КФК-МВ_b: 0.0000
#   ПТИ_b: 0.0000
#   МНО_b: 0.0000
#   ТВ_b: 0.0000
#   Экстренная_операция_ИБ_Новый: 0.0000
#   повторные_операции: 0.0000
#   Тип_повторной_операции: 0.0000
#   Открытая_перация_на_сердце_в_анамнезе: 0.0000
#   P: 0.0000
#   PQ: 0.0000
#   QRS: 0.0000
#   Моноциты_абсолютное_значение_a: 0.0000
#   Эозинофилы_%_a: 0.0000
#   Палочкоядерные_нейтрофилы_%_a: 0.0000
#   Cегментоядерные_нейтрофилы_%_a: 0.0000
#   Лимфоциты_%_a: 0.0000
#   Миелоциты_%_a: 0.0000
#   Билирубин_общий_a: 0.0000
#   ЛДГ_a: 0.0000
#   eGFR_a: 0.0000
#   Тропонин_1_b: 0.0000
#   Тропонин_1_gt_0.1_b: 0.0000
#   Тропонин_1: 0.0000
#   Smoking: 0.0000
#   Протокол_коронарографии: 0.0000
#   Аортальный_стеноз_Заключение: 0.0000
#   Коррекция_А-В_блокады: 0.0000
#   Исход_А-В_блокады: 0.0000
#   Начало_А-В_блокады_До/после_ЧКВ: 0.0000
#   А-В_блокада: 0.0000
#   Инфаркт-зависимая_артерия_Огригированная: 0.0000
#   Инфаркт-зависимая_артерия_Огригированная_2: 0.0000
#   Ишемический_инсульт_Выгрузка_из_ИБ_-_временный_столбец: 0.0000
#   Инсульт_Выгрузка_из_ИБ_-_временный_столбец: 0.0000
#   GRACE_Общее_gt_156: 0.0000
#   Медицинская_помощь_оказана_за_первые_4_часа: 0.0000
#   Гипертоническая_болезнь: 0.0000
#   TIMI_Летальность: 0.0000
#   РЕКОРД_Низкий_риск: 0.0000
#   GRACE_Низкий_риск: 0.0000
#   GRACE_Средний_риск: 0.0000
#   TIMI_Летальность_Низкий_риск: 0.0000
#   Время_ЧКВ: 0.0000
#   А-В_блокада_степень: 0.0000
#   Часов_до_введения_первого_антибиотика: 0.0000
#   Часов_в_ОРИТ_ДО_развития_SOFA_8: 0.0000
#   Максимальный_прокальцитонин_за_сутки_до_развития_SOFA_8: 0.0000
#   Максимальный_ЛАКТАТ_вена_за_сутки_до_развития_SOFA_8: 0.0000
#   Максимальный_ЛАКТАТ_вена_за_сутки_после_развития_SOFA_8: 0.0000
#   SOFA_первый_раз_больше_или_равна_8_баллам: 0.0000
#   SOFA_до_развития_8_и_более_баллов: 0.0000
#   Используемый_антибиотик_ДО_развития_SOFA_8_и_более: 0.0000
#   Левофлоксацин_антибиотик_ДО_развития_SOFA_8_и_более: 0.0000
#   Линезолид_антибиотик_ДО_развития_SOFA_8_и_более: 0.0000
#   Меропенем_антибиотик_ДО_развития_SOFA_8_и_более: 0.0000
#   Метронидазол_антибиотик_ДО_развития_SOFA_8_и_более: 0.0000
#   Моксифлоксацин_антибиотик_ДО_развития_SOFA_8_и_более: 0.0000
#   Нифуроксазид_антибиотик_ДО_развития_SOFA_8_и_более: 0.0000
#   Фосфомицин_антибиотик_ДО_развития_SOFA_8_и_более: 0.0000
#   Цефазолин_антибиотик_ДО_развития_SOFA_8_и_более: 0.0000
#   Сульбактам_антибиотик_ДО_развития_SOFA_8_и_более: 0.0000
#   Цефоперазон_антибиотик_ДО_развития_SOFA_8_и_более: 0.0000
#   Количество_часов_применения_антибиотика_ДО_развития_SOFA_8_и_более: 0.0000
#   Антибиотик_после_развития_SOFA_8_и_более: 0.0000
#   Моксифлоксацин_после_развития_SOFA_8_и_более: 0.0000
#   Левофлоксацин_после_развития_SOFA_8_и_более: 0.0000
#   Азитромицин_после_развития_SOFA_8_и_более: 0.0000
#   Линезолид_после_развития_SOFA_8_и_более: 0.0000
#   Меропенем_после_развития_SOFA_8_и_более: 0.0000
#   Метронидазол_после_развития_SOFA_8_и_более: 0.0000
#   Нифуроксазид_после_развития_SOFA_8_и_более: 0.0000
#   Фосфомицин_после_развития_SOFA_8_и_более: 0.0000
#   Цефазолин_после_развития_SOFA_8_и_более: 0.0000
#   Сульбактам_после_развития_SOFA_8_и_более: 0.0000
#   Цефепим_после_развития_SOFA_8_и_более: 0.0000
#   Цефтриаксон_после_развития_SOFA_8_и_более: 0.0000
#   Через_сколько_часов_после_развития_SOFA_8_и_более_был_введен_антибиотик: 0.0000
#   APACHE_сутки_до_развития_SOFA_8_и_более: 0.0000
#   АД_среднее_за_сутки_до_развития_SOFA_8: 0.0000
#   Среднее_АД_1_сутки_в_орит: 0.0000
#   Минимальное_АД_1_сут: 0.0000
#   Макс_АД_1_сут: 0.0000
#   Среднее_АД_3_сутки_в_орит: 0.0000
#   Среднее_АД_7_сутки_в_орит: 0.0000
#   Минимальное_АД_7_сут: 0.0000
#   Макс_АД_7_сут: 0.0000
#   Среднее_ЧСС_1_сутки: 0.0000
#   Мин_ЧСС_1_сутки: 0.0000
#   Среднее_ЧСС_3_сутки: 0.0000
#   Мин_ЧСС_3_сутки: 0.0000
#   Максимальное_ЧСС_3_сутки: 0.0000
#   Среднее_ЧСС_7_сутки: 0.0000
#   Мин_ЧСС_7_сутки: 0.0000
#   Максимальное_ЧСС_7_сутки: 0.0000
#   Лейкоциты_больше_9_до_назначения_аб: 0.0000
#   ИВЛ: 0.0000
#   Вазопрессорная_поддержка: 0.0000
#   Норадреналин: 0.0000
#   Левосимендан: 0.0000
#   Max_Добутамин: 0.0000
#   Max_Допмин: 0.0000
#   Max_Мезатона: 0.0000
#   UA_нестабильная_стенокардия: 0.0000
#   Натрий_Na_b: 0.0000
#   Калий_K_b: 0.0000
#   Кальций_ионизированный_Ca+_a: 0.0000
#   Кальций_ионизированный_Ca+: 0.0000
#   pHARTmin_b: 0.0000
#   pHARTmin_a: 0.0000
#   pHARTmax_b: 0.0000
#   pHARTmax_a: 0.0000
#   pO2ARTmin_a: 0.0000
#   pO2ARTmax_b: 0.0000
#   pCO2min_b: 0.0000
#   pCO2min_a: 0.0000
#   pCO2max_a: 0.0000
#   SaO2max_b: 0.0000
#   SaO2max_a: 0.0000
#   SaO2max: 0.0000
#   LACTartMax: 0.0000
#   BEArtMin: 0.0000
#   BEArtMax_b: 0.0000
#   HCO3ArtMin_b: 0.0000
#   HCO3ArtMin_a: 0.0000
#   HCO3ArtMax_b: 0.0000
#   HCO3ArtMax_a: 0.0000
#   HCO3ArtMax: 0.0000
#   PHVenMin_b: 0.0000
#   PHVenMax_a: 0.0000
#   PO2VenMin_b: 0.0000
#   PO2VenMin_a: 0.0000
#   PO2VenMin: 0.0000
#   PO2VenMax_a: 0.0000
#   PO2VenMax: 0.0000
#   PCO2VenMin_b: 0.0000
#   PCO2VenMin_a: 0.0000
#   PCO2VenMin: 0.0000
#   PCO2VenMax_b: 0.0000
#   PCO2VenMax_a: 0.0000
#   PCO2VenMax: 0.0000
#   ScvO2Min_b: 0.0000
#   ScvO2Min_a: 0.0000
#   ScvO2Min: 0.0000
#   ScvO2Max_b: 0.0000
#   ScvO2Max_a: 0.0000
#   ScvO2Max: 0.0000
#   LactVenMin_a: 0.0000
#   LactVenMax_b: 0.0000
#   LactVenMax: 0.0000
#   BEVenMax_a: 0.0000
#   HCO3VenMin: 0.0000
#   HCO3VenMax_a: 0.0000
#   BNP_b: 0.0000
#   BNP: 0.0000
