# %%
from my_library import do_magic

# %%
import pandas as pd

# %%
df = pd.read_excel("../../../../data_raw/DataSet_V49 (2).xlsx")

print(f"Данные успешно загружены! Размер: {df.shape}")
print(f"Занимаемая память: {df.memory_usage(deep=True).sum() / 1024**2:.2f} MB")
# Out:
# Данные успешно загружены! Размер: (17430, 465)
# Занимаемая память: 189.51 MB

# %%
cols = ['Смерть', 'Age', 'Sex', 'Рост', 'Вес', 'Индекс массы тела']

# %%
df = df[cols]

# %%
df
# Out:
#       Смерть   Age Sex   Рост    Вес  Индекс массы тела
# 0        Нет  78.0   М  168.0   75.0                NaN
# 1        Нет  80.0   Ж  160.0   55.0          21.480000
# 2        Нет  40.0   М  185.0   90.0          26.300000
# 3        Нет  78.0   М  180.0   98.0                NaN
# 4         Да  75.0   М  185.0   76.0          22.205990
# ...      ...   ...  ..    ...    ...                ...
# 17425    Нет  60.0   М  176.0   98.0          31.637397
# 17426    Нет  81.0   Ж  165.0   78.0          28.650138
# 17427    Нет  48.0   М  178.0  110.0          34.717839
# 17428    Нет  50.0   М  170.0   65.0          22.491349
# 17429    Нет  53.0   М  175.0   78.0          25.469388
#
# [17430 rows x 6 columns]

# %%
do_magic(df)
# Out:
# ## 📊 Базовая информация о датасете
# ### 💾 Информация о типах данных
# ```
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17430 entries, 0 to 17429
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Смерть             16613 non-null  object
#  1   Age                17406 non-null  float64
#  2   Sex                17355 non-null  object
#  3   Рост               16485 non-null  float64
#  4   Вес                16501 non-null  float64
#  5   Индекс массы тела  12859 non-null  float64
# dtypes: float64(4), object(2)
# memory usage: 817.2+ KB
#
# ```
# <style type="text/css">
# #T_29112_row0_col4, #T_29112_row2_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_29112_row1_col4 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_29112_row3_col4 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_29112_row4_col4 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_29112_row5_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_29112">
#   <caption>DataFrame Schema Overview</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_29112_level0_col0" class="col_heading level0 col0" >Column</th>
#       <th id="T_29112_level0_col1" class="col_heading level0 col1" >Type</th>
#       <th id="T_29112_level0_col2" class="col_heading level0 col2" >First Value</th>
#       <th id="T_29112_level0_col3" class="col_heading level0 col3" >Last Value</th>
#       <th id="T_29112_level0_col4" class="col_heading level0 col4" >Unique Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_29112_level0_row0" class="row_heading level0 row0" >Смерть</th>
#       <td id="T_29112_row0_col0" class="data row0 col0" >Смерть</td>
#       <td id="T_29112_row0_col1" class="data row0 col1" >object</td>
#       <td id="T_29112_row0_col2" class="data row0 col2" >Нет</td>
#       <td id="T_29112_row0_col3" class="data row0 col3" >Нет</td>
#       <td id="T_29112_row0_col4" class="data row0 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_29112_level0_row1" class="row_heading level0 row1" >Age</th>
#       <td id="T_29112_row1_col0" class="data row1 col0" >Age</td>
#       <td id="T_29112_row1_col1" class="data row1 col1" >float64</td>
#       <td id="T_29112_row1_col2" class="data row1 col2" >78.00</td>
#       <td id="T_29112_row1_col3" class="data row1 col3" >53.00</td>
#       <td id="T_29112_row1_col4" class="data row1 col4" >79</td>
#     </tr>
#     <tr>
#       <th id="T_29112_level0_row2" class="row_heading level0 row2" >Sex</th>
#       <td id="T_29112_row2_col0" class="data row2 col0" >Sex</td>
#       <td id="T_29112_row2_col1" class="data row2 col1" >object</td>
#       <td id="T_29112_row2_col2" class="data row2 col2" >М</td>
#       <td id="T_29112_row2_col3" class="data row2 col3" >М</td>
#       <td id="T_29112_row2_col4" class="data row2 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_29112_level0_row3" class="row_heading level0 row3" >Рост</th>
#       <td id="T_29112_row3_col0" class="data row3 col0" >Рост</td>
#       <td id="T_29112_row3_col1" class="data row3 col1" >float64</td>
#       <td id="T_29112_row3_col2" class="data row3 col2" >168.00</td>
#       <td id="T_29112_row3_col3" class="data row3 col3" >175.00</td>
#       <td id="T_29112_row3_col4" class="data row3 col4" >62</td>
#     </tr>
#     <tr>
#       <th id="T_29112_level0_row4" class="row_heading level0 row4" >Вес</th>
#       <td id="T_29112_row4_col0" class="data row4 col0" >Вес</td>
#       <td id="T_29112_row4_col1" class="data row4 col1" >float64</td>
#       <td id="T_29112_row4_col2" class="data row4 col2" >75.00</td>
#       <td id="T_29112_row4_col3" class="data row4 col3" >78.00</td>
#       <td id="T_29112_row4_col4" class="data row4 col4" >155</td>
#     </tr>
#     <tr>
#       <th id="T_29112_level0_row5" class="row_heading level0 row5" >Индекс массы тела</th>
#       <td id="T_29112_row5_col0" class="data row5 col0" >Индекс массы тела</td>
#       <td id="T_29112_row5_col1" class="data row5 col1" >float64</td>
#       <td id="T_29112_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_29112_row5_col3" class="data row5 col3" >25.47</td>
#       <td id="T_29112_row5_col4" class="data row5 col4" >2625</td>
#     </tr>
#   </tbody>
# </table>
# ### 📈 Описательная статистика числовых признаков
# <style type="text/css">
# #T_eaa5e_row0_col0, #T_eaa5e_row1_col1, #T_eaa5e_row1_col3, #T_eaa5e_row1_col4, #T_eaa5e_row1_col5, #T_eaa5e_row1_col6, #T_eaa5e_row1_col7, #T_eaa5e_row2_col2 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_eaa5e_row0_col1 {
#   background-color: #3c508b;
#   color: #f1f1f1;
# }
# #T_eaa5e_row0_col2 {
#   background-color: #1f9a8a;
#   color: #f1f1f1;
# }
# #T_eaa5e_row0_col3 {
#   background-color: #481b6d;
#   color: #f1f1f1;
# }
# #T_eaa5e_row0_col4 {
#   background-color: #3e4989;
#   color: #f1f1f1;
# }
# #T_eaa5e_row0_col5 {
#   background-color: #3a538b;
#   color: #f1f1f1;
# }
# #T_eaa5e_row0_col6 {
#   background-color: #38598c;
#   color: #f1f1f1;
# }
# #T_eaa5e_row0_col7 {
#   background-color: #46075a;
#   color: #f1f1f1;
# }
# #T_eaa5e_row1_col0 {
#   background-color: #7ad151;
#   color: #000000;
# }
# #T_eaa5e_row1_col2 {
#   background-color: #9bd93c;
#   color: #000000;
# }
# #T_eaa5e_row2_col0 {
#   background-color: #7cd250;
#   color: #000000;
# }
# #T_eaa5e_row2_col1 {
#   background-color: #2c738e;
#   color: #f1f1f1;
# }
# #T_eaa5e_row2_col3 {
#   background-color: #3d4d8a;
#   color: #f1f1f1;
# }
# #T_eaa5e_row2_col4 {
#   background-color: #31688e;
#   color: #f1f1f1;
# }
# #T_eaa5e_row2_col5 {
#   background-color: #2d718e;
#   color: #f1f1f1;
# }
# #T_eaa5e_row2_col6 {
#   background-color: #297a8e;
#   color: #f1f1f1;
# }
# #T_eaa5e_row2_col7 {
#   background-color: #482374;
#   color: #f1f1f1;
# }
# #T_eaa5e_row3_col0, #T_eaa5e_row3_col1, #T_eaa5e_row3_col2, #T_eaa5e_row3_col3, #T_eaa5e_row3_col4, #T_eaa5e_row3_col5, #T_eaa5e_row3_col6, #T_eaa5e_row3_col7 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_eaa5e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eaa5e_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_eaa5e_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_eaa5e_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_eaa5e_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_eaa5e_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_eaa5e_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_eaa5e_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_eaa5e_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eaa5e_level0_row0" class="row_heading level0 row0" >Age</th>
#       <td id="T_eaa5e_row0_col0" class="data row0 col0" >17406.000000</td>
#       <td id="T_eaa5e_row0_col1" class="data row0 col1" >63.263128</td>
#       <td id="T_eaa5e_row0_col2" class="data row0 col2" >10.747807</td>
#       <td id="T_eaa5e_row0_col3" class="data row0 col3" >17.000000</td>
#       <td id="T_eaa5e_row0_col4" class="data row0 col4" >56.000000</td>
#       <td id="T_eaa5e_row0_col5" class="data row0 col5" >64.000000</td>
#       <td id="T_eaa5e_row0_col6" class="data row0 col6" >71.000000</td>
#       <td id="T_eaa5e_row0_col7" class="data row0 col7" >97.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eaa5e_level0_row1" class="row_heading level0 row1" >Рост</th>
#       <td id="T_eaa5e_row1_col0" class="data row1 col0" >16485.000000</td>
#       <td id="T_eaa5e_row1_col1" class="data row1 col1" >170.378101</td>
#       <td id="T_eaa5e_row1_col2" class="data row1 col2" >14.088637</td>
#       <td id="T_eaa5e_row1_col3" class="data row1 col3" >105.000000</td>
#       <td id="T_eaa5e_row1_col4" class="data row1 col4" >165.000000</td>
#       <td id="T_eaa5e_row1_col5" class="data row1 col5" >170.000000</td>
#       <td id="T_eaa5e_row1_col6" class="data row1 col6" >176.000000</td>
#       <td id="T_eaa5e_row1_col7" class="data row1 col7" >1625.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eaa5e_level0_row2" class="row_heading level0 row2" >Вес</th>
#       <td id="T_eaa5e_row2_col0" class="data row2 col0" >16501.000000</td>
#       <td id="T_eaa5e_row2_col1" class="data row2 col1" >82.409187</td>
#       <td id="T_eaa5e_row2_col2" class="data row2 col2" >15.700054</td>
#       <td id="T_eaa5e_row2_col3" class="data row2 col3" >32.000000</td>
#       <td id="T_eaa5e_row2_col4" class="data row2 col4" >72.000000</td>
#       <td id="T_eaa5e_row2_col5" class="data row2 col5" >80.000000</td>
#       <td id="T_eaa5e_row2_col6" class="data row2 col6" >90.000000</td>
#       <td id="T_eaa5e_row2_col7" class="data row2 col7" >220.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eaa5e_level0_row3" class="row_heading level0 row3" >Индекс массы тела</th>
#       <td id="T_eaa5e_row3_col0" class="data row3 col0" >12859.000000</td>
#       <td id="T_eaa5e_row3_col1" class="data row3 col1" >28.503481</td>
#       <td id="T_eaa5e_row3_col2" class="data row3 col2" >4.939003</td>
#       <td id="T_eaa5e_row3_col3" class="data row3 col3" >10.080000</td>
#       <td id="T_eaa5e_row3_col4" class="data row3 col4" >25.209201</td>
#       <td id="T_eaa5e_row3_col5" class="data row3 col5" >27.760000</td>
#       <td id="T_eaa5e_row3_col6" class="data row3 col6" >31.140000</td>
#       <td id="T_eaa5e_row3_col7" class="data row3 col7" >72.562358</td>
#     </tr>
#   </tbody>
# </table>
# ### 👀 Первые 5 строк данных
#   Смерть   Age Sex   Рост   Вес  Индекс массы тела
# 0    Нет  78.0   М  168.0  75.0                NaN
# 1    Нет  80.0   Ж  160.0  55.0           21.48000
# 2    Нет  40.0   М  185.0  90.0           26.30000
# 3    Нет  78.0   М  180.0  98.0                NaN
# 4     Да  75.0   М  185.0  76.0           22.20599
# ### 👀 Последние 5 строк данных
#       Смерть   Age Sex   Рост    Вес  Индекс массы тела
# 17425    Нет  60.0   М  176.0   98.0          31.637397
# 17426    Нет  81.0   Ж  165.0   78.0          28.650138
# 17427    Нет  48.0   М  178.0  110.0          34.717839
# 17428    Нет  50.0   М  170.0   65.0          22.491349
# 17429    Нет  53.0   М  175.0   78.0          25.469388
# ### 🔍 Анализ уникальных значений (первые 10 столбцов)
#                   unique_count                                      unique_values    dtype
# Смерть                       2                                     [Нет, Да, nan]   object
# Age                         79  [78.0, 80.0, 40.0, 75.0, 61.0, 69.0, 67.0, 49....  float64
# Sex                          2                                        [М, Ж, nan]   object
# Рост                        62  [168.0, 160.0, 185.0, 180.0, 172.0, 167.0, 173...  float64
# Вес                        155  [75.0, 55.0, 90.0, 98.0, 76.0, 105.0, 95.0, 74...  float64
# Индекс массы тела         2625  [nan, 21.48, 26.3, 22.20598977355734, 26.53375...  float64
# ## ⚖️ Анализ дисбаланса классов
# ### Целевая переменная: `Смерть`
# <style type="text/css">
# #T_fde40_row0_col0, #T_fde40_row1_col1, #T_fde40_row1_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_fde40_row0_col1, #T_fde40_row0_col2, #T_fde40_row1_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_fde40">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fde40_level0_col0" class="col_heading level0 col0" >Класс</th>
#       <th id="T_fde40_level0_col1" class="col_heading level0 col1" >Количество</th>
#       <th id="T_fde40_level0_col2" class="col_heading level0 col2" >Процент</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fde40_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fde40_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_fde40_row0_col1" class="data row0 col1" >16038</td>
#       <td id="T_fde40_row0_col2" class="data row0 col2" >92.013769</td>
#     </tr>
#     <tr>
#       <th id="T_fde40_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fde40_row1_col0" class="data row1 col0" >1.000000</td>
#       <td id="T_fde40_row1_col1" class="data row1 col1" >575</td>
#       <td id="T_fde40_row1_col2" class="data row1 col2" >3.298910</td>
#     </tr>
#   </tbody>
# </table>
# ### 📈 Степень дисбаланса: 27.9:1
# ⚠️ **Сильный дисбаланс!** Требуются специальные методы обработки.
# ## 🕳️ Анализ пропущенных значений
# ### 📊 Общая статистика по пропускам:
# - Всего столбцов с пропусками: 6 из 6
# - Средний процент пропусков: 7.04%
# - Максимальный процент пропусков: 26.22%
# ### 🏆 Топ-20 столбцов с наибольшими пропусками:
# <style type="text/css">
# #T_644bc_row0_col1 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_644bc_row1_col1 {
#   background-color: #fee187;
#   color: #000000;
# }
# #T_644bc_row2_col1 {
#   background-color: #fee288;
#   color: #000000;
# }
# #T_644bc_row3_col1 {
#   background-color: #ffe590;
#   color: #000000;
# }
# #T_644bc_row4_col1 {
#   background-color: #fffec9;
#   color: #000000;
# }
# #T_644bc_row5_col1 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# </style>
# <table id="T_644bc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_644bc_level0_col0" class="col_heading level0 col0" >Столбец</th>
#       <th id="T_644bc_level0_col1" class="col_heading level0 col1" >Процент пропусков</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_644bc_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_644bc_row0_col0" class="data row0 col0" >Индекс массы тела</td>
#       <td id="T_644bc_row0_col1" class="data row0 col1" >26.224900</td>
#     </tr>
#     <tr>
#       <th id="T_644bc_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_644bc_row1_col0" class="data row1 col0" >Рост</td>
#       <td id="T_644bc_row1_col1" class="data row1 col1" >5.421687</td>
#     </tr>
#     <tr>
#       <th id="T_644bc_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_644bc_row2_col0" class="data row2 col0" >Вес</td>
#       <td id="T_644bc_row2_col1" class="data row2 col1" >5.329891</td>
#     </tr>
#     <tr>
#       <th id="T_644bc_level0_row3" class="row_heading level0 row3" >0</th>
#       <td id="T_644bc_row3_col0" class="data row3 col0" >Смерть</td>
#       <td id="T_644bc_row3_col1" class="data row3 col1" >4.687321</td>
#     </tr>
#     <tr>
#       <th id="T_644bc_level0_row4" class="row_heading level0 row4" >2</th>
#       <td id="T_644bc_row4_col0" class="data row4 col0" >Sex</td>
#       <td id="T_644bc_row4_col1" class="data row4 col1" >0.430293</td>
#     </tr>
#     <tr>
#       <th id="T_644bc_level0_row5" class="row_heading level0 row5" >1</th>
#       <td id="T_644bc_row5_col0" class="data row5 col0" >Age</td>
#       <td id="T_644bc_row5_col1" class="data row5 col1" >0.137694</td>
#     </tr>
#   </tbody>
# </table>
# ### 🎯 Анализ пропусков в контексте целевой переменной
# #### Столбец: `Индекс массы тела`
# **Абсолютные значения:**
# Индекс массы тела  Значение  Пропуск  Всего
# Смерть
# 0.0                   12453     3585  16038
# 1.0                     379      196    575
# Всего                 12832     3781  16613
# **Проценты:**
# <style type="text/css">
# </style>
# <table id="T_d2eeb">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Индекс массы тела</th>
#       <th id="T_d2eeb_level0_col0" class="col_heading level0 col0" >Значение</th>
#       <th id="T_d2eeb_level0_col1" class="col_heading level0 col1" >Пропуск</th>
#       <th id="T_d2eeb_level0_col2" class="col_heading level0 col2" >Всего</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Смерть</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d2eeb_level0_row0" class="row_heading level0 row0" >0.000000</th>
#       <td id="T_d2eeb_row0_col0" class="data row0 col0" >97.0%</td>
#       <td id="T_d2eeb_row0_col1" class="data row0 col1" >94.8%</td>
#       <td id="T_d2eeb_row0_col2" class="data row0 col2" >96.5%</td>
#     </tr>
#     <tr>
#       <th id="T_d2eeb_level0_row1" class="row_heading level0 row1" >1.000000</th>
#       <td id="T_d2eeb_row1_col0" class="data row1 col0" >3.0%</td>
#       <td id="T_d2eeb_row1_col1" class="data row1 col1" >5.2%</td>
#       <td id="T_d2eeb_row1_col2" class="data row1 col2" >3.5%</td>
#     </tr>
#     <tr>
#       <th id="T_d2eeb_level0_row2" class="row_heading level0 row2" >Всего</th>
#       <td id="T_d2eeb_row2_col0" class="data row2 col0" >100.0%</td>
#       <td id="T_d2eeb_row2_col1" class="data row2 col1" >100.0%</td>
#       <td id="T_d2eeb_row2_col2" class="data row2 col2" >100.0%</td>
#     </tr>
#   </tbody>
# </table>
# #### Столбец: `Рост`
# **Абсолютные значения:**
# Рост    Значение  Пропуск  Всего
# Смерть
# 0.0        15349      689  16038
# 1.0          486       89    575
# Всего      15835      778  16613
# **Проценты:**
# <style type="text/css">
# </style>
# <table id="T_d584e">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Рост</th>
#       <th id="T_d584e_level0_col0" class="col_heading level0 col0" >Значение</th>
#       <th id="T_d584e_level0_col1" class="col_heading level0 col1" >Пропуск</th>
#       <th id="T_d584e_level0_col2" class="col_heading level0 col2" >Всего</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Смерть</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d584e_level0_row0" class="row_heading level0 row0" >0.000000</th>
#       <td id="T_d584e_row0_col0" class="data row0 col0" >96.9%</td>
#       <td id="T_d584e_row0_col1" class="data row0 col1" >88.6%</td>
#       <td id="T_d584e_row0_col2" class="data row0 col2" >96.5%</td>
#     </tr>
#     <tr>
#       <th id="T_d584e_level0_row1" class="row_heading level0 row1" >1.000000</th>
#       <td id="T_d584e_row1_col0" class="data row1 col0" >3.1%</td>
#       <td id="T_d584e_row1_col1" class="data row1 col1" >11.4%</td>
#       <td id="T_d584e_row1_col2" class="data row1 col2" >3.5%</td>
#     </tr>
#     <tr>
#       <th id="T_d584e_level0_row2" class="row_heading level0 row2" >Всего</th>
#       <td id="T_d584e_row2_col0" class="data row2 col0" >100.0%</td>
#       <td id="T_d584e_row2_col1" class="data row2 col1" >100.0%</td>
#       <td id="T_d584e_row2_col2" class="data row2 col2" >100.0%</td>
#     </tr>
#   </tbody>
# </table>
# #### Столбец: `Вес`
# **Абсолютные значения:**
# Вес     Значение  Пропуск  Всего
# Смерть
# 0.0        15362      676  16038
# 1.0          486       89    575
# Всего      15848      765  16613
# **Проценты:**
# <style type="text/css">
# </style>
# <table id="T_9e7bf">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Вес</th>
#       <th id="T_9e7bf_level0_col0" class="col_heading level0 col0" >Значение</th>
#       <th id="T_9e7bf_level0_col1" class="col_heading level0 col1" >Пропуск</th>
#       <th id="T_9e7bf_level0_col2" class="col_heading level0 col2" >Всего</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Смерть</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9e7bf_level0_row0" class="row_heading level0 row0" >0.000000</th>
#       <td id="T_9e7bf_row0_col0" class="data row0 col0" >96.9%</td>
#       <td id="T_9e7bf_row0_col1" class="data row0 col1" >88.4%</td>
#       <td id="T_9e7bf_row0_col2" class="data row0 col2" >96.5%</td>
#     </tr>
#     <tr>
#       <th id="T_9e7bf_level0_row1" class="row_heading level0 row1" >1.000000</th>
#       <td id="T_9e7bf_row1_col0" class="data row1 col0" >3.1%</td>
#       <td id="T_9e7bf_row1_col1" class="data row1 col1" >11.6%</td>
#       <td id="T_9e7bf_row1_col2" class="data row1 col2" >3.5%</td>
#     </tr>
#     <tr>
#       <th id="T_9e7bf_level0_row2" class="row_heading level0 row2" >Всего</th>
#       <td id="T_9e7bf_row2_col0" class="data row2 col0" >100.0%</td>
#       <td id="T_9e7bf_row2_col1" class="data row2 col1" >100.0%</td>
#       <td id="T_9e7bf_row2_col2" class="data row2 col2" >100.0%</td>
#     </tr>
#   </tbody>
# </table>
# #### Столбец: `Sex`
# **Абсолютные значения:**
# Sex     Значение  Пропуск  Всего
# Смерть
# 0.0        16000       38  16038
# 1.0          573        2    575
# Всего      16573       40  16613
# **Проценты:**
# <style type="text/css">
# </style>
# <table id="T_89234">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th id="T_89234_level0_col0" class="col_heading level0 col0" >Значение</th>
#       <th id="T_89234_level0_col1" class="col_heading level0 col1" >Пропуск</th>
#       <th id="T_89234_level0_col2" class="col_heading level0 col2" >Всего</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Смерть</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_89234_level0_row0" class="row_heading level0 row0" >0.000000</th>
#       <td id="T_89234_row0_col0" class="data row0 col0" >96.5%</td>
#       <td id="T_89234_row0_col1" class="data row0 col1" >95.0%</td>
#       <td id="T_89234_row0_col2" class="data row0 col2" >96.5%</td>
#     </tr>
#     <tr>
#       <th id="T_89234_level0_row1" class="row_heading level0 row1" >1.000000</th>
#       <td id="T_89234_row1_col0" class="data row1 col0" >3.5%</td>
#       <td id="T_89234_row1_col1" class="data row1 col1" >5.0%</td>
#       <td id="T_89234_row1_col2" class="data row1 col2" >3.5%</td>
#     </tr>
#     <tr>
#       <th id="T_89234_level0_row2" class="row_heading level0 row2" >Всего</th>
#       <td id="T_89234_row2_col0" class="data row2 col0" >100.0%</td>
#       <td id="T_89234_row2_col1" class="data row2 col1" >100.0%</td>
#       <td id="T_89234_row2_col2" class="data row2 col2" >100.0%</td>
#     </tr>
#   </tbody>
# </table>
# Собрано 5 цифровых колонок
# ## 🔍 Поиск утечек данных (data leaks)
# ### 📈 Поиск признаков с крайне высокой корреляцией с target
# ### Числовые признаки для анализа: 4 из 6
# ### 📊 Топ-20 признаков по корреляции с target:
# <style type="text/css">
# #T_03c19_row0_col1 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_03c19_row1_col1 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_03c19_row2_col1, #T_03c19_row3_col1 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# </style>
# <table id="T_03c19">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_03c19_level0_col0" class="col_heading level0 col0" >Признак</th>
#       <th id="T_03c19_level0_col1" class="col_heading level0 col1" >Корреляция с target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_03c19_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_03c19_row0_col0" class="data row0 col0" >Age</td>
#       <td id="T_03c19_row0_col1" class="data row0 col1" >0.118773</td>
#     </tr>
#     <tr>
#       <th id="T_03c19_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_03c19_row1_col0" class="data row1 col0" >Вес</td>
#       <td id="T_03c19_row1_col1" class="data row1 col1" >-0.042440</td>
#     </tr>
#     <tr>
#       <th id="T_03c19_level0_row2" class="row_heading level0 row2" >1</th>
#       <td id="T_03c19_row2_col0" class="data row2 col0" >Рост</td>
#       <td id="T_03c19_row2_col1" class="data row2 col1" >-0.029776</td>
#     </tr>
#     <tr>
#       <th id="T_03c19_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_03c19_row3_col0" class="data row3 col0" >Индекс массы тела</td>
#       <td id="T_03c19_row3_col1" class="data row3 col1" >-0.028389</td>
#     </tr>
#   </tbody>
# </table>
# ✅ Не обнаружено признаков с экстремально высокой корреляцией (потенциальных утечек)
# ## 🏷️ Анализ категориальных признаков на предмет утечек
# ### Категориальные признаки для анализа: 1
# ### 🔍 Поиск категориальных признаков с идеальным разделением классов
# ✅ Не обнаружено категориальных признаков с идеальным разделением классов
# ## 📐 Анализ мультиколлинеарности признаков
# ✅ Не обнаружено признаков с экстремально высокой корреляцией между собой
# ## 📈 Анализ распределений признаков по классам target
# ### Распределения топ-4 признаков по классам target:
# ❌ **Данные не загружены!** Выполните сначала ячейки с EDA и загрузкой данных.
# ### 🗑️ Удалено 817 строк с пропусками в целевой переменной
# ## ⚖️ Финальный дисбаланс классов:
# <style type="text/css">
# #T_ff2a6_row0_col0, #T_ff2a6_row1_col1, #T_ff2a6_row1_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_ff2a6_row0_col1, #T_ff2a6_row0_col2, #T_ff2a6_row1_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ff2a6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff2a6_level0_col0" class="col_heading level0 col0" >Класс</th>
#       <th id="T_ff2a6_level0_col1" class="col_heading level0 col1" >Количество</th>
#       <th id="T_ff2a6_level0_col2" class="col_heading level0 col2" >Процент</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff2a6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ff2a6_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_ff2a6_row0_col1" class="data row0 col1" >16038</td>
#       <td id="T_ff2a6_row0_col2" class="data row0 col2" >96.538855</td>
#     </tr>
#     <tr>
#       <th id="T_ff2a6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ff2a6_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_ff2a6_row1_col1" class="data row1 col1" >575</td>
#       <td id="T_ff2a6_row1_col2" class="data row1 col2" >3.461145</td>
#     </tr>
#   </tbody>
# </table>
# ## 🕳️ Шаг 2: Стратегическая обработка пропусков
# ✅ Нет признаков для удаления по критерию >70% пропусков
# ### 📊 Распределение типов признаков:
# - **Числовых признаков:** 4
# - **Категориальных признаков:** 1
# - **Всего признаков:** 5
# ### 🔍 Примеры категориальных признаков:
# - `Sex`: примеры значений ['М' 'Ж']
# ### 🔄 Кодирование категориальных признаков
# ✅ Бинарное кодирование: `Sex` → 0/1
# ### 📈 Размер после кодирования: 16613 строк, 5 столбцов
# ### 🔍 Поиск признаков, присутствующих только в одном классе
# ✅ Не обнаружено признаков, присутствующих только в одном классе
# ## 🔍 Шаг 3: Отбор признаков
# ### 📐 Устранение мультиколлинеарности
# ℹ️ Недостаточно числовых признаков для анализа мультиколлинеарности
# ### 🎯 Финальный отбор признаков
# ### 📊 Финальные признаки для моделирования: 5
# ['Age', 'Sex', 'Рост', 'Вес', 'Индекс массы тела']
# ## 📊 Шаг 4: Стратифицированное разделение данных
# ### Пример данных после проведения всех манипуляций
#         Age  Sex   Рост    Вес  Индекс массы тела
# 12998  54.0  0.0  190.0   95.0          26.320000
# 15288  77.0  1.0  175.0   85.0          27.760000
# 5071   81.0  1.0  164.0   84.0          26.790000
# 13167  75.0  1.0  160.0   65.0          25.390000
# 2830   72.0  0.0  170.0   68.0                NaN
# ...     ...  ...    ...    ...                ...
# 15957  51.0  0.0  171.0  114.0          38.990000
# 7875   79.0  1.0  169.0   89.0          31.161374
# 17038  64.0  0.0  175.0   85.0          27.755102
# 2229   54.0  1.0  158.0   80.0          32.046146
# 16789  67.0  0.0  170.0   70.0          24.221453
#
# [9967 rows x 5 columns]
# ### ✅ Успешное разделение данных!
# **Размеры наборов:**
# - Train: 9967 (3.5% класса 1)
# - Validation: 3323 (3.5% класса 1)
# - Test: 3323 (3.5% класса 1)
# **Проверка стратификации (процент minority класса):**
# <style type="text/css">
# #T_5e124_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_5e124_row1_col1, #T_5e124_row2_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_5e124">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5e124_level0_col0" class="col_heading level0 col0" >Набор</th>
#       <th id="T_5e124_level0_col1" class="col_heading level0 col1" >Процент класса 1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e124_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5e124_row0_col0" class="data row0 col0" >Train</td>
#       <td id="T_5e124_row0_col1" class="data row0 col1" >3.461423</td>
#     </tr>
#     <tr>
#       <th id="T_5e124_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5e124_row1_col0" class="data row1 col0" >Validation</td>
#       <td id="T_5e124_row1_col1" class="data row1 col1" >3.460728</td>
#     </tr>
#     <tr>
#       <th id="T_5e124_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5e124_row2_col0" class="data row2 col0" >Test</td>
#       <td id="T_5e124_row2_col1" class="data row2 col1" >3.460728</td>
#     </tr>
#   </tbody>
# </table>
# ## 📊 Базовая информация о датасете
# ### 💾 Информация о типах данных
# ```
# <class 'pandas.core.frame.DataFrame'>
# Index: 16613 entries, 0 to 17429
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Age                16608 non-null  float64
#  1   Sex                16573 non-null  float64
#  2   Рост               15835 non-null  float64
#  3   Вес                15848 non-null  float64
#  4   Индекс массы тела  12832 non-null  float64
# dtypes: float64(5)
# memory usage: 778.7 KB
#
# ```
# <style type="text/css">
# #T_dbbca_row0_col4 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_dbbca_row1_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_dbbca_row2_col4 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_dbbca_row3_col4 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_dbbca_row4_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_dbbca">
#   <caption>DataFrame Schema Overview</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dbbca_level0_col0" class="col_heading level0 col0" >Column</th>
#       <th id="T_dbbca_level0_col1" class="col_heading level0 col1" >Type</th>
#       <th id="T_dbbca_level0_col2" class="col_heading level0 col2" >First Value</th>
#       <th id="T_dbbca_level0_col3" class="col_heading level0 col3" >Last Value</th>
#       <th id="T_dbbca_level0_col4" class="col_heading level0 col4" >Unique Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dbbca_level0_row0" class="row_heading level0 row0" >Age</th>
#       <td id="T_dbbca_row0_col0" class="data row0 col0" >Age</td>
#       <td id="T_dbbca_row0_col1" class="data row0 col1" >float64</td>
#       <td id="T_dbbca_row0_col2" class="data row0 col2" >78.00</td>
#       <td id="T_dbbca_row0_col3" class="data row0 col3" >53.00</td>
#       <td id="T_dbbca_row0_col4" class="data row0 col4" >78</td>
#     </tr>
#     <tr>
#       <th id="T_dbbca_level0_row1" class="row_heading level0 row1" >Sex</th>
#       <td id="T_dbbca_row1_col0" class="data row1 col0" >Sex</td>
#       <td id="T_dbbca_row1_col1" class="data row1 col1" >float64</td>
#       <td id="T_dbbca_row1_col2" class="data row1 col2" >0.00</td>
#       <td id="T_dbbca_row1_col3" class="data row1 col3" >0.00</td>
#       <td id="T_dbbca_row1_col4" class="data row1 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_dbbca_level0_row2" class="row_heading level0 row2" >Рост</th>
#       <td id="T_dbbca_row2_col0" class="data row2 col0" >Рост</td>
#       <td id="T_dbbca_row2_col1" class="data row2 col1" >float64</td>
#       <td id="T_dbbca_row2_col2" class="data row2 col2" >168.00</td>
#       <td id="T_dbbca_row2_col3" class="data row2 col3" >175.00</td>
#       <td id="T_dbbca_row2_col4" class="data row2 col4" >62</td>
#     </tr>
#     <tr>
#       <th id="T_dbbca_level0_row3" class="row_heading level0 row3" >Вес</th>
#       <td id="T_dbbca_row3_col0" class="data row3 col0" >Вес</td>
#       <td id="T_dbbca_row3_col1" class="data row3 col1" >float64</td>
#       <td id="T_dbbca_row3_col2" class="data row3 col2" >75.00</td>
#       <td id="T_dbbca_row3_col3" class="data row3 col3" >78.00</td>
#       <td id="T_dbbca_row3_col4" class="data row3 col4" >147</td>
#     </tr>
#     <tr>
#       <th id="T_dbbca_level0_row4" class="row_heading level0 row4" >Индекс массы тела</th>
#       <td id="T_dbbca_row4_col0" class="data row4 col0" >Индекс массы тела</td>
#       <td id="T_dbbca_row4_col1" class="data row4 col1" >float64</td>
#       <td id="T_dbbca_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_dbbca_row4_col3" class="data row4 col3" >25.47</td>
#       <td id="T_dbbca_row4_col4" class="data row4 col4" >2616</td>
#     </tr>
#   </tbody>
# </table>
# ### 📈 Описательная статистика числовых признаков
# <style type="text/css">
# #T_b22a0_row0_col0, #T_b22a0_row2_col1, #T_b22a0_row2_col3, #T_b22a0_row2_col4, #T_b22a0_row2_col5, #T_b22a0_row2_col6, #T_b22a0_row2_col7, #T_b22a0_row3_col2 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_b22a0_row0_col1 {
#   background-color: #2d718e;
#   color: #f1f1f1;
# }
# #T_b22a0_row0_col2 {
#   background-color: #38b977;
#   color: #f1f1f1;
# }
# #T_b22a0_row0_col3, #T_b22a0_row4_col5 {
#   background-color: #453882;
#   color: #f1f1f1;
# }
# #T_b22a0_row0_col4 {
#   background-color: #2f6b8e;
#   color: #f1f1f1;
# }
# #T_b22a0_row0_col5 {
#   background-color: #2c728e;
#   color: #f1f1f1;
# }
# #T_b22a0_row0_col6 {
#   background-color: #2a788e;
#   color: #f1f1f1;
# }
# #T_b22a0_row0_col7 {
#   background-color: #481769;
#   color: #f1f1f1;
# }
# #T_b22a0_row1_col0 {
#   background-color: #f8e621;
#   color: #000000;
# }
# #T_b22a0_row1_col1, #T_b22a0_row1_col2, #T_b22a0_row1_col3, #T_b22a0_row1_col4, #T_b22a0_row1_col5, #T_b22a0_row1_col6, #T_b22a0_row1_col7, #T_b22a0_row4_col0 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_b22a0_row2_col0 {
#   background-color: #77d153;
#   color: #000000;
# }
# #T_b22a0_row2_col2 {
#   background-color: #c2df23;
#   color: #000000;
# }
# #T_b22a0_row3_col0 {
#   background-color: #7ad151;
#   color: #000000;
# }
# #T_b22a0_row3_col1 {
#   background-color: #228c8d;
#   color: #f1f1f1;
# }
# #T_b22a0_row3_col3 {
#   background-color: #34618d;
#   color: #f1f1f1;
# }
# #T_b22a0_row3_col4 {
#   background-color: #26818e;
#   color: #f1f1f1;
# }
# #T_b22a0_row3_col5 {
#   background-color: #23898e;
#   color: #f1f1f1;
# }
# #T_b22a0_row3_col6 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_b22a0_row3_col7 {
#   background-color: #472a7a;
#   color: #f1f1f1;
# }
# #T_b22a0_row4_col1 {
#   background-color: #443983;
#   color: #f1f1f1;
# }
# #T_b22a0_row4_col2 {
#   background-color: #355e8d;
#   color: #f1f1f1;
# }
# #T_b22a0_row4_col3 {
#   background-color: #482374;
#   color: #f1f1f1;
# }
# #T_b22a0_row4_col4 {
#   background-color: #453581;
#   color: #f1f1f1;
# }
# #T_b22a0_row4_col6 {
#   background-color: #443b84;
#   color: #f1f1f1;
# }
# #T_b22a0_row4_col7 {
#   background-color: #471164;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b22a0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b22a0_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_b22a0_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_b22a0_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_b22a0_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_b22a0_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_b22a0_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_b22a0_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_b22a0_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b22a0_level0_row0" class="row_heading level0 row0" >Age</th>
#       <td id="T_b22a0_row0_col0" class="data row0 col0" >16608.000000</td>
#       <td id="T_b22a0_row0_col1" class="data row0 col1" >63.343750</td>
#       <td id="T_b22a0_row0_col2" class="data row0 col2" >10.677091</td>
#       <td id="T_b22a0_row0_col3" class="data row0 col3" >17.000000</td>
#       <td id="T_b22a0_row0_col4" class="data row0 col4" >57.000000</td>
#       <td id="T_b22a0_row0_col5" class="data row0 col5" >64.000000</td>
#       <td id="T_b22a0_row0_col6" class="data row0 col6" >71.000000</td>
#       <td id="T_b22a0_row0_col7" class="data row0 col7" >97.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b22a0_level0_row1" class="row_heading level0 row1" >Sex</th>
#       <td id="T_b22a0_row1_col0" class="data row1 col0" >16573.000000</td>
#       <td id="T_b22a0_row1_col1" class="data row1 col1" >0.332167</td>
#       <td id="T_b22a0_row1_col2" class="data row1 col2" >0.471005</td>
#       <td id="T_b22a0_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_b22a0_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_b22a0_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_b22a0_row1_col6" class="data row1 col6" >1.000000</td>
#       <td id="T_b22a0_row1_col7" class="data row1 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b22a0_level0_row2" class="row_heading level0 row2" >Рост</th>
#       <td id="T_b22a0_row2_col0" class="data row2 col0" >15835.000000</td>
#       <td id="T_b22a0_row2_col1" class="data row2 col1" >170.435554</td>
#       <td id="T_b22a0_row2_col2" class="data row2 col2" >14.248013</td>
#       <td id="T_b22a0_row2_col3" class="data row2 col3" >105.000000</td>
#       <td id="T_b22a0_row2_col4" class="data row2 col4" >165.000000</td>
#       <td id="T_b22a0_row2_col5" class="data row2 col5" >170.000000</td>
#       <td id="T_b22a0_row2_col6" class="data row2 col6" >176.000000</td>
#       <td id="T_b22a0_row2_col7" class="data row2 col7" >1625.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b22a0_level0_row3" class="row_heading level0 row3" >Вес</th>
#       <td id="T_b22a0_row3_col0" class="data row3 col0" >15848.000000</td>
#       <td id="T_b22a0_row3_col1" class="data row3 col1" >82.483651</td>
#       <td id="T_b22a0_row3_col2" class="data row3 col2" >15.609396</td>
#       <td id="T_b22a0_row3_col3" class="data row3 col3" >32.000000</td>
#       <td id="T_b22a0_row3_col4" class="data row3 col4" >72.000000</td>
#       <td id="T_b22a0_row3_col5" class="data row3 col5" >80.000000</td>
#       <td id="T_b22a0_row3_col6" class="data row3 col6" >90.000000</td>
#       <td id="T_b22a0_row3_col7" class="data row3 col7" >197.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b22a0_level0_row4" class="row_heading level0 row4" >Индекс массы тела</th>
#       <td id="T_b22a0_row4_col0" class="data row4 col0" >12832.000000</td>
#       <td id="T_b22a0_row4_col1" class="data row4 col1" >28.500367</td>
#       <td id="T_b22a0_row4_col2" class="data row4 col2" >4.928536</td>
#       <td id="T_b22a0_row4_col3" class="data row4 col3" >10.080000</td>
#       <td id="T_b22a0_row4_col4" class="data row4 col4" >25.209201</td>
#       <td id="T_b22a0_row4_col5" class="data row4 col5" >27.760000</td>
#       <td id="T_b22a0_row4_col6" class="data row4 col6" >31.140000</td>
#       <td id="T_b22a0_row4_col7" class="data row4 col7" >72.562358</td>
#     </tr>
#   </tbody>
# </table>
# ### 👀 Первые 5 строк данных
#     Age  Sex   Рост   Вес  Индекс массы тела
# 0  78.0  0.0  168.0  75.0                NaN
# 1  80.0  1.0  160.0  55.0           21.48000
# 2  40.0  0.0  185.0  90.0           26.30000
# 3  78.0  0.0  180.0  98.0                NaN
# 4  75.0  0.0  185.0  76.0           22.20599
# ### 👀 Последние 5 строк данных
#         Age  Sex   Рост    Вес  Индекс массы тела
# 17425  60.0  0.0  176.0   98.0          31.637397
# 17426  81.0  1.0  165.0   78.0          28.650138
# 17427  48.0  0.0  178.0  110.0          34.717839
# 17428  50.0  0.0  170.0   65.0          22.491349
# 17429  53.0  0.0  175.0   78.0          25.469388
# ### 🔍 Анализ уникальных значений (первые 10 столбцов)
#                   unique_count                                      unique_values    dtype
# Age                         78  [78.0, 80.0, 40.0, 75.0, 61.0, 69.0, 67.0, 49....  float64
# Sex                          2                                    [0.0, 1.0, nan]  float64
# Рост                        62  [168.0, 160.0, 185.0, 180.0, 172.0, 167.0, 173...  float64
# Вес                        147  [75.0, 55.0, 90.0, 98.0, 76.0, 105.0, 95.0, 74...  float64
# Индекс массы тела         2616  [nan, 21.48, 26.3, 22.20598977355734, 26.53375...  float64
# ## 🤖 Шаг 2: Обучение моделей с поддержкой пропусков
# ✅ **Успешно импортированы модели с поддержкой пропусков:**
# - XGBoost: автоматическая обработка NaN через параметр `missing`
# - LightGBM: встроенная поддержка пропусков
# - CatBoost: автоматическая обработка пропусков
# ### ⚖️ Параметры для работы с дисбалансом 97%/3%:
# - **scale_pos_weight (XGBoost/LightGBM):** 27.9
# - **class_weight (CatBoost):** {0: 1, 1: 27.889855072463767}
# - **Приоритетная метрика:** Recall для класса 1 (смерть)
# ## 🚀 Обучение baseline моделей
# ### 🚀 Обучение XGBoost...
# ✅ **XGBoost обучена за 10.05 секунд**
# ### 📊 Результаты XGBoost:
# <style type="text/css">
# #T_ff94f_row0_col0, #T_ff94f_row0_col1, #T_ff94f_row0_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_ff94f_row1_col0, #T_ff94f_row1_col1, #T_ff94f_row1_col5 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_ff94f_row2_col0 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_ff94f_row2_col1 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_ff94f_row2_col5 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# </style>
# <table id="T_ff94f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff94f_level0_col0" class="col_heading level0 col0" >Recall (Sensitivity)</th>
#       <th id="T_ff94f_level0_col1" class="col_heading level0 col1" >Balanced Accuracy</th>
#       <th id="T_ff94f_level0_col2" class="col_heading level0 col2" >Precision</th>
#       <th id="T_ff94f_level0_col3" class="col_heading level0 col3" >F1-score</th>
#       <th id="T_ff94f_level0_col4" class="col_heading level0 col4" >ROC-AUC</th>
#       <th id="T_ff94f_level0_col5" class="col_heading level0 col5" >PR-AUC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff94f_level0_row0" class="row_heading level0 row0" >Train</th>
#       <td id="T_ff94f_row0_col0" class="data row0 col0" >0.910145</td>
#       <td id="T_ff94f_row0_col1" class="data row0 col1" >0.877438</td>
#       <td id="T_ff94f_row0_col2" class="data row0 col2" >0.173673</td>
#       <td id="T_ff94f_row0_col3" class="data row0 col3" >0.291686</td>
#       <td id="T_ff94f_row0_col4" class="data row0 col4" >0.940038</td>
#       <td id="T_ff94f_row0_col5" class="data row0 col5" >0.392765</td>
#     </tr>
#     <tr>
#       <th id="T_ff94f_level0_row1" class="row_heading level0 row1" >Validation</th>
#       <td id="T_ff94f_row1_col0" class="data row1 col0" >0.417391</td>
#       <td id="T_ff94f_row1_col1" class="data row1 col1" >0.628116</td>
#       <td id="T_ff94f_row1_col2" class="data row1 col2" >0.084956</td>
#       <td id="T_ff94f_row1_col3" class="data row1 col3" >0.141176</td>
#       <td id="T_ff94f_row1_col4" class="data row1 col4" >0.715308</td>
#       <td id="T_ff94f_row1_col5" class="data row1 col5" >0.081139</td>
#     </tr>
#     <tr>
#       <th id="T_ff94f_level0_row2" class="row_heading level0 row2" >Test</th>
#       <td id="T_ff94f_row2_col0" class="data row2 col0" >0.478261</td>
#       <td id="T_ff94f_row2_col1" class="data row2 col1" >0.652940</td>
#       <td id="T_ff94f_row2_col2" class="data row2 col2" >0.090461</td>
#       <td id="T_ff94f_row2_col3" class="data row2 col3" >0.152144</td>
#       <td id="T_ff94f_row2_col4" class="data row2 col4" >0.683595</td>
#       <td id="T_ff94f_row2_col5" class="data row2 col5" >0.088741</td>
#     </tr>
#   </tbody>
# </table>
# ### ⚠️ Анализ ошибок (крайне важно для медицины):
# ## 📊 Диагностика текущих результатов
# ### Confusion Matrix для XGBoost:
#                   Predicted 0  Predicted 1
# Actual 0 (Выжил)         2655          553
# Actual 1 (Умер)            60           55
# **Confusion Matrix (Test set):**
# - True Negative (правильные выжившие): 2655
# - False Positive (ложные тревоги): 553
# - False Negative (пропущенные смерти) ⚠️: 60
# - True Positive (правильные предсказания смерти): 55
# ❌ **КРИТИЧНО:** Модель пропустила 60 смертельных случаев!
# ⚠️ **Внимание:** 553 ложных тревог могут привести к ненужным вмешательствам
# ### 🌟 Топ-10 важных признаков (XGBoost):
# <style type="text/css">
# #T_308b2_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_308b2_row1_col1 {
#   background-color: #004d1f;
#   color: #f1f1f1;
# }
# #T_308b2_row2_col1 {
#   background-color: #79c67a;
#   color: #000000;
# }
# #T_308b2_row3_col1 {
#   background-color: #c9eac2;
#   color: #000000;
# }
# #T_308b2_row4_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_308b2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_308b2_level0_col0" class="col_heading level0 col0" >Признак</th>
#       <th id="T_308b2_level0_col1" class="col_heading level0 col1" >Важность</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_308b2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_308b2_row0_col0" class="data row0 col0" >Age</td>
#       <td id="T_308b2_row0_col1" class="data row0 col1" >0.233241</td>
#     </tr>
#     <tr>
#       <th id="T_308b2_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_308b2_row1_col0" class="data row1 col0" >Вес</td>
#       <td id="T_308b2_row1_col1" class="data row1 col1" >0.231009</td>
#     </tr>
#     <tr>
#       <th id="T_308b2_level0_row2" class="row_heading level0 row2" >1</th>
#       <td id="T_308b2_row2_col0" class="data row2 col0" >Sex</td>
#       <td id="T_308b2_row2_col1" class="data row2 col1" >0.196066</td>
#     </tr>
#     <tr>
#       <th id="T_308b2_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_308b2_row3_col0" class="data row3 col0" >Индекс массы тела</td>
#       <td id="T_308b2_row3_col1" class="data row3 col1" >0.178661</td>
#     </tr>
#     <tr>
#       <th id="T_308b2_level0_row4" class="row_heading level0 row4" >2</th>
#       <td id="T_308b2_row4_col0" class="data row4 col0" >Рост</td>
#       <td id="T_308b2_row4_col1" class="data row4 col1" >0.161023</td>
#     </tr>
#   </tbody>
# </table>
# ### 🚀 Обучение LightGBM...
# ✅ **LightGBM обучена за 18.73 секунд**
# ### 📊 Результаты LightGBM:
# <style type="text/css">
# #T_869b6_row0_col0, #T_869b6_row0_col1, #T_869b6_row0_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_869b6_row1_col0, #T_869b6_row1_col1, #T_869b6_row1_col5 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_869b6_row2_col0 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_869b6_row2_col1 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_869b6_row2_col5 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# </style>
# <table id="T_869b6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_869b6_level0_col0" class="col_heading level0 col0" >Recall (Sensitivity)</th>
#       <th id="T_869b6_level0_col1" class="col_heading level0 col1" >Balanced Accuracy</th>
#       <th id="T_869b6_level0_col2" class="col_heading level0 col2" >Precision</th>
#       <th id="T_869b6_level0_col3" class="col_heading level0 col3" >F1-score</th>
#       <th id="T_869b6_level0_col4" class="col_heading level0 col4" >ROC-AUC</th>
#       <th id="T_869b6_level0_col5" class="col_heading level0 col5" >PR-AUC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_869b6_level0_row0" class="row_heading level0 row0" >Train</th>
#       <td id="T_869b6_row0_col0" class="data row0 col0" >0.898551</td>
#       <td id="T_869b6_row0_col1" class="data row0 col1" >0.872108</td>
#       <td id="T_869b6_row0_col2" class="data row0 col2" >0.172702</td>
#       <td id="T_869b6_row0_col3" class="data row0 col3" >0.289720</td>
#       <td id="T_869b6_row0_col4" class="data row0 col4" >0.937046</td>
#       <td id="T_869b6_row0_col5" class="data row0 col5" >0.349609</td>
#     </tr>
#     <tr>
#       <th id="T_869b6_level0_row1" class="row_heading level0 row1" >Validation</th>
#       <td id="T_869b6_row1_col0" class="data row1 col0" >0.408696</td>
#       <td id="T_869b6_row1_col1" class="data row1 col1" >0.623924</td>
#       <td id="T_869b6_row1_col2" class="data row1 col2" >0.083481</td>
#       <td id="T_869b6_row1_col3" class="data row1 col3" >0.138643</td>
#       <td id="T_869b6_row1_col4" class="data row1 col4" >0.698901</td>
#       <td id="T_869b6_row1_col5" class="data row1 col5" >0.092208</td>
#     </tr>
#     <tr>
#       <th id="T_869b6_level0_row2" class="row_heading level0 row2" >Test</th>
#       <td id="T_869b6_row2_col0" class="data row2 col0" >0.530435</td>
#       <td id="T_869b6_row2_col1" class="data row2 col1" >0.682611</td>
#       <td id="T_869b6_row2_col2" class="data row2 col2" >0.103215</td>
#       <td id="T_869b6_row2_col3" class="data row2 col3" >0.172805</td>
#       <td id="T_869b6_row2_col4" class="data row2 col4" >0.700218</td>
# ...
#       <td id="T_07985_row0_col0" class="data row0 col0" >LightGBM</td>
#       <td id="T_07985_row0_col1" class="data row0 col1" >0.530</td>
#       <td id="T_07985_row0_col2" class="data row0 col2" >0.683</td>
#       <td id="T_07985_row0_col3" class="data row0 col3" >0.103</td>
#       <td id="T_07985_row0_col4" class="data row0 col4" >0.173</td>
#       <td id="T_07985_row0_col5" class="data row0 col5" >0.101</td>
#       <td id="T_07985_row0_col6" class="data row0 col6" >0.700</td>
#     </tr>
#     <tr>
#       <th id="T_07985_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_07985_row1_col0" class="data row1 col0" >CatBoost</td>
#       <td id="T_07985_row1_col1" class="data row1 col1" >0.583</td>
#       <td id="T_07985_row1_col2" class="data row1 col2" >0.672</td>
#       <td id="T_07985_row1_col3" class="data row1 col3" >0.080</td>
#       <td id="T_07985_row1_col4" class="data row1 col4" >0.141</td>
#       <td id="T_07985_row1_col5" class="data row1 col5" >0.110</td>
#       <td id="T_07985_row1_col6" class="data row1 col6" >0.703</td>
#     </tr>
#     <tr>
#       <th id="T_07985_level0_row2" class="row_heading level0 row2" >0</th>
#       <td id="T_07985_row2_col0" class="data row2 col0" >XGBoost</td>
#       <td id="T_07985_row2_col1" class="data row2 col1" >0.478</td>
#       <td id="T_07985_row2_col2" class="data row2 col2" >0.653</td>
#       <td id="T_07985_row2_col3" class="data row2 col3" >0.090</td>
#       <td id="T_07985_row2_col4" class="data row2 col4" >0.152</td>
#       <td id="T_07985_row2_col5" class="data row2 col5" >0.089</td>
#       <td id="T_07985_row2_col6" class="data row2 col6" >0.684</td>
#     </tr>
#   </tbody>
# </table>
# ## 🎯 Рекомендации по выбору модели:
# ### 🔍 **Разные модели лидируют по разным метрикам:**
# - **Лучший Balanced Accuracy:** LightGBM - приоритет для медицины!
# - **Лучший PR-AUC:** CatBoost - баланс precision/recall
# ## ⚙️ Оптимизация порога классификации для LightGBM
# ### 🎯 Оптимальный порог классификации: 0.50
# - **Balanced Accuracy при этом пороге:** 0.683
# - **Precision при этом пороге:** 0.103
# ### 📊 Финальные метрики с оптимальным порогом:
# <style type="text/css">
# #T_173c9_row0_col1 {
#   background-color: #268e47;
#   color: #f1f1f1;
# }
# #T_173c9_row1_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_173c9_row2_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_173c9_row3_col1 {
#   background-color: #e6f5e1;
#   color: #000000;
# }
# </style>
# <table id="T_173c9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_173c9_level0_col0" class="col_heading level0 col0" >Метрика</th>
#       <th id="T_173c9_level0_col1" class="col_heading level0 col1" >Значение</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_173c9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_173c9_row0_col0" class="data row0 col0" >Recall (Sensitivity)</td>
#       <td id="T_173c9_row0_col1" class="data row0 col1" >0.530435</td>
#     </tr>
#     <tr>
#       <th id="T_173c9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_173c9_row1_col0" class="data row1 col0" >Balanced Accuracy</td>
#       <td id="T_173c9_row1_col1" class="data row1 col1" >0.682611</td>
#     </tr>
#     <tr>
#       <th id="T_173c9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_173c9_row2_col0" class="data row2 col0" >Precision</td>
#       <td id="T_173c9_row2_col1" class="data row2 col1" >0.103215</td>
#     </tr>
#     <tr>
#       <th id="T_173c9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_173c9_row3_col0" class="data row3 col0" >F1-score</td>
#       <td id="T_173c9_row3_col1" class="data row3 col1" >0.172805</td>
#     </tr>
#   </tbody>
# </table>
# ## 📊 Диагностика текущих результатов
# ### Confusion Matrix для LightGBM:
#                   Predicted 0  Predicted 1
# Actual 0 (Выжил)         2678          530
# Actual 1 (Умер)            54           61
# ### Критические метрики:
# - **Recall (Sensitivity) для смерти:** 0.530
# - **Количество пропущенных смертей (FN):** 54 из 115
# - **Precision для смерти:** 0.103
# ## 🚀 Шаг 1: Гиперпараметрическая оптимизация
# ### ⚖️ Параметры дисбаланса: scale_pos_weight = 27.9
# ### 🤖 XGBoost оптимизация
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# ✅ **XGBoost оптимизирован за 7.91 секунд**
# **Лучшие параметры:**
# ```python
# {'colsample_bytree': np.float64(0.786705157299192), 'gamma': np.float64(0.4299702033681603), 'learning_rate': np.float64(0.2140922615763339), 'max_depth': 3, 'min_child_weight': 7, 'n_estimators': 67, 'scale_pos_weight': 27.889855072463767, 'subsample': np.float64(0.9862528132298237)}
# ```
# **Лучший Balanced Accuracy на кросс-валидации:** 0.628
# ### 🤖 LightGBM оптимизация
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# ✅ **LightGBM оптимизирован за 2409.72 секунд**
# **Лучшие параметры:**
# ```python
# {'class_weight': {0: 1, 1: 27.889855072463767}, 'colsample_bytree': np.float64(0.7615344684232164), 'learning_rate': np.float64(0.029467674132694466), 'max_depth': 4, 'min_child_samples': 24, 'n_estimators': 61, 'num_leaves': 53, 'subsample': np.float64(0.7988994023569542)}
# ```
# **Лучший Balanced Accuracy на кросс-валидации:** 0.655
# ### 🤖 CatBoost оптимизация
# 🔍 **Запуск рандомизированного поиска для CatBoost...**
# Итерация 1/15: Balanced Accuracy = 0.680
# Итерация 6/15: Balanced Accuracy = 0.662
# Итерация 11/15: Balanced Accuracy = 0.693
# Итерация 16/15: Balanced Accuracy = 0.687
# Итерация 21/15: Balanced Accuracy = 0.683
# ✅ **CatBoost оптимизирован за 3.05 секунд**
# **Лучшие параметры:**
# ```python
# {'iterations': 268, 'learning_rate': np.float64(0.2465550935427162), 'depth': 4, 'l2_leaf_reg': np.float64(7.951137521967642), 'border_count': 106, 'class_weights': [1, np.float64(27.889855072463767)]}
# ```
# **Лучший Balanced Accuracy на validation:** 0.697
# ## 📊 Шаг 2: Оценка оптимизированных моделей
# ### 📈 Оценка XGBoost
# **Метрики на тестовом наборе:**
# <style type="text/css">
# #T_fff9e_row0_col1 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_fff9e_row1_col1 {
#   background-color: #084488;
#   color: #f1f1f1;
# }
# #T_fff9e_row2_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_fff9e_row3_col1 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_fff9e_row4_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_fff9e_row5_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# </style>
# <table id="T_fff9e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fff9e_level0_col0" class="col_heading level0 col0" >Метрика</th>
#       <th id="T_fff9e_level0_col1" class="col_heading level0 col1" >Значение</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fff9e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fff9e_row0_col0" class="data row0 col0" >Recall</td>
#       <td id="T_fff9e_row0_col1" class="data row0 col1" >0.565217</td>
#     </tr>
#     <tr>
#       <th id="T_fff9e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fff9e_row1_col0" class="data row1 col0" >Balanced Accuracy</td>
#       <td id="T_fff9e_row1_col1" class="data row1 col1" >0.664467</td>
#     </tr>
#     <tr>
#       <th id="T_fff9e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fff9e_row2_col0" class="data row2 col0" >Precision</td>
#       <td id="T_fff9e_row2_col1" class="data row2 col1" >0.078979</td>
#     </tr>
#     <tr>
#       <th id="T_fff9e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fff9e_row3_col0" class="data row3 col0" >F1-score</td>
#       <td id="T_fff9e_row3_col1" class="data row3 col1" >0.138593</td>
#     </tr>
#     <tr>
#       <th id="T_fff9e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fff9e_row4_col0" class="data row4 col0" >ROC-AUC</td>
#       <td id="T_fff9e_row4_col1" class="data row4 col1" >0.711852</td>
#     </tr>
#     <tr>
#       <th id="T_fff9e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fff9e_row5_col0" class="data row5 col0" >PR-AUC</td>
#       <td id="T_fff9e_row5_col1" class="data row5 col1" >0.115216</td>
#     </tr>
#   </tbody>
# </table>
# ### 📈 Оценка LightGBM
# **Метрики на тестовом наборе:**
# <style type="text/css">
# #T_046e9_row0_col1 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_046e9_row1_col1 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_046e9_row2_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_046e9_row3_col1 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_046e9_row4_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_046e9_row5_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# </style>
# <table id="T_046e9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_046e9_level0_col0" class="col_heading level0 col0" >Метрика</th>
#       <th id="T_046e9_level0_col1" class="col_heading level0 col1" >Значение</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_046e9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_046e9_row0_col0" class="data row0 col0" >Recall</td>
#       <td id="T_046e9_row0_col1" class="data row0 col1" >0.547826</td>
#     </tr>
#     <tr>
#       <th id="T_046e9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_046e9_row1_col0" class="data row1 col0" >Balanced Accuracy</td>
#       <td id="T_046e9_row1_col1" class="data row1 col1" >0.669487</td>
#     </tr>
#     <tr>
#       <th id="T_046e9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_046e9_row2_col0" class="data row2 col0" >Precision</td>
#       <td id="T_046e9_row2_col1" class="data row2 col1" >0.085948</td>
#     </tr>
#     <tr>
#       <th id="T_046e9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_046e9_row3_col0" class="data row3 col0" >F1-score</td>
#       <td id="T_046e9_row3_col1" class="data row3 col1" >0.148585</td>
#     </tr>
#     <tr>
#       <th id="T_046e9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_046e9_row4_col0" class="data row4 col0" >ROC-AUC</td>
#       <td id="T_046e9_row4_col1" class="data row4 col1" >0.701712</td>
#     </tr>
#     <tr>
#       <th id="T_046e9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_046e9_row5_col0" class="data row5 col0" >PR-AUC</td>
#       <td id="T_046e9_row5_col1" class="data row5 col1" >0.090529</td>
#     </tr>
#   </tbody>
# </table>
# ### 📈 Оценка CatBoost
# **Метрики на тестовом наборе:**
# <style type="text/css">
# #T_cbc04_row0_col1 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_cbc04_row1_col1 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_cbc04_row2_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_cbc04_row3_col1 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_cbc04_row4_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_cbc04_row5_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# </style>
# <table id="T_cbc04">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cbc04_level0_col0" class="col_heading level0 col0" >Метрика</th>
#       <th id="T_cbc04_level0_col1" class="col_heading level0 col1" >Значение</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cbc04_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cbc04_row0_col0" class="data row0 col0" >Recall</td>
#       <td id="T_cbc04_row0_col1" class="data row0 col1" >0.617391</td>
#     </tr>
#     <tr>
#       <th id="T_cbc04_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cbc04_row1_col0" class="data row1 col0" >Balanced Accuracy</td>
#       <td id="T_cbc04_row1_col1" class="data row1 col1" >0.675591</td>
#     </tr>
#     <tr>
#       <th id="T_cbc04_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cbc04_row2_col0" class="data row2 col0" >Precision</td>
#       <td id="T_cbc04_row2_col1" class="data row2 col1" >0.076757</td>
#     </tr>
#     <tr>
#       <th id="T_cbc04_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cbc04_row3_col0" class="data row3 col0" >F1-score</td>
#       <td id="T_cbc04_row3_col1" class="data row3 col1" >0.136538</td>
#     </tr>
#     <tr>
#       <th id="T_cbc04_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cbc04_row4_col0" class="data row4 col0" >ROC-AUC</td>
#       <td id="T_cbc04_row4_col1" class="data row4 col1" >0.697256</td>
#     </tr>
#     <tr>
#       <th id="T_cbc04_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cbc04_row5_col0" class="data row5 col0" >PR-AUC</td>
#       <td id="T_cbc04_row5_col1" class="data row5 col1" >0.111654</td>
#     </tr>
#   </tbody>
# </table>
# ## 🏆 Сравнение оптимизированных моделей:
# <style type="text/css">
# #T_3f09d_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_3f09d_row0_col2, #T_3f09d_row1_col4, #T_3f09d_row2_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_3f09d_row0_col3 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_3f09d_row0_col4, #T_3f09d_row0_col5, #T_3f09d_row2_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_3f09d_row1_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_3f09d_row1_col2 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_3f09d_row1_col3 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_3f09d_row1_col5 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_3f09d_row2_col1 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_3f09d_row2_col3 {
#   background-color: #fdd2a6;
#   color: #000000;
# }
# #T_3f09d_row2_col4 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# </style>
# <table id="T_3f09d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3f09d_level0_col0" class="col_heading level0 col0" >Модель</th>
#       <th id="T_3f09d_level0_col1" class="col_heading level0 col1" >Recall</th>
#       <th id="T_3f09d_level0_col2" class="col_heading level0 col2" >Balanced Accuracy</th>
#       <th id="T_3f09d_level0_col3" class="col_heading level0 col3" >Precision</th>
#       <th id="T_3f09d_level0_col4" class="col_heading level0 col4" >F1-score</th>
#       <th id="T_3f09d_level0_col5" class="col_heading level0 col5" >ROC-AUC</th>
#       <th id="T_3f09d_level0_col6" class="col_heading level0 col6" >PR-AUC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3f09d_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_3f09d_row0_col0" class="data row0 col0" >CatBoost</td>
#       <td id="T_3f09d_row0_col1" class="data row0 col1" >0.617391</td>
#       <td id="T_3f09d_row0_col2" class="data row0 col2" >0.675591</td>
#       <td id="T_3f09d_row0_col3" class="data row0 col3" >0.076757</td>
#       <td id="T_3f09d_row0_col4" class="data row0 col4" >0.136538</td>
#       <td id="T_3f09d_row0_col5" class="data row0 col5" >0.697256</td>
#       <td id="T_3f09d_row0_col6" class="data row0 col6" >0.111654</td>
#     </tr>
#     <tr>
#       <th id="T_3f09d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3f09d_row1_col0" class="data row1 col0" >LightGBM</td>
#       <td id="T_3f09d_row1_col1" class="data row1 col1" >0.547826</td>
#       <td id="T_3f09d_row1_col2" class="data row1 col2" >0.669487</td>
#       <td id="T_3f09d_row1_col3" class="data row1 col3" >0.085948</td>
#       <td id="T_3f09d_row1_col4" class="data row1 col4" >0.148585</td>
#       <td id="T_3f09d_row1_col5" class="data row1 col5" >0.701712</td>
#       <td id="T_3f09d_row1_col6" class="data row1 col6" >0.090529</td>
#     </tr>
#     <tr>
#       <th id="T_3f09d_level0_row2" class="row_heading level0 row2" >0</th>
#       <td id="T_3f09d_row2_col0" class="data row2 col0" >XGBoost</td>
#       <td id="T_3f09d_row2_col1" class="data row2 col1" >0.565217</td>
#       <td id="T_3f09d_row2_col2" class="data row2 col2" >0.664467</td>
#       <td id="T_3f09d_row2_col3" class="data row2 col3" >0.078979</td>
#       <td id="T_3f09d_row2_col4" class="data row2 col4" >0.138593</td>
#       <td id="T_3f09d_row2_col5" class="data row2 col5" >0.711852</td>
#       <td id="T_3f09d_row2_col6" class="data row2 col6" >0.115216</td>
#     </tr>
#   </tbody>
# </table>
# ## 🎯 Лучшая модель по Balanced Accuracy: **CatBoost**
